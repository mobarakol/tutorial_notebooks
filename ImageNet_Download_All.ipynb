# %% [markdown]
# <a href="https://colab.research.google.com/github/mobarakol/tutorial_notebooks/blob/main/ImageNet_Download_All.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ImageNet (ILSVRC2012)
#
# It contains 1000 classes, 1.28 million training images, and 50 thousand validation images. There are 1,281,167 images and 732-1300 per class in the ILSVRC2012 training set. This dataset spans 1000 object classes and contains 1,281,167 training images, 50,000 validation images and 100,000 test images. It requires more than 150GB of storage, and training a resnet50 on it will take around 215 hours using a T4 GPU on Google Colab. Folder name to actual class mapping: https://www.image-net.org/challenges/LSVRC/2012/browse-synsets.php <br>
# Sample size is not equal in ImageNet. For example top 10 classes:<br>
# n02094433:    3047 (Yorkshire terrier)<br>
# n02086240:    2563 (Shih-Tzu)<br>
# n01882714:    2469 (koala bear, kangaroo bear, native bear, )<br>
# n02087394:    2449 (Rhodesian ridgeback)<br>
# n02100735:    2426 (English setter)<br>
# n00483313:    2410 (singles)<br>
# n02279972:    2386 (monarch butterfly, Danaus plexippus)<br>
# n09428293:    2382 (seashore)<br>
# n02138441:    2341 (meerkat)<br>
# n02100583:    2334 (vizsla, Hungarian pointer)<br>
#
#
# Task-1. Image classification (2010-2014): Algorithms produce a list of object categories present in the image.<br>
# Task-2. Single-object localization (2011-2014): Algorithms
# produce a list of object categories present in the image, along with an axis-aligned bounding box indicating the position and scale of one instance of each object category.<br>
# Task-3. Object detection (2013-2014): Algorithms produce
# a list of object categories present in the image along
# with an axis-aligned bounding box indicating the
# position and scale of every instance of each object
# category.<br>
#
# #Download Links:
#
# Training Images (taskl&2): https://image-net.org/data/ILSVRC/2012/ILSVRC2012_img_train.tar <br>
# Training Annotations (taskl&2): https://image-net.org/data/ILSVRC/2012/ILSVRC2012_bbox_train_v2.tar.gz <br>
#
# Validation Images (all tasks): https://image-net.org/data/ILSVRC/2012/ILSVRC2012_img_val.tar
#
# Validation Annotations (all tasks): https://image-net.org/data/ILSVRC/2012/ILSVRC2012_bbox_val_v3.tgz

# %% [markdown]
# # Download specific number of classes and samples per class:

# %%
! git clone https://github.com/mf1024/ImageNet-Datasets-Downloader.git
# %cd ImageNet-Datasets-Downloader
! mkdir imagenet
# Out:
# fatal: destination path 'ImageNet-Datasets-Downloader' already exists and is not an empty directory.
# /content/ImageNet-Datasets-Downloader

# %%
#!/usr/bin/env python3
import os
import numpy as np
import requests
import argparse
import json
import time
import logging
import csv

from multiprocessing import Pool, Process, Value, Lock

from requests.exceptions import ConnectionError, ReadTimeout, TooManyRedirects, MissingSchema, InvalidURL

parser = argparse.ArgumentParser(description='ImageNet image scraper')
parser.add_argument('-scrape_only_flickr', default=True, type=lambda x: (str(x).lower() == 'true'))
parser.add_argument('-number_of_classes', default = 1000, type=int)
parser.add_argument('-images_per_class', default = 10, type=int)
parser.add_argument('-data_root', default='imagenet' , type=str)
parser.add_argument('-use_class_list', default=False,type=lambda x: (str(x).lower() == 'true'))
parser.add_argument('-class_list', default=[], nargs='*')
parser.add_argument('-debug', default=False,type=lambda x: (str(x).lower() == 'true'))

parser.add_argument('-multiprocessing_workers', default = 8, type=int)

args, args_other = parser.parse_known_args([])

if args.debug:
    logging.basicConfig(filename='imagenet_scarper.log', level=logging.DEBUG)

if len(args.data_root) == 0:
    logging.error("-data_root is required to run downloader!")
    exit()

if not os.path.isdir(args.data_root):
    logging.error(f'folder {args.data_root} does not exist! please provide existing folder in -data_root arg!')
    exit()


IMAGENET_API_WNID_TO_URLS = lambda wnid: f'http://www.image-net.org/api/imagenet.synset.geturls?wnid={wnid}'

current_folder = os.path.dirname(os.path.realpath('__file__'))

class_info_json_filename = 'imagenet_class_info.json'
class_info_json_filepath = os.path.join(current_folder, class_info_json_filename)

class_info_dict = dict()

with open(class_info_json_filepath) as class_info_json_f:
    class_info_dict = json.load(class_info_json_f)

classes_to_scrape = []

if args.use_class_list == True:
   for item in args.class_list:
       classes_to_scrape.append(item)
       if item not in class_info_dict:
           logging.error(f'Class {item} not found in ImageNete')
           exit()

elif args.use_class_list == False:
    potential_class_pool = []
    for key, val in class_info_dict.items():

        if args.scrape_only_flickr:
            if int(val['flickr_img_url_count']) * 0.9 > args.images_per_class:
                potential_class_pool.append(key)
        else:
            if int(val['img_url_count']) * 0.8 > args.images_per_class:
                potential_class_pool.append(key)

    if (len(potential_class_pool) < args.number_of_classes):
        logging.error(f"With {args.images_per_class} images per class there are {len(potential_class_pool)} to choose from.")
        logging.error(f"Decrease number of classes or decrease images per class.")
        exit()

    picked_classes_idxes = np.random.choice(len(potential_class_pool), args.number_of_classes, replace = False)

    for idx in picked_classes_idxes:
        classes_to_scrape.append(potential_class_pool[idx])


print("Picked the following clases:")
print([ class_info_dict[class_wnid]['class_name'] for class_wnid in classes_to_scrape ])

imagenet_images_folder = os.path.join(args.data_root, 'imagenet_images')
if not os.path.isdir(imagenet_images_folder):
    os.mkdir(imagenet_images_folder)


scraping_stats = dict(
    all=dict(
        tried=0,
        success=0,
        time_spent=0,
    ),
    is_flickr=dict(
        tried=0,
        success=0,
        time_spent=0,
    ),
    not_flickr=dict(
        tried=0,
        success=0,
        time_spent=0,
    )
)

def add_debug_csv_row(row):
    with open('stats.csv', "a") as csv_f:
        csv_writer = csv.writer(csv_f, delimiter=",")
        csv_writer.writerow(row)

class MultiStats():
    def __init__(self):

        self.lock = Lock()

        self.stats = dict(
            all=dict(
                tried=Value('d', 0),
                success=Value('d',0),
                time_spent=Value('d',0),
            ),
            is_flickr=dict(
                tried=Value('d', 0),
                success=Value('d',0),
                time_spent=Value('d',0),
            ),
            not_flickr=dict(
                tried=Value('d', 0),
                success=Value('d', 0),
                time_spent=Value('d', 0),
            )
        )
    def inc(self, cls, stat, val):
        with self.lock:
            self.stats[cls][stat].value += val

    def get(self, cls, stat):
        with self.lock:
            ret = self.stats[cls][stat].value
        return ret

multi_stats = MultiStats()


if args.debug:
    row = [
        "all_tried",
        "all_success",
        "all_time_spent",
        "is_flickr_tried",
        "is_flickr_success",
        "is_flickr_time_spent",
        "not_flickr_tried",
        "not_flickr_success",
        "not_flickr_time_spent"
    ]
    add_debug_csv_row(row)

def add_stats_to_debug_csv():
    row = [
        multi_stats.get('all', 'tried'),
        multi_stats.get('all', 'success'),
        multi_stats.get('all', 'time_spent'),
        multi_stats.get('is_flickr', 'tried'),
        multi_stats.get('is_flickr', 'success'),
        multi_stats.get('is_flickr', 'time_spent'),
        multi_stats.get('not_flickr', 'tried'),
        multi_stats.get('not_flickr', 'success'),
        multi_stats.get('not_flickr', 'time_spent'),
    ]
    add_debug_csv_row(row)

def print_stats(cls, print_func):

    actual_all_time_spent = time.time() - scraping_t_start.value
    processes_all_time_spent = multi_stats.get('all', 'time_spent')

    if processes_all_time_spent == 0:
        actual_processes_ratio = 1.0
    else:
        actual_processes_ratio = actual_all_time_spent / processes_all_time_spent

    #print(f"actual all time: {actual_all_time_spent} proc all time {processes_all_time_spent}")

    print_func(f'STATS For class {cls}:')
    print_func(f' tried {multi_stats.get(cls, "tried")} urls with'
               f' {multi_stats.get(cls, "success")} successes')

    if multi_stats.get(cls, "tried") > 0:
        print_func(f'{100.0 * multi_stats.get(cls, "success")/multi_stats.get(cls, "tried")}% success rate for {cls} urls ')
    if multi_stats.get(cls, "success") > 0:
        print_func(f'{multi_stats.get(cls,"time_spent") * actual_processes_ratio / multi_stats.get(cls,"success")} seconds spent per {cls} succesful image download')



lock = Lock()
url_tries = Value('d', 0)
scraping_t_start = Value('d', time.time())
class_folder = ''
class_images = Value('d', 0)

def get_image(img_url):

    #print(f'Processing {img_url}')

    #time.sleep(3)

    if len(img_url) <= 1:
        return


    cls_imgs = 0
    with lock:
        cls_imgs = class_images.value

    if cls_imgs >= args.images_per_class:
        return

    logging.debug(img_url)

    cls = ''

    if 'flickr' in img_url:
        cls = 'is_flickr'
    else:
        cls = 'not_flickr'
        if args.scrape_only_flickr:
            return

    t_start = time.time()

    def finish(status):
        t_spent = time.time() - t_start
        multi_stats.inc(cls, 'time_spent', t_spent)
        multi_stats.inc('all', 'time_spent', t_spent)

        multi_stats.inc(cls,'tried', 1)
        multi_stats.inc('all', 'tried', 1)

        if status == 'success':
            multi_stats.inc(cls,'success', 1)
            multi_stats.inc('all', 'success', 1)

        elif status == 'failure':
            pass
        else:
            logging.error(f'No such status {status}!!')
            exit()
        return


    with lock:
        url_tries.value += 1
        if url_tries.value % 250 == 0:
            print(f'\nScraping stats:')
            print_stats('is_flickr', print)
            print_stats('not_flickr', print)
            print_stats('all', print)
            if args.debug:
                add_stats_to_debug_csv()

    try:
        img_resp = requests.get(img_url, timeout = 1)
    except ConnectionError:
        logging.debug(f"Connection Error for url {img_url}")
        return finish('failure')
    except ReadTimeout:
        logging.debug(f"Read Timeout for url {img_url}")
        return finish('failure')
    except TooManyRedirects:
        logging.debug(f"Too many redirects {img_url}")
        return finish('failure')
    except MissingSchema:
        return finish('failure')
    except InvalidURL:
        return finish('failure')

    if not 'content-type' in img_resp.headers:
        return finish('failure')

    if not 'image' in img_resp.headers['content-type']:
        logging.debug("Not an image")
        return finish('failure')

    if (len(img_resp.content) < 1000):
        return finish('failure')

    logging.debug(img_resp.headers['content-type'])
    logging.debug(f'image size {len(img_resp.content)}')

    img_name = img_url.split('/')[-1]
    img_name = img_name.split("?")[0]

    if (len(img_name) <= 1):
        return finish('failure')

    img_file_path = os.path.join(class_folder, img_name)
    logging.debug(f'Saving image in {img_file_path}')

    with open(img_file_path, 'wb') as img_f:
        img_f.write(img_resp.content)

        with lock:
            class_images.value += 1

        logging.debug(f'Scraping stats')
        print_stats('is_flickr', logging.debug)
        print_stats('not_flickr', logging.debug)
        print_stats('all', logging.debug)

        return finish('success')


for class_wnid in classes_to_scrape:

    class_name = class_info_dict[class_wnid]["class_name"]
    print(f'Scraping images for class \"{class_name}\"')
    url_urls = IMAGENET_API_WNID_TO_URLS(class_wnid)

    time.sleep(0.05)
    resp = requests.get(url_urls)

    class_folder = os.path.join(imagenet_images_folder, class_name)
    if not os.path.exists(class_folder):
        os.mkdir(class_folder)

    class_images.value = 0

    urls = [url.decode('utf-8') for url in resp.content.splitlines()]

    #for url in  urls:
    #    get_image(url)

    print(f"Multiprocessing workers: {args.multiprocessing_workers}")
    with Pool(processes=args.multiprocessing_workers) as p:
        p.map(get_image,urls)
# Out:
# Picked the following clases:
# ['Polynesian tattler', 'turnip greens', 'Delicious', 'swallow-tailed kite', 'ant bear', 'Boy Scout', 'prize winner', 'stand', 'barometer', 'pin', 'Australian pine', 'anode', 'comer', 'strawberry tomato', 'dungeon', 'tunicate', 'conning tower', 'sieva bean', 'solan', 'dunker', 'berth', 'sanitary napkin', 'afropavo', 'maggot', 'ensign', 'puffball', 'tinfoil', 'stupa', 'wing nut', 'huntress', 'beet', 'chicken paprika', 'ground ivy', 'gargoyle', 'native cranberry', 'no-hit game', 'kin', 'laser-guided bomb', 'protea', 'Olympian', 'video recording', 'winery', 'cinchona', 'depth finder', 'evergreen', 'Psychopsis krameriana', 'computerized axial tomography scanner', 'Lhasa', 'dry wall', 'bedpan', 'mountain ebony', 'stakeholder', 'Canada lily', 'flashlight battery', 'dwarf dandelion', 'ciderpress', 'grater', 'Mexican mint', 'ruff', 'cereal bowl', 'iridaceous plant', 'field sparrow', 'winter crookneck', 'baggage', 'red maple', 'western redbud', 'bass horn', 'splint', 'hypercoaster', 'hood', 'New World oriole', 'purple finch', 'power drill', 'villa', 'egg yolk', 'calf', 'birch', 'lounging pajama', 'pocket rat', 'chestnut', 'Polistes annularis', 'black mangrove', 'calamus', 'grinner', 'audio amplifier', 'popinjay', 'skylark', 'roarer', 'bumblebee', 'California wine', 'preserver', 'goosander', 'skullcap', 'domestic goat', 'mossy saxifrage', 'siskin', 'pine siskin', 'clintonia', 'interceptor', 'Metis', 'character printer', 'guard', 'pear', 'lake trout', 'popcorn', 'diaper', 'dining-hall', 'black poplar', 'fly poison', 'blue columbine', 'ewe', 'storage ring', 'dishtowel', 'racerunner', 'nightshade', 'urn', 'water horehound', 'ague root', 'basil', 'birdbath', 'pouch', 'Old World beaver', 'belted kingfisher', 'love-in-a-mist', 'scaling ladder', 'beast of burden', 'tube', 'strangler', 'smooth plane', 'dough', 'Scotch egg', 'cranberry bush', 'claret', 'velociraptor', 'bog rosemary', 'mammillaria', 'treadmill', 'wild oat', 'salamander', 'wraparound', 'school ship', 'elevator', 'vice chancellor', 'papaya', 'poplin', 'discussant', 'silver fern', 'man of letters', 'Russian almond', 'kangaroo', 'mechanical system', 'canvas', 'slipper', 'Muscadet', 'tachymeter', 'climbing fern', 'scrutineer', 'aioli', 'puppy', 'fudge', 'platform bed', 'computer scientist', 'seat', 'suckling', 'broad-leaved plantain', 'plant', 'electric meter', 'coriander', 'office furniture', 'sunflower seed', 'black bream', "fisherman's lure", 'rudder', 'seaside daisy', 'cathode-ray tube', 'bubble chamber', 'swamp birch', 'smart bomb', 'cigar box', 'motmot', 'ticking', 'pinesap', 'can', 'Kahlua', 'snowplow', 'dancing-master', 'inclinometer', 'lawman', 'raita', 'turbot', 'western grey squirrel', 'mimosa', 'fly orchid', 'wright', 'diapheromera', 'medusa', 'desk phone', 'zoysia', 'gear', 'Iceland moss', 'chicken yard', 'button pink', 'mountain skink', 'ethernet', 'ex-husband', 'reef squirrelfish', 'bandicoot', 'capelin', 'heart', 'organ loft', 'fallow deer', 'bomb', 'orange', 'holly fern', 'New World warbler', 'Pitot tube', 'ball carrier', 'bluetick', 'lamb', 'juniper berries', 'grand piano', 'two-toed sloth', 'nipple', 'gusher', 'allspice', 'cog', 'call forwarding', 'hop clover', 'hospital', 'bull snake', 'weapon', 'basket', 'sidecar', 'chair', 'demitasse', 'Mason jar', 'theosophist', 'Wedgwood', 'sewer', 'clamp', 'chapterhouse', 'polyphemus moth', 'trailing edge', 'fox', 'harrier', 'one-flowered wintergreen', 'windfall', 'car', 'musteline mammal', 'Atlantic halibut', 'cannon', 'Oregon white oak', 'sheik', 'easy chair', 'common comfrey', 'European hornbeam', 'young mammal', 'shiitake', 'wax palm', 'orange sneezeweed', 'grapnel', 'guppy', 'platen', 'guy', 'mountain lily', 'blacktip shark', 'cardoon', 'roper', 'thermal printer', 'flower girl', 'Aryan', 'candied fruit', 'black bread', 'Beaujolais', 'freshwater mussel', 'saurischian', 'safety arch', 'green snake', 'bottle green', 'menorah', 'macadamia', 'substitute', 'chantry', 'huckster', 'earthstar', 'gander', 'aposematic coloration', 'a ...
# Scraping images for class "Polynesian tattler"
# Multiprocessing workers: 8
# Scraping images for class "turnip greens"
# Multiprocessing workers: 8
# Scraping images for class "Delicious"
# Multiprocessing workers: 8
# Scraping images for class "swallow-tailed kite"
# Multiprocessing workers: 8
# Scraping images for class "ant bear"
# Multiprocessing workers: 8
# Scraping images for class "Boy Scout"
# Multiprocessing workers: 8
# Scraping images for class "prize winner"
# Multiprocessing workers: 8
# Scraping images for class "stand"
# Multiprocessing workers: 8
# Scraping images for class "barometer"
# Multiprocessing workers: 8
# Scraping images for class "pin"
# Multiprocessing workers: 8
# Scraping images for class "Australian pine"
# Multiprocessing workers: 8
# Scraping images for class "anode"
# Multiprocessing workers: 8
# Scraping images for class "comer"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 242.0 urls with 199.0 successes
# 82.23140495867769% success rate for is_flickr urls
# 0.09229335593218779 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 242.0 urls with 199.0 successes
# 82.23140495867769% success rate for all urls
# 0.0925957916969031 seconds spent per all succesful image download
# Scraping images for class "strawberry tomato"
# Multiprocessing workers: 8
# Scraping images for class "dungeon"
# Multiprocessing workers: 8
# Scraping images for class "tunicate"
# Multiprocessing workers: 8
# Scraping images for class "conning tower"
# Multiprocessing workers: 8
# Scraping images for class "sieva bean"
# Multiprocessing workers: 8
# Scraping images for class "solan"
# Multiprocessing workers: 8
# Scraping images for class "dunker"
# Multiprocessing workers: 8
# Scraping images for class "berth"
# Multiprocessing workers: 8
# Scraping images for class "sanitary napkin"
# Multiprocessing workers: 8
# Scraping images for class "afropavo"
# Multiprocessing workers: 8
# Scraping images for class "maggot"
# Multiprocessing workers: 8
# Scraping images for class "ensign"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 492.0 urls with 393.0 successes
# 79.8780487804878% success rate for is_flickr urls
# 0.09106160848195316 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 494.0 urls with 393.0 successes
# 79.55465587044534% success rate for all urls
# 0.0913468386728484 seconds spent per all succesful image download
# Scraping images for class "puffball"
# Multiprocessing workers: 8
# Scraping images for class "tinfoil"
# Multiprocessing workers: 8
# Scraping images for class "stupa"
# Multiprocessing workers: 8
# Scraping images for class "wing nut"
# Multiprocessing workers: 8
# Scraping images for class "huntress"
# Multiprocessing workers: 8
# Scraping images for class "beet"
# Multiprocessing workers: 8
# Scraping images for class "chicken paprika"
# Multiprocessing workers: 8
# Scraping images for class "ground ivy"
# Multiprocessing workers: 8
# Scraping images for class "gargoyle"
# Multiprocessing workers: 8
# Scraping images for class "native cranberry"
# Multiprocessing workers: 8
# Scraping images for class "no-hit game"
# Multiprocessing workers: 8
# Scraping images for class "kin"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 742.0 urls with 581.0 successes
# 78.30188679245283% success rate for is_flickr urls
# 0.0916280939328691 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 742.0 urls with 581.0 successes
# 78.30188679245283% success rate for all urls
# 0.09171612948025361 seconds spent per all succesful image download
# Scraping images for class "laser-guided bomb"
# Multiprocessing workers: 8
# Scraping images for class "protea"
# Multiprocessing workers: 8
# Scraping images for class "Olympian"
# Multiprocessing workers: 8
# Scraping images for class "video recording"
# Multiprocessing workers: 8
# Scraping images for class "winery"
# Multiprocessing workers: 8
# Scraping images for class "cinchona"
# Multiprocessing workers: 8
# Scraping images for class "depth finder"
# Multiprocessing workers: 8
# Scraping images for class "evergreen"
# Multiprocessing workers: 8
# Scraping images for class "Psychopsis krameriana"
# Multiprocessing workers: 8
# Scraping images for class "computerized axial tomography scanner"
# Multiprocessing workers: 8
# Scraping images for class "Lhasa"
# Multiprocessing workers: 8
# Scraping images for class "dry wall"
# Multiprocessing workers: 8
# Scraping images for class "bedpan"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 996.0 urls with 783.0 successes
# 78.6144578313253% success rate for is_flickr urls
# 0.0919577962746261 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 996.0 urls with 783.0 successes
# 78.6144578313253% success rate for all urls
# 0.0920716522601677 seconds spent per all succesful image download
# Scraping images for class "mountain ebony"
# Multiprocessing workers: 8
# Scraping images for class "stakeholder"
# Multiprocessing workers: 8
# Scraping images for class "Canada lily"
# Multiprocessing workers: 8
# Scraping images for class "flashlight battery"
# Multiprocessing workers: 8
# Scraping images for class "dwarf dandelion"
# Multiprocessing workers: 8
# Scraping images for class "ciderpress"
# Multiprocessing workers: 8
# Scraping images for class "grater"
# Multiprocessing workers: 8
# Scraping images for class "Mexican mint"
# Multiprocessing workers: 8
# Scraping images for class "ruff"
# Multiprocessing workers: 8
# Scraping images for class "cereal bowl"
# Multiprocessing workers: 8
# Scraping images for class "iridaceous plant"
# Multiprocessing workers: 8
# Scraping images for class "field sparrow"
# Multiprocessing workers: 8
# Scraping images for class "winter crookneck"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 1243.0 urls with 986.0 successes
# 79.32421560740144% success rate for is_flickr urls
# 0.09287303142083345 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 1243.0 urls with 986.0 successes
# 79.32421560740144% success rate for all urls
# 0.0929869048252067 seconds spent per all succesful image download
# Scraping images for class "baggage"
# Multiprocessing workers: 8
# Scraping images for class "red maple"
# Multiprocessing workers: 8
# Scraping images for class "western redbud"
# Multiprocessing workers: 8
# Scraping images for class "bass horn"
# Multiprocessing workers: 8
# Scraping images for class "splint"
# Multiprocessing workers: 8
# Scraping images for class "hypercoaster"
# Multiprocessing workers: 8
# Scraping images for class "hood"
# Multiprocessing workers: 8
# Scraping images for class "New World oriole"
# Multiprocessing workers: 8
# Scraping images for class "purple finch"
# Multiprocessing workers: 8
# Scraping images for class "power drill"
# Multiprocessing workers: 8
# Scraping images for class "villa"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 1492.0 urls with 1170.0 successes
# 78.41823056300268% success rate for is_flickr urls
# 0.09315446156721849 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 1492.0 urls with 1170.0 successes
# 78.41823056300268% success rate for all urls
# 0.09320924119052724 seconds spent per all succesful image download
# Scraping images for class "egg yolk"
# Multiprocessing workers: 8
# Scraping images for class "calf"
# Multiprocessing workers: 8
# Scraping images for class "birch"
# Multiprocessing workers: 8
# Scraping images for class "lounging pajama"
# Multiprocessing workers: 8
# Scraping images for class "pocket rat"
# Multiprocessing workers: 8
# Scraping images for class "chestnut"
# Multiprocessing workers: 8
# Scraping images for class "Polistes annularis"
# Multiprocessing workers: 8
# Scraping images for class "black mangrove"
# Multiprocessing workers: 8
# Scraping images for class "calamus"
# Multiprocessing workers: 8
# Scraping images for class "grinner"
# Multiprocessing workers: 8
# Scraping images for class "audio amplifier"
# Multiprocessing workers: 8
# Scraping images for class "popinjay"
# Multiprocessing workers: 8
# Scraping images for class "skylark"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 1742.0 urls with 1371.0 successes
# 78.70264064293914% success rate for is_flickr urls
# 0.09284241715980046 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 1742.0 urls with 1371.0 successes
# 78.70264064293914% success rate for all urls
# 0.09294505714065919 seconds spent per all succesful image download
# Scraping images for class "roarer"
# Multiprocessing workers: 8
# Scraping images for class "bumblebee"
# Multiprocessing workers: 8
# Scraping images for class "California wine"
# Multiprocessing workers: 8
# Scraping images for class "preserver"
# Multiprocessing workers: 8
# Scraping images for class "goosander"
# Multiprocessing workers: 8
# Scraping images for class "skullcap"
# Multiprocessing workers: 8
# Scraping images for class "domestic goat"
# Multiprocessing workers: 8
# Scraping images for class "mossy saxifrage"
# Multiprocessing workers: 8
# Scraping images for class "siskin"
# Multiprocessing workers: 8
# Scraping images for class "pine siskin"
# Multiprocessing workers: 8
# Scraping images for class "clintonia"
# Multiprocessing workers: 8
# Scraping images for class "interceptor"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 1992.0 urls with 1564.0 successes
# 78.5140562248996% success rate for is_flickr urls
# 0.09335208975750467 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 1992.0 urls with 1564.0 successes
# 78.5140562248996% success rate for all urls
# 0.09338742799466224 seconds spent per all succesful image download
# Scraping images for class "Metis"
# Multiprocessing workers: 8
# Scraping images for class "character printer"
# Multiprocessing workers: 8
# Scraping images for class "guard"
# Multiprocessing workers: 8
# Scraping images for class "pear"
# Multiprocessing workers: 8
# Scraping images for class "lake trout"
# Multiprocessing workers: 8
# Scraping images for class "popcorn"
# Multiprocessing workers: 8
# Scraping images for class "diaper"
# Multiprocessing workers: 8
# Scraping images for class "dining-hall"
# Multiprocessing workers: 8
# Scraping images for class "black poplar"
# Multiprocessing workers: 8
# Scraping images for class "fly poison"
# Multiprocessing workers: 8
# Scraping images for class "blue columbine"
# Multiprocessing workers: 8
# Scraping images for class "ewe"
# Multiprocessing workers: 8
# Scraping images for class "storage ring"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 2246.0 urls with 1756.0 successes
# 78.18343722172752% success rate for is_flickr urls
# 0.09394220977274867 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 2246.0 urls with 1756.0 successes
# 78.18343722172752% success rate for all urls
# 0.0939922100590682 seconds spent per all succesful image download
# Scraping images for class "dishtowel"
# Multiprocessing workers: 8
# Scraping images for class "racerunner"
# Multiprocessing workers: 8
# Scraping images for class "nightshade"
# Multiprocessing workers: 8
# Scraping images for class "urn"
# Multiprocessing workers: 8
# Scraping images for class "water horehound"
# Multiprocessing workers: 8
# Scraping images for class "ague root"
# Multiprocessing workers: 8
# Scraping images for class "basil"
# Multiprocessing workers: 8
# Scraping images for class "birdbath"
# Multiprocessing workers: 8
# Scraping images for class "pouch"
# Multiprocessing workers: 8
# Scraping images for class "Old World beaver"
# Multiprocessing workers: 8
# Scraping images for class "belted kingfisher"
# Multiprocessing workers: 8
# Scraping images for class "love-in-a-mist"
# Multiprocessing workers: 8
# Scraping images for class "scaling ladder"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 2492.0 urls with 1960.0 successes
# 78.65168539325843% success rate for is_flickr urls
# 0.09379145235431438 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 2492.0 urls with 1960.0 successes
# 78.65168539325843% success rate for all urls
# 0.09382398493435919 seconds spent per all succesful image download
# Scraping images for class "beast of burden"
# Multiprocessing workers: 8
# Scraping images for class "tube"
# Multiprocessing workers: 8
# Scraping images for class "strangler"
# Multiprocessing workers: 8
# Scraping images for class "smooth plane"
# Multiprocessing workers: 8
# Scraping images for class "dough"
# Multiprocessing workers: 8
# Scraping images for class "Scotch egg"
# Multiprocessing workers: 8
# Scraping images for class "cranberry bush"
# Multiprocessing workers: 8
# Scraping images for class "claret"
# Multiprocessing workers: 8
# Scraping images for class "velociraptor"
# Multiprocessing workers: 8
# Scraping images for class "bog rosemary"
# Multiprocessing workers: 8
# Scraping images for class "mammillaria"
# Multiprocessing workers: 8
# Scraping images for class "treadmill"
# Multiprocessing workers: 8
# Scraping images for class "wild oat"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 2748.0 urls with 2165.0 successes
# 78.78457059679766% success rate for is_flickr urls
# 0.0941939087442658 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 2748.0 urls with 2165.0 successes
# 78.78457059679766% success rate for all urls
# 0.09421995132129132 seconds spent per all succesful image download
# Scraping images for class "salamander"
# Multiprocessing workers: 8
# Scraping images for class "wraparound"
# Multiprocessing workers: 8
# Scraping images for class "school ship"
# Multiprocessing workers: 8
# Scraping images for class "elevator"
# Multiprocessing workers: 8
# Scraping images for class "vice chancellor"
# Multiprocessing workers: 8
# Scraping images for class "papaya"
# Multiprocessing workers: 8
# Scraping images for class "poplin"
# Multiprocessing workers: 8
# Scraping images for class "discussant"
# Multiprocessing workers: 8
# Scraping images for class "silver fern"
# Multiprocessing workers: 8
# Scraping images for class "man of letters"
# Multiprocessing workers: 8
# Scraping images for class "Russian almond"
# Multiprocessing workers: 8
# Scraping images for class "kangaroo"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 2992.0 urls with 2349.0 successes
# 78.50935828877006% success rate for is_flickr urls
# 0.09794022500032869 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 2992.0 urls with 2349.0 successes
# 78.50935828877006% success rate for all urls
# 0.09798351578531796 seconds spent per all succesful image download
# Scraping images for class "mechanical system"
# Multiprocessing workers: 8
# Scraping images for class "canvas"
# Multiprocessing workers: 8
# Scraping images for class "slipper"
# Multiprocessing workers: 8
# Scraping images for class "Muscadet"
# Multiprocessing workers: 8
# Scraping images for class "tachymeter"
# Multiprocessing workers: 8
# Scraping images for class "climbing fern"
# Multiprocessing workers: 8
# Scraping images for class "scrutineer"
# Multiprocessing workers: 8
# Scraping images for class "aioli"
# Multiprocessing workers: 8
# Scraping images for class "puppy"
# Multiprocessing workers: 8
# Scraping images for class "fudge"
# Multiprocessing workers: 8
# Scraping images for class "platform bed"
# Multiprocessing workers: 8
# Scraping images for class "computer scientist"
# Multiprocessing workers: 8
# Scraping images for class "seat"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 3244.0 urls with 2556.0 successes
# 78.79161528976572% success rate for is_flickr urls
# 0.09943059231380529 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 3244.0 urls with 2556.0 successes
# 78.79161528976572% success rate for all urls
# 0.09946641666415339 seconds spent per all succesful image download
# Scraping images for class "suckling"
# Multiprocessing workers: 8
# Scraping images for class "broad-leaved plantain"
# Multiprocessing workers: 8
# Scraping images for class "plant"
# Multiprocessing workers: 8
# Scraping images for class "electric meter"
# Multiprocessing workers: 8
# Scraping images for class "coriander"
# Multiprocessing workers: 8
# Scraping images for class "office furniture"
# Multiprocessing workers: 8
# Scraping images for class "sunflower seed"
# Multiprocessing workers: 8
# Scraping images for class "black bream"
# Multiprocessing workers: 8
# Scraping images for class "fisherman's lure"
# Multiprocessing workers: 8
# Scraping images for class "rudder"
# Multiprocessing workers: 8
# Scraping images for class "seaside daisy"
# Multiprocessing workers: 8
# Scraping images for class "cathode-ray tube"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 3495.0 urls with 2747.0 successes
# 78.59799713876967% success rate for is_flickr urls
#
# 0.09914814675118995 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successesSTATS For class all:
#  tried 3495.0 urls with 2747.0 successes
#
# 0.09917030266774625 seconds spent per all succesful image download
# 78.59799713876967% success rate for all urls Scraping images for class "bubble chamber"
# Multiprocessing workers: 8
# Scraping images for class "swamp birch"
# Multiprocessing workers: 8
# Scraping images for class "smart bomb"
# Multiprocessing workers: 8
# Scraping images for class "cigar box"
# Multiprocessing workers: 8
# Scraping images for class "motmot"
# Multiprocessing workers: 8
# Scraping images for class "ticking"
# Multiprocessing workers: 8
# Scraping images for class "pinesap"
# Multiprocessing workers: 8
# Scraping images for class "can"
# Multiprocessing workers: 8
# Scraping images for class "Kahlua"
# Multiprocessing workers: 8
# Scraping images for class "snowplow"
# Multiprocessing workers: 8
# Scraping images for class "dancing-master"
# Multiprocessing workers: 8
# Scraping images for class "inclinometer"
# Multiprocessing workers: 8
#
# Scraping stats:STATS For class is_flickr:
#
#  tried 3742.0 urls with 2949.0 successes
# 78.80812399786211% success rate for is_flickr urls
# 0.0991448364891655 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 3742.0 urls with 2949.0 successes
# 78.80812399786211% success rate for all urls
# 0.0991586939526154 seconds spent per all succesful image download
# Scraping images for class "lawman"
# Multiprocessing workers: 8
# Scraping images for class "raita"
# Multiprocessing workers: 8
# Scraping images for class "turbot"
# Multiprocessing workers: 8
# Scraping images for class "western grey squirrel"
# Multiprocessing workers: 8
# Scraping images for class "mimosa"
# Multiprocessing workers: 8
# Scraping images for class "fly orchid"
# Multiprocessing workers: 8
# Scraping images for class "wright"
# Multiprocessing workers: 8
# Scraping images for class "diapheromera"
# Multiprocessing workers: 8
# Scraping images for class "medusa"
# Multiprocessing workers: 8
# Scraping images for class "desk phone"
# Multiprocessing workers: 8
# Scraping images for class "zoysia"
# Multiprocessing workers: 8
# Scraping images for class "gear"
# Multiprocessing workers: 8
# Scraping images for class "Iceland moss"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 3995.0 urls with 3153.0 successes
# 78.92365456821027% success rate for is_flickr urls
# 0.0987031761517874 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 3995.0 urls with 3153.0 successes
# 78.92365456821027% success rate for all urls
# 0.09874204284154987 seconds spent per all succesful image download
# Scraping images for class "chicken yard"
# Multiprocessing workers: 8
# Scraping images for class "button pink"
# Multiprocessing workers: 8
# Scraping images for class "mountain skink"
# Multiprocessing workers: 8
# Scraping images for class "ethernet"
# Multiprocessing workers: 8
# Scraping images for class "ex-husband"
# Multiprocessing workers: 8
# Scraping images for class "reef squirrelfish"
# Multiprocessing workers: 8
# Scraping images for class "bandicoot"
# Multiprocessing workers: 8
# Scraping images for class "capelin"
# Multiprocessing workers: 8
# Scraping images for class "heart"
# Multiprocessing workers: 8
# Scraping images for class "organ loft"
# Multiprocessing workers: 8
# Scraping images for class "fallow deer"
# Multiprocessing workers: 8
# Scraping images for class "bomb"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 4242.0 urls with 3357.0 successes
# 79.13719943422913% success rate for is_flickr urls
# 0.09826975299163627 seconds spent per is_flickr succesful image download
#
# 0.09828170531201583 seconds spent per all succesful image download
# 79.13719943422913% success rate for all urls
#  tried 4242.0 urls with 3357.0 successes
# STATS For class all:
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successesScraping images for class "orange"
# Multiprocessing workers: 8
# Scraping images for class "holly fern"
# Multiprocessing workers: 8
# Scraping images for class "New World warbler"
# Multiprocessing workers: 8
# Scraping images for class "Pitot tube"
# Multiprocessing workers: 8
# Scraping images for class "ball carrier"
# Multiprocessing workers: 8
# Scraping images for class "bluetick"
# Multiprocessing workers: 8
# Scraping images for class "lamb"
# Multiprocessing workers: 8
# Scraping images for class "juniper berries"
# Multiprocessing workers: 8
# Scraping images for class "grand piano"
# Multiprocessing workers: 8
# Scraping images for class "two-toed sloth"
# Multiprocessing workers: 8
# Scraping images for class "nipple"
# Multiprocessing workers: 8
# Scraping images for class "gusher"
# Multiprocessing workers: 8
# Scraping images for class "allspice"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 4492.0 urls with 3555.0 successes
# 79.1406945681211% success rate for is_flickr urls
# 0.0984512304957909 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 4492.0 urls with 3555.0 successes
# 79.1406945681211% success rate for all urls
# 0.09847312416205427 seconds spent per all succesful image download
# Scraping images for class "cog"
# Multiprocessing workers: 8
# Scraping images for class "call forwarding"
# Multiprocessing workers: 8
# Scraping images for class "hop clover"
# Multiprocessing workers: 8
# Scraping images for class "hospital"
# Multiprocessing workers: 8
# Scraping images for class "bull snake"
# Multiprocessing workers: 8
# Scraping images for class "weapon"
# Multiprocessing workers: 8
# Scraping images for class "basket"
# Multiprocessing workers: 8
# Scraping images for class "sidecar"
# Multiprocessing workers: 8
# Scraping images for class "chair"
# Multiprocessing workers: 8
# Scraping images for class "demitasse"
# Multiprocessing workers: 8
# Scraping images for class "Mason jar"
# Multiprocessing workers: 8
# Scraping images for class "theosophist"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 4742.0 urls with 3746.0 successes
# 78.9962041332771% success rate for is_flickr urls
# 0.09834709004546256 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 4743.0 urls with 3746.0 successes
# 78.97954880877082% success rate for all urls
# 0.09836413391885182 seconds spent per all succesful image download
# Scraping images for class "Wedgwood"
# Multiprocessing workers: 8
# Scraping images for class "sewer"
# Multiprocessing workers: 8
# Scraping images for class "clamp"
# Multiprocessing workers: 8
# Scraping images for class "chapterhouse"
# Multiprocessing workers: 8
# Scraping images for class "polyphemus moth"
# Multiprocessing workers: 8
# Scraping images for class "trailing edge"
# Multiprocessing workers: 8
# Scraping images for class "fox"
# Multiprocessing workers: 8
# Scraping images for class "harrier"
# Multiprocessing workers: 8
# Scraping images for class "one-flowered wintergreen"
# Multiprocessing workers: 8
# Scraping images for class "windfall"
# Multiprocessing workers: 8
# Scraping images for class "car"
# Multiprocessing workers: 8
# Scraping images for class "musteline mammal"
# Multiprocessing workers: 8
# Scraping images for class "Atlantic halibut"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 4994.0 urls with 3953.0 successes
# 79.15498598317981% success rate for is_flickr urls
# 0.0983900920728958 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 4994.0 urls with 3953.0 successes
# 79.15498598317981% success rate for all urls
# 0.09841908281916399 seconds spent per all succesful image download
# Scraping images for class "cannon"
# Multiprocessing workers: 8
# Scraping images for class "Oregon white oak"
# Multiprocessing workers: 8
# Scraping images for class "sheik"
# Multiprocessing workers: 8
# Scraping images for class "easy chair"
# Multiprocessing workers: 8
# Scraping images for class "common comfrey"
# Multiprocessing workers: 8
# Scraping images for class "European hornbeam"
# Multiprocessing workers: 8
# Scraping images for class "young mammal"
# Multiprocessing workers: 8
# Scraping images for class "shiitake"
# Multiprocessing workers: 8
# Scraping images for class "wax palm"
# Multiprocessing workers: 8
# Scraping images for class "orange sneezeweed"
# Multiprocessing workers: 8
# Scraping images for class "grapnel"
# Multiprocessing workers: 8
# Scraping images for class "guppy"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 5242.0 urls with 4138.0 successes
# 78.93933613124761% success rate for is_flickr urls
# 0.09876176877664794 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 5242.0 urls with 4138.0 successes
# 78.93933613124761% success rate for all urls
# 0.09877610091370279 seconds spent per all succesful image download
# Scraping images for class "platen"
# Multiprocessing workers: 8
# Scraping images for class "guy"
# Multiprocessing workers: 8
# Scraping images for class "mountain lily"
# Multiprocessing workers: 8
# Scraping images for class "blacktip shark"
# Multiprocessing workers: 8
# Scraping images for class "cardoon"
# Multiprocessing workers: 8
# Scraping images for class "roper"
# Multiprocessing workers: 8
# Scraping images for class "thermal printer"
# Multiprocessing workers: 8
# Scraping images for class "flower girl"
# Multiprocessing workers: 8
# Scraping images for class "Aryan"
# Multiprocessing workers: 8
# Scraping images for class "candied fruit"
# Multiprocessing workers: 8
# Scraping images for class "black bread"
# Multiprocessing workers: 8
# Scraping images for class "Beaujolais"
# Multiprocessing workers: 8
# Scraping images for class "freshwater mussel"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 5496.0 urls with 4339.0 successes
# 78.94832605531296% success rate for is_flickr urls
# 0.09912300049420682 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 5496.0 urls with 4339.0 successes
# 78.94832605531296% success rate for all urls
# 0.0991450579766992 seconds spent per all succesful image download
# Scraping images for class "saurischian"
# Multiprocessing workers: 8
# Scraping images for class "safety arch"
# Multiprocessing workers: 8
# Scraping images for class "green snake"
# Multiprocessing workers: 8
# Scraping images for class "bottle green"
# Multiprocessing workers: 8
# Scraping images for class "menorah"
# Multiprocessing workers: 8
# Scraping images for class "macadamia"
# Multiprocessing workers: 8
# Scraping images for class "substitute"
# Multiprocessing workers: 8
# Scraping images for class "chantry"
# Multiprocessing workers: 8
# Scraping images for class "huckster"
# Multiprocessing workers: 8
# Scraping images for class "earthstar"
# Multiprocessing workers: 8
# Scraping images for class "gander"
# Multiprocessing workers: 8
# Scraping images for class "aposematic coloration"
# Multiprocessing workers: 8
# Scraping images for class "antelope"
# Multiprocessing workers: 8
#
# Scraping stats: tried 5742.0 urls with 4538.0 successes
# STATS For class is_flickr:
#
# 79.03169627307558% success rate for is_flickr urls
# 0.0989342009564127 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 5742.0 urls with 4538.0 successes
# 79.03169627307558% success rate for all urls
# 0.0989385063083963 seconds spent per all succesful image download
# Scraping images for class "great yellow gentian"
# Multiprocessing workers: 8
# Scraping images for class "head cabbage"
# Multiprocessing workers: 8
# Scraping images for class "citrus"
# Multiprocessing workers: 8
# Scraping images for class "enemy"
# Multiprocessing workers: 8
# Scraping images for class "West Indian jasmine"
# Multiprocessing workers: 8
# Scraping images for class "gas engine"
# Multiprocessing workers: 8
# Scraping images for class "copper"
# Multiprocessing workers: 8
# Scraping images for class "suit"
# Multiprocessing workers: 8
# Scraping images for class "truncated pyramid"
# Multiprocessing workers: 8
# Scraping images for class "pallone"
# Multiprocessing workers: 8
# Scraping images for class "rosita"
# Multiprocessing workers: 8
# Scraping images for class "postern"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 5992.0 urls with 4728.0 successes
# 78.90520694259013% success rate for is_flickr urls
# 0.10102770524178262 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 5992.0 urls with 4728.0 successes
# 78.90520694259013% success rate for all urls
# 0.1010421846320383 seconds spent per all succesful image download
# Scraping images for class "incumbent"
# Multiprocessing workers: 8
# Scraping images for class "streptocarpus"
# Multiprocessing workers: 8
# Scraping images for class "marriage bed"
# Multiprocessing workers: 8
# Scraping images for class "walrus mustache"
# Multiprocessing workers: 8
# Scraping images for class "settler"
# Multiprocessing workers: 8
# Scraping images for class "slice bar"
# Multiprocessing workers: 8
# Scraping images for class "Chilean cedar"
# Multiprocessing workers: 8
# Scraping images for class "bather"
# Multiprocessing workers: 8
# Scraping images for class "lawgiver"
# Multiprocessing workers: 8
# Scraping images for class "sowbane"
# Multiprocessing workers: 8
# Scraping images for class "matting"
# Multiprocessing workers: 8
# Scraping images for class "kaoliang"
# Multiprocessing workers: 8
# Scraping images for class "shrew"
# Multiprocessing workers: 8
# Scraping images for class "flickertail"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 6247.0 urls with 4945.0 successes
# 79.15799583800224% success rate for is_flickr urls
# 0.10182051041490268 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 6247.0 urls with 4945.0 successes
# 79.15799583800224% success rate for all urls
# 0.10183782003767208 seconds spent per all succesful image download
# Scraping images for class "dresser"
# Multiprocessing workers: 8
# Scraping images for class "cherry"
# Multiprocessing workers: 8
# Scraping images for class "laurel oak"
# Multiprocessing workers: 8
# Scraping images for class "brake disk"
# Multiprocessing workers: 8
# Scraping images for class "joinery"
# Multiprocessing workers: 8
# Scraping images for class "sac fungus"
# Multiprocessing workers: 8
# Scraping images for class "leaf lettuce"
# Multiprocessing workers: 8
# Scraping images for class "blue tit"
# Multiprocessing workers: 8
# Scraping images for class "Dictaphone"
# Multiprocessing workers: 8
# Scraping images for class "ordinary"
# Multiprocessing workers: 8
# Scraping images for class "Tibetan terrier"
# Multiprocessing workers: 8
# Scraping images for class "telephone bell"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 6498.0 urls with 5141.0 successes
# 79.1166512773161% success rate for is_flickr urls
# 0.10149599925666161 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 6498.0 urls with 5141.0 successes
# 79.1166512773161% success rate for all urls
# 0.10150720896458398 seconds spent per all succesful image download
# Scraping images for class "radish"
# Multiprocessing workers: 8
# Scraping images for class "yardie"
# Multiprocessing workers: 8
# Scraping images for class "athletic supporter"
# Multiprocessing workers: 8
# Scraping images for class "loquat"
# Multiprocessing workers: 8
# Scraping images for class "by-catch"
# Multiprocessing workers: 8
# Scraping images for class "terrine"
# Multiprocessing workers: 8
# Scraping images for class "alexic"
# Multiprocessing workers: 8
# Scraping images for class "Allen wrench"
# Multiprocessing workers: 8
# Scraping images for class "sweeper"
# Multiprocessing workers: 8
# Scraping images for class "actinia"
# Multiprocessing workers: 8
# Scraping images for class "sportswear"
# Multiprocessing workers: 8
# Scraping images for class "Brazilian trumpeter"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 6742.0 urls with 5340.0 successes
# 79.20498368436665% success rate for is_flickr urls
# 0.10113945449336191 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 6742.0 urls with 5340.0 successes
# 79.19323743141035% success rate for all urls
# 0.10115716032355053 seconds spent per all succesful image download
# Scraping images for class "lubber's hole"
# Multiprocessing workers: 8
# Scraping images for class "bowling shoe"
# Multiprocessing workers: 8
# Scraping images for class "parrot"
# Multiprocessing workers: 8
# Scraping images for class "lupine"
# Multiprocessing workers: 8
# Scraping images for class "field mustard"
# Multiprocessing workers: 8
# Scraping images for class "cardcase"
# Multiprocessing workers: 8
# Scraping images for class "forceps"
# Multiprocessing workers: 8
# Scraping images for class "snail"
# Multiprocessing workers: 8
# Scraping images for class "spun yarn"
# Multiprocessing workers: 8
# Scraping images for class "espadrille"
# Multiprocessing workers: 8
# Scraping images for class "greenfly"
# Multiprocessing workers: 8
# Scraping images for class "jaunting car"
# Multiprocessing workers: 8
# Scraping images for class "glume"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 6992.0 urls with 5539.0 successes
# 79.21910755148741% success rate for is_flickr urls
# 0.10263521151758742 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 6992.0 urls with 5539.0 successes
# 79.21910755148741% success rate for all urls
# 0.10264036177211472 seconds spent per all succesful image download
# Scraping images for class "rock hind"
# Multiprocessing workers: 8
# Scraping images for class "bamboo fern"
# Multiprocessing workers: 8
# Scraping images for class "field soybean"
# Multiprocessing workers: 8
# Scraping images for class "Cape tulip"
# Multiprocessing workers: 8
# Scraping images for class "water moccasin"
# Multiprocessing workers: 8
# Scraping images for class "baluster"
# Multiprocessing workers: 8
# Scraping images for class "high tea"
# Multiprocessing workers: 8
# Scraping images for class "Winchester"
# Multiprocessing workers: 8
# Scraping images for class "pooch"
# Multiprocessing workers: 8
# Scraping images for class "cheese fondue"
# Multiprocessing workers: 8
# Scraping images for class "Brie"
# Multiprocessing workers: 8
# Scraping images for class "barking frog"
# Multiprocessing workers: 8
# Scraping images for class "barrel"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 7242.0 urls with 5751.0 successes
# 79.41176470588235% success rate for is_flickr urls
# 0.10514336187017417 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 7242.0 urls with 5751.0 successes
# 79.41176470588235% success rate for all urls
# 0.10515339841761395 seconds spent per all succesful image download
# Scraping images for class "osier"
# Multiprocessing workers: 8
# Scraping images for class "Bofors gun"
# Multiprocessing workers: 8
# Scraping images for class "mousetrap"
# Multiprocessing workers: 8
# Scraping images for class "yellow avens"
# Multiprocessing workers: 8
# Scraping images for class "pulley"
# Multiprocessing workers: 8
# Scraping images for class "piccalilli"
# Multiprocessing workers: 8
# Scraping images for class "porcupinefish"
# Multiprocessing workers: 8
# Scraping images for class "bok choy"
# Multiprocessing workers: 8
# Scraping images for class "Bulgarian"
# Multiprocessing workers: 8
# Scraping images for class "lovebird"
# Multiprocessing workers: 8
# Scraping images for class "goldthread"
# Multiprocessing workers: 8
# Scraping images for class "cacique"
# Multiprocessing workers: 8
# Scraping images for class "surfbird"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 7492.0 urls with 5952.0 successes
# 79.4447410571276% success rate for is_flickr urls
# 0.1052931746648204 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 7492.0 urls with 5952.0 successes
# 79.4447410571276% success rate for all urls
# 0.10529721095677345 seconds spent per all succesful image download
# Scraping images for class "in-basket"
# Multiprocessing workers: 8
# Scraping images for class "springer spaniel"
# Multiprocessing workers: 8
# Scraping images for class "spark plug"
# Multiprocessing workers: 8
# Scraping images for class "fuller's teasel"
# Multiprocessing workers: 8
# Scraping images for class "tablespoon"
# Multiprocessing workers: 8
# Scraping images for class "Eastern hop hornbeam"
# Multiprocessing workers: 8
# Scraping images for class "draftsman"
# Multiprocessing workers: 8
# Scraping images for class "fairground"
# Multiprocessing workers: 8
# Scraping images for class "king crab"
# Multiprocessing workers: 8
# Scraping images for class "sprig"
# Multiprocessing workers: 8
# Scraping images for class "wineberry"
# Multiprocessing workers: 8
# Scraping images for class "single-breasted jacket"
# Multiprocessing workers: 8
# Scraping images for class "conserve"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 7743.0 urls with 6162.0 successes
# 79.58155753583883% success rate for is_flickr urls
# 0.10490223410376401 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 7743.0 urls with 6162.0 successes
# 79.58155753583883% success rate for all urls
# 0.10492416207413517 seconds spent per all succesful image download
# Scraping images for class "codling"
# Multiprocessing workers: 8
# Scraping images for class "viola"
# Multiprocessing workers: 8
# Scraping images for class "power steering"
# Multiprocessing workers: 8
# Scraping images for class "butcher shop"
# Multiprocessing workers: 8
# Scraping images for class "ivory palm"
# Multiprocessing workers: 8
# Scraping images for class "sea raven"
# Multiprocessing workers: 8
# Scraping images for class "pew"
# Multiprocessing workers: 8
# Scraping images for class "light cream"
# Multiprocessing workers: 8
# Scraping images for class "Mohican"
# Multiprocessing workers: 8
# Scraping images for class "C-clamp"
# Multiprocessing workers: 8
# Scraping images for class "digital clock"
# Multiprocessing workers: 8
# Scraping images for class "umbel"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 7992.0 urls with 6356.0 successes
# 79.52952952952953% success rate for is_flickr urls
# 0.1046924421140576 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 7992.0 urls with 6356.0 successes
# 79.52952952952953% success rate for all urls
# 0.10469778383805964 seconds spent per all succesful image download
# Scraping images for class "safety belt"
# Multiprocessing workers: 8
# Scraping images for class "homegirl"
# Multiprocessing workers: 8
# Scraping images for class "crow pheasant"
# Multiprocessing workers: 8
# Scraping images for class "Welsh terrier"
# Multiprocessing workers: 8
# Scraping images for class "milking stool"
# Multiprocessing workers: 8
# Scraping images for class "fighting chair"
# Multiprocessing workers: 8
# Scraping images for class "common shrew"
# Multiprocessing workers: 8
# Scraping images for class "professional wrestling"
# Multiprocessing workers: 8
# Scraping images for class "knob"
# Multiprocessing workers: 8
# Scraping images for class "steed"
# Multiprocessing workers: 8
# Scraping images for class "storage medium"
# Multiprocessing workers: 8
# Scraping images for class "bittersweet"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 8242.0 urls with 6546.0 successes
# 79.4224702742053% success rate for is_flickr urls
# 0.10583399568097948 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 8242.0 urls with 6546.0 successes
# 79.4224702742053% success rate for all urls
# 0.10584282230391183 seconds spent per all succesful image download
# Scraping images for class "carriage"
# Multiprocessing workers: 8
# Scraping images for class "figwort"
# Multiprocessing workers: 8
# Scraping images for class "hunk"
# Multiprocessing workers: 8
# Scraping images for class "plug"
# Multiprocessing workers: 8
# Scraping images for class "breechcloth"
# Multiprocessing workers: 8
# Scraping images for class "broadsword"
# Multiprocessing workers: 8
# Scraping images for class "tody"
# Multiprocessing workers: 8
# Scraping images for class "court"
# Multiprocessing workers: 8
# Scraping images for class "corner"
# Multiprocessing workers: 8
# Scraping images for class "wrestling"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 8492.0 urls with 6707.0 successes
# 78.9802166745172% success rate for is_flickr urls
# 0.10622197319395908 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 8493.0 urls with 6707.0 successes
# 78.97091722595079% success rate for all urls
# 0.10623267625791938 seconds spent per all succesful image download
# Scraping images for class "Victoria plum"
# Multiprocessing workers: 8
# Scraping images for class "sea milkwort"
# Multiprocessing workers: 8
# Scraping images for class "nebuchadnezzar"
# Multiprocessing workers: 8
# Scraping images for class "Gothic arch"
# Multiprocessing workers: 8
# Scraping images for class "jibboom"
# Multiprocessing workers: 8
# Scraping images for class "fanaloka"
# Multiprocessing workers: 8
# Scraping images for class "enamelware"
# Multiprocessing workers: 8
# Scraping images for class "heartbreaker"
# Multiprocessing workers: 8
# Scraping images for class "political prisoner"
# Multiprocessing workers: 8
# Scraping images for class "sickle cell"
# Multiprocessing workers: 8
# Scraping images for class "bird pepper"
# Multiprocessing workers: 8
# Scraping images for class "German short-haired pointer"
# Multiprocessing workers: 8
# Scraping images for class "orange tortrix"
# ...
# STATS For class is_flickr:
#  tried 16993.0 urls with 13417.0 successes
# 78.9560407226505% success rate for is_flickr urls
# 0.10202090225054822 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 16993.0 urls with 13417.0 successes
# 78.9560407226505% success rate for all urls
# 0.10202634534475442 seconds spent per all succesful image download
# Scraping images for class "tennis"
# Multiprocessing workers: 8
# Scraping images for class "yew"
# Multiprocessing workers: 8
# Scraping images for class "bird of prey"
# Multiprocessing workers: 8
# Scraping images for class "silver sage"
# Multiprocessing workers: 8
# Scraping images for class "common starling"
# Multiprocessing workers: 8
# Scraping images for class "khadi"
# Multiprocessing workers: 8
# Scraping images for class "holster"
# Multiprocessing workers: 8
# Scraping images for class "coiffeur"
# Multiprocessing workers: 8
# Scraping images for class "peach"
# Multiprocessing workers: 8
# Scraping images for class "globeflower"
# Multiprocessing workers: 8
# Scraping images for class "bunk bed"
# Multiprocessing workers: 8
# Scraping images for class "golden pheasant"
# Multiprocessing workers: 8
#
# Scraping stats:
#
# STATS For class is_flickr:
#  tried 17242.0 urls with 13619.0 successes78.98735645516761% success rate for is_flickr urls
# 0.10192881735842241 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 17242.0 urls with 13619.0 successes
# 78.98735645516761% success rate for all urls
# 0.10193154956986528 seconds spent per all succesful image download
# Scraping images for class "paper feed"
# Multiprocessing workers: 8
# Scraping images for class "nut butter"
# Multiprocessing workers: 8
# Scraping images for class "gendarme"
# Multiprocessing workers: 8
# Scraping images for class "gondolier"
# Multiprocessing workers: 8
# Scraping images for class "sea squill"
# Multiprocessing workers: 8
# Scraping images for class "mosquitofish"
# Multiprocessing workers: 8
# Scraping images for class "plum pudding"
# Multiprocessing workers: 8
# Scraping images for class "diode"
# Multiprocessing workers: 8
# Scraping images for class "slip-on"
# Multiprocessing workers: 8
# Scraping images for class "wimple"
# Multiprocessing workers: 8
# Scraping images for class "pup"
# Multiprocessing workers: 8
# Scraping images for class "schooner"
# Multiprocessing workers: 8
# Scraping images for class "blast furnace"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 17498.0 urls with 13825.0 successes
# 79.00902960338324% success rate for is_flickr urls
# 0.10181407471461926 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 17498.0 urls with 13825.0 successes
# 79.00902960338324% success rate for all urls
# 0.10182195811763163 seconds spent per all succesful image download
# Scraping images for class "parfait glass"
# Multiprocessing workers: 8
# Scraping images for class "coelogyne"
# Multiprocessing workers: 8
# Scraping images for class "reel"
# Multiprocessing workers: 8
# Scraping images for class "potato salad"
# Multiprocessing workers: 8
# Scraping images for class "Namibian"
# Multiprocessing workers: 8
# Scraping images for class "dip"
# Multiprocessing workers: 8
# Scraping images for class "piece de resistance"
# Multiprocessing workers: 8
# Scraping images for class "matelote"
# Multiprocessing workers: 8
# Scraping images for class "outrigger canoe"
# Multiprocessing workers: 8
# Scraping images for class "vanilla orchid"
# Multiprocessing workers: 8
# Scraping images for class "maypole"
# Multiprocessing workers: 8
# Scraping images for class "flophouse"
# Multiprocessing workers: 8
# Scraping images for class "caveman"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 17745.0 urls with 14040.0 successes
# 79.12087912087912% success rate for is_flickr urls
# 0.10168617537558249 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 17745.0 urls with 14040.0 successes
# 79.12087912087912% success rate for all urls
# 0.10169188307221459 seconds spent per all succesful image download
# Scraping images for class "blue-eyed African daisy"
# Multiprocessing workers: 8
# Scraping images for class "rapeseed"
# Multiprocessing workers: 8
# Scraping images for class "junior"
# Multiprocessing workers: 8
# Scraping images for class "spaghetti and meatballs"
# Multiprocessing workers: 8
# Scraping images for class "delegate"
# Multiprocessing workers: 8
# Scraping images for class "megaphone"
# Multiprocessing workers: 8
# Scraping images for class "Orangeman"
# Multiprocessing workers: 8
# Scraping images for class "slot machine"
# Multiprocessing workers: 8
# Scraping images for class "winter heliotrope"
# Multiprocessing workers: 8
# Scraping images for class "wasp"
# Multiprocessing workers: 8
# Scraping images for class "Bewick's swan"
# Multiprocessing workers: 8
# Scraping images for class "dreadnought"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 17996.0 urls with 14229.0 successes
# 79.06757057123805% success rate for is_flickr urls
# 0.1016076467672079 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 17996.0 urls with 14229.0 successes
# 79.06757057123805% success rate for all urls
# 0.10161335510684463 seconds spent per all succesful image download
# Scraping images for class "damselfish"
# Multiprocessing workers: 8
# Scraping images for class "bull"
# Multiprocessing workers: 8
# Scraping images for class "giant taro"
# Multiprocessing workers: 8
# Scraping images for class "portal site"
# Multiprocessing workers: 8
# Scraping images for class "walleye"
# Multiprocessing workers: 8
# Scraping images for class "jaguarundi"
# Multiprocessing workers: 8
# Scraping images for class "balloon"
# Multiprocessing workers: 8
# Scraping images for class "creche"
# Multiprocessing workers: 8
# Scraping images for class "anthropoid"
# Multiprocessing workers: 8
# Scraping images for class "candy"
# Multiprocessing workers: 8
# Scraping images for class "lacquerware"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 18242.0 urls with 14412.0 successes
# 79.00016444663707% success rate for is_flickr urls
# 0.10157553869173919 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 18243.0 urls with 14412.0 successes
# 79.00016444663707% success rate for all urls
# 0.10157845401115428 seconds spent per all succesful image download
# Scraping images for class "cowpen daisy"
# Multiprocessing workers: 8
# Scraping images for class "Homo erectus"
# Multiprocessing workers: 8
# Scraping images for class "hypocrite"
# Multiprocessing workers: 8
# Scraping images for class "flannel"
# Multiprocessing workers: 8
# Scraping images for class "steam bath"
# Multiprocessing workers: 8
# Scraping images for class "nephew"
# Multiprocessing workers: 8
# Scraping images for class "slop basin"
# Multiprocessing workers: 8
# Scraping images for class "casaba"
# Multiprocessing workers: 8
# Scraping images for class "saskatoon"
# Multiprocessing workers: 8
# Scraping images for class "swamp azalea"
# Multiprocessing workers: 8
# Scraping images for class "jilt"
# Multiprocessing workers: 8
# Scraping images for class "kaiser roll"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 18492.0 urls with 14603.0 successes
# 78.96928401470906% success rate for is_flickr urls
# 0.10151276016679438 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 18492.0 urls with 14603.0 successes
# 78.96928401470906% success rate for all urls
# 0.10151820568763123 seconds spent per all succesful image download
# Scraping images for class "drey"
# Multiprocessing workers: 8
# Scraping images for class "bling"
# Multiprocessing workers: 8
# Scraping images for class "creche"
# Multiprocessing workers: 8
# Scraping images for class "Chief Secretary"
# Multiprocessing workers: 8
# Scraping images for class "ballot box"
# Multiprocessing workers: 8
# Scraping images for class "native speaker"
# Multiprocessing workers: 8
# Scraping images for class "marmoset"
# Multiprocessing workers: 8
# Scraping images for class "currawong"
# Multiprocessing workers: 8
# Scraping images for class "arame"
# Multiprocessing workers: 8
# Scraping images for class "blueweed"
# Multiprocessing workers: 8
# Scraping images for class "wood horsetail"
# Multiprocessing workers: 8
# Scraping images for class "black huckleberry"
# Multiprocessing workers: 8
# Scraping images for class "freckle"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 18742.0 urls with 14799.0 successes
# 78.96169032120372% success rate for is_flickr urls 0.10154015248317526 seconds spent per is_flickr succesful image download
#
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 18742.0 urls with 14799.0 successes
# 78.96169032120372% success rate for all urls
# 0.10154395585479313 seconds spent per all succesful image download
# Scraping images for class "vitamin B2"
# Multiprocessing workers: 8
# Scraping images for class "sheep plant"
# Multiprocessing workers: 8
# Scraping images for class "corn chamomile"
# Multiprocessing workers: 8
# Scraping images for class "fountain pen"
# Multiprocessing workers: 8
# Scraping images for class "buckskin"
# Multiprocessing workers: 8
# Scraping images for class "governor's plum"
# Multiprocessing workers: 8
# Scraping images for class "wok"
# Multiprocessing workers: 8
# Scraping images for class "organ pipe"
# Multiprocessing workers: 8
# Scraping images for class "Doppler radar"
# Multiprocessing workers: 8
# Scraping images for class "industry analyst"
# Multiprocessing workers: 8
# Scraping images for class "Arnica montana"
# Multiprocessing workers: 8
# Scraping images for class "home fries"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 18992.0 urls with 14994.0 successes
# 78.94903117101937% success rate for is_flickr urls
# 0.1014864205105616 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 18992.0 urls with 14994.0 successes
# 78.94903117101937% success rate for all urls
# 0.10148988128487581 seconds spent per all succesful image download
# Scraping images for class "microfiche"
# Multiprocessing workers: 8
# Scraping images for class "poisonous parasol"
# Multiprocessing workers: 8
# Scraping images for class "chickeree"
# Multiprocessing workers: 8
# Scraping images for class "reader"
# Multiprocessing workers: 8
# Scraping images for class "water tower"
# Multiprocessing workers: 8
# Scraping images for class "bagel"
# Multiprocessing workers: 8
# Scraping images for class "marchand de vin"
# Multiprocessing workers: 8
# Scraping images for class "garboard"
# Multiprocessing workers: 8
# Scraping images for class "tuna fish salad"
# Multiprocessing workers: 8
# Scraping images for class "Dewar flask"
# Multiprocessing workers: 8
# Scraping images for class "five-spot"
# Multiprocessing workers: 8
# Scraping images for class "amusement park"
# Multiprocessing workers: 8
# Scraping images for class "Yavapai"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 19242.0 urls with 15193.0 successes78.9574888265253% success rate for is_flickr urls
#
# 0.10146125157151065 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 19242.0 urls with 15193.0 successes
# 78.9574888265253% success rate for all urls
# 0.10146634939479081 seconds spent per all succesful image download
# Scraping images for class "brickwork"
# Multiprocessing workers: 8
# Scraping images for class "tactician"
# Multiprocessing workers: 8
# Scraping images for class "saurian"
# Multiprocessing workers: 8
# Scraping images for class "doorplate"
# Multiprocessing workers: 8
# Scraping images for class "Green Beret"
# Multiprocessing workers: 8
# Scraping images for class "wild sheep"
# Multiprocessing workers: 8
# Scraping images for class "bear cub"
# Multiprocessing workers: 8
# Scraping images for class "grappa"
# Multiprocessing workers: 8
# Scraping images for class "weathervane"
# Multiprocessing workers: 8
# Scraping images for class "promontory"
# Multiprocessing workers: 8
# Scraping images for class "jacket"
# Multiprocessing workers: 8
# Scraping images for class "pilot burner"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 19494.0 urls with 15390.0 successes
# 78.94736842105263% success rate for is_flickr urls
# 0.10147755384600109 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 19494.0 urls with 15390.0 successes
# 78.94736842105263% success rate for all urls
# 0.10147917468955255 seconds spent per all succesful image download
# Scraping images for class "mason"
# Multiprocessing workers: 8
# Scraping images for class "water strider"
# Multiprocessing workers: 8
# Scraping images for class "morello"
# Multiprocessing workers: 8
# Scraping images for class "cat fancier"
# Multiprocessing workers: 8
# Scraping images for class "marsh horsetail"
# Multiprocessing workers: 8
# Scraping images for class "nut pine"
# Multiprocessing workers: 8
# Scraping images for class "blacktail jackrabbit"
# Multiprocessing workers: 8
# Scraping images for class "wort"
# Multiprocessing workers: 8
# Scraping images for class "menu"
# Multiprocessing workers: 8
# Scraping images for class "bolognese pasta sauce"
# Multiprocessing workers: 8
# Scraping images for class "in-law"
# Multiprocessing workers: 8
# Scraping images for class "coral fungus"
# Multiprocessing workers: 8
# Scraping images for class "daily"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 19742.0 urls with 15591.0 successes
# 78.97376152365516% success rate for is_flickr urls
# 0.10153274028130427 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 19745.0 urls with 15591.0 successes
# 78.96176247151178% success rate for all urls
# 0.10154627612119586 seconds spent per all succesful image download
# Scraping images for class "yogi"
# Multiprocessing workers: 8
# Scraping images for class "ratepayer"
# Multiprocessing workers: 8
# Scraping images for class "queen"
# Multiprocessing workers: 8
# Scraping images for class "anchovy sauce"
# Multiprocessing workers: 8
# Scraping images for class "tribute album"
# Multiprocessing workers: 8
# Scraping images for class "storm cellar"
# Multiprocessing workers: 8
# Scraping images for class "banana"
# Multiprocessing workers: 8
# Scraping images for class "sparkling wine"
# Multiprocessing workers: 8
# Scraping images for class "tarragon"
# Multiprocessing workers: 8
# Scraping images for class "long sleeve"
# Multiprocessing workers: 8
# Scraping images for class "window frame"
# Multiprocessing workers: 8
# Scraping images for class "tree wallaby"
# Multiprocessing workers: 8
#
# Scraping stats:
# STATS For class is_flickr:
#  tried 19992.0 urls with 15795.0 successes
# 79.00660264105642% success rate for is_flickr urls
# 0.10145463229508746 seconds spent per is_flickr succesful image download
# STATS For class not_flickr:
#  tried 0.0 urls with 0.0 successes
# STATS For class all:
#  tried 19992.0 urls with 15795.0 successes
# 79.00660264105642% success rate for all urls
# 0.10145720306473768 seconds spent per all succesful image download
# Scraping images for class "crested wheatgrass"
# Multiprocessing workers: 8
# Scraping images for class "magpie"
# Multiprocessing workers: 8
# Scraping images for class "testudo"
# Multiprocessing workers: 8
# Scraping images for class "bottle gourd"
# Multiprocessing workers: 8
# Scraping images for class "acetate disk"
# Multiprocessing workers: 8
# Scraping images for class "black morel"
# Multiprocessing workers: 8

# %% [markdown]
# # Download only Validation Set

# %%
# !wget https://image-net.org/data/ILSVRC/2012/ILSVRC2012_img_val.tar
# ILSVRC2012_val_00002378.JPEG
# ILSVRC2012_val_00001035.JPEG
# ILSVRC2012_val_00000923.JPEG
# ILSVRC2012_val_00049968.JPEG
# ILSVRC2012_val_00049337.JPEG
# ILSVRC2012_val_00047759.JPEG
# ILSVRC2012_val_00047307.JPEG
# ILSVRC2012_val_00046684.JPEG
# ILSVRC2012_val_00043846.JPEG
# ILSVRC2012_val_00043314.JPEG
# ILSVRC2012_val_00043156.JPEG
# ILSVRC2012_val_00042537.JPEG
# ILSVRC2012_val_00041682.JPEG
# ILSVRC2012_val_00040681.JPEG
# ILSVRC2012_val_00040311.JPEG
# ILSVRC2012_val_00039917.JPEG
# ILSVRC2012_val_00038045.JPEG
# ILSVRC2012_val_00036677.JPEG
# ILSVRC2012_val_00035442.JPEG
# ILSVRC2012_val_00034564.JPEG
# ILSVRC2012_val_00033924.JPEG
# ILSVRC2012_val_00033735.JPEG
# ILSVRC2012_val_00032115.JPEG
# ILSVRC2012_val_00029316.JPEG
# ILSVRC2012_val_00027984.JPEG
# ILSVRC2012_val_00027010.JPEG
# ILSVRC2012_val_00026602.JPEG
# ILSVRC2012_val_00026020.JPEG
# ILSVRC2012_val_00024127.JPEG
# ILSVRC2012_val_00022546.JPEG
# ILSVRC2012_val_00021402.JPEG
# ILSVRC2012_val_00018850.JPEG
# ILSVRC2012_val_00017484.JPEG
# ILSVRC2012_val_00017031.JPEG
# ILSVRC2012_val_00015846.JPEG
# ILSVRC2012_val_00015765.JPEG
# ILSVRC2012_val_00015105.JPEG
# ILSVRC2012_val_00012719.JPEG
# ILSVRC2012_val_00012244.JPEG
# ILSVRC2012_val_00009116.JPEG
# ILSVRC2012_val_00007660.JPEG
# ILSVRC2012_val_00007603.JPEG
# ILSVRC2012_val_00006963.JPEG
# ILSVRC2012_val_00006390.JPEG
# ILSVRC2012_val_00006204.JPEG
# ILSVRC2012_val_00005990.JPEG
# ILSVRC2012_val_00005659.JPEG
# ILSVRC2012_val_00004890.JPEG
# ILSVRC2012_val_00004220.JPEG
# ILSVRC2012_val_00003883.JPEG
# ILSVRC2012_val_00003515.JPEG
# ILSVRC2012_val_00002155.JPEG
# ILSVRC2012_val_00000854.JPEG

# %%
# !ls ILSVRC2012_img_val | wc -l
# Out:
# 50000

# %%
! wget https://image-net.org/data/ILSVRC/2012/ILSVRC2012_bbox_val_v3.tgz
# Out:
# --2022-10-05 18:17:55--  https://image-net.org/data/ILSVRC/2012/ILSVRC2012_bbox_val_v3.tgz
# Resolving image-net.org (image-net.org)... 171.64.68.16
# Connecting to image-net.org (image-net.org)|171.64.68.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2221290 (2.1M) [application/x-gzip]
# Saving to: ‘ILSVRC2012_bbox_val_v3.tgz’
#
# ILSVRC2012_bbox_val 100%[===================>]   2.12M  --.-KB/s    in 0.1s
#
# 2022-10-05 18:17:55 (16.7 MB/s) - ‘ILSVRC2012_bbox_val_v3.tgz’ saved [2221290/2221290]

# %%
# !ls
# Out:
# classes_in_imagenet.csv     ILSVRC2012_img_val.tar    README.md
# downloader.py		    imagenet		      requirements.txt
# ILSVRC2012_bbox_val_v3.tgz  imagenet_class_info.json  words.txt
# ILSVRC2012_img_val	    prepare_stats.py
