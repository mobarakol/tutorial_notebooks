# %% [markdown]
# <a href="https://colab.research.google.com/github/mobarakol/tutorial_notebooks/blob/main/endovis18_coco_yolov8_valid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #YoloV8:Surgical Instrument Detection
# src:https://github.com/Andrewhsin/YOLO-NAS-pytorch

# %% [markdown]
# #Download Endovis18 dataset

# %%
import gdown

#endovis18 dataset
url = 'https://drive.google.com/uc?id=1lRNAgC-6QgIQd-vum-jr523tYPr6yNM7'
gdown.download(url,'endovis18.zip',quiet=True) 
# !unzip -q endovis18.zip

# %% [markdown]
# #Converting endovis18 to COCO format and folder structure<br>
# datatset-><br>
# &emsp;    images-><br>
# &emsp; &emsp; &emsp; train->
# &emsp; &emsp;&emsp; &emsp;seq_2_frame000.png,
#  seq_2_frame001.png ... <br>
# &emsp; &emsp; &emsp; val->
# &emsp; &emsp;&emsp; &emsp;seq_1_frame000.png,
#  seq_1_frame001.png ... <br>
# &emsp;    labels-><br>
# &emsp; &emsp; &emsp; train->
# &emsp; &emsp;&emsp; &emsp;seq_2_frame000.txt,
#  seq_2_frame001.txt ... <br>
# &emsp; &emsp; &emsp; val->
# &emsp; &emsp;&emsp; &emsp;seq_1_frame000.txt,
#  seq_1_frame001.txt ... <br>

# %% [markdown]
# 1. Converting .xml of [(x1, y1), (x2, y2)] to .txt (xc, yc, h, w)

# %%
import xml.etree.ElementTree as ET
import os
from glob import glob
from tqdm import tqdm

root_dir = "endovis18/"
dest_dir = root_dir

class_name_to_id_mapping = {
    "kidney": 0,
    "bipolar_forceps": 1,
    "prograsp_forceps": 2,
    "large_needle_driver": 3,
    "monopolar_curved_scissors": 4,
    "ultrasound_probe": 5,
    "suction": 6,
    "clip_applier": 7,
    "stapler": 8,
}


# Function to get the data from XML Annotation
def extract_info_from_xml(xml_file):
    root = ET.parse(xml_file).getroot()

    # Initialise the info dict
    info_dict = {}
    info_dict["bboxes"] = []

    # Parse the XML Tree
    for elem in root:
        # Get the file name
        if elem.tag == "filename":
            info_dict["filename"] = elem.text

        # Get the image size
        elif elem.tag == "size":
            image_size = []
            for subelem in elem:
                image_size.append(int(subelem.text))

            info_dict["image_size"] = tuple(image_size)

        # Get details of the bounding box
        elif elem.tag == "objects":
            bbox = {}
            for subelem in elem:
                if subelem.tag == "name":
                    bbox["class"] = subelem.text

                elif subelem.tag == "bndbox":
                    for subsubelem in subelem:
                        bbox[subsubelem.tag] = int(subsubelem.text)
            info_dict["bboxes"].append(bbox)

    info_dict["image_size"] = tuple([1280, 1024, 3])

    return info_dict


# print(extract_info_from_xml('dataset/instruments18/seq_1/xml/frame000.xml'))


def convert_to_yolov5(info_dict, ann):
    print_buffer = []

    # For each bounding box
    for b in info_dict["bboxes"]:
        try:
            class_id = class_name_to_id_mapping[b["class"]]
        except KeyError:
            print("Invalid Class. Must be one from ", class_name_to_id_mapping.keys())

        # Transform the bbox co-ordinates as per the format required by YOLO v5
        b_center_x = (b["xmin"] + b["xmax"]) / 2
        b_center_y = (b["ymin"] + b["ymax"]) / 2
        b_width = b["xmax"] - b["xmin"]
        b_height = b["ymax"] - b["ymin"]

        # Normalise the co-ordinates by the dimensions of the image
        image_w, image_h, image_c = info_dict["image_size"]
        b_center_x /= image_w
        b_center_y /= image_h
        b_width /= image_w
        b_height /= image_h

        # Write the bbox details to the file
        print_buffer.append(
            "{} {:.3f} {:.3f} {:.3f} {:.3f}".format(
                class_id, b_center_x, b_center_y, b_width, b_height
            )
        )

    # Name of the file which we have to save
    save_file_name = os.path.splitext(ann)[0] + ".txt"

    # Save the annotation to disk
    print("\n".join(print_buffer), file=open(save_file_name, "w"))


# Get the annotations
annotations = glob(root_dir + "*/xml/*.xml")

# # Convert and save the annotations
for ann in tqdm(annotations):
    info_dict = extract_info_from_xml(ann)
    convert_to_yolov5(info_dict, ann)

annotations = glob(root_dir + "*/xml/*.txt")
print('done!')
# Out:
# 100%|██████████| 2007/2007 [00:00<00:00, 3809.44it/s]
# done!

# %% [markdown]
# 2. Rearranging folders as COCO dataset

# %%
from glob import glob
import shutil
import os
from PIL import Image

root_dir = "endovis18/"
path = glob(root_dir + "*/xml/*.txt")
endovis_coco_img_path_train = 'endovis18_coco/images/train'
endovis_coco_img_path_val = 'endovis18_coco/images/val'
endovis_coco_label_path_train = 'endovis18_coco/labels/train'
endovis_coco_label_path_val = 'endovis18_coco/labels/val'

os.makedirs(endovis_coco_img_path_train, exist_ok=True)
os.makedirs(endovis_coco_img_path_val, exist_ok=True)
os.makedirs(endovis_coco_label_path_train, exist_ok=True)
os.makedirs(endovis_coco_label_path_val, exist_ok=True)

#validation set with the seq 1, 5, 16 following: https://ieeexplore.ieee.org/abstract/document/9944843
val_seq = [1, 5, 16]
path_all = []
for seq in val_seq:
    path_all.extend(glob(root_dir + "seq_{}/xml/*.txt".format(seq)))

for path in path_all:
    endovis_coco_label_path_val_full = os.path.join(endovis_coco_label_path_val, path.split('/')[1] + '_' + os.path.basename(path))
    shutil.copyfile(path, endovis_coco_label_path_val_full)
    img_path = os.path.join(path.split('/')[0], path.split('/')[1],'left_frames', os.path.basename(path[:-3])+'png')
    endovis_coco_img_path_val_full = os.path.join(endovis_coco_img_path_val, img_path.split('/')[1] + '_' + os.path.basename(img_path))
    shutil.copyfile(img_path, endovis_coco_img_path_val_full)
    

# Training set with the remaining seq following: https://ieeexplore.ieee.org/abstract/document/9944843
train_seq = [2, 3, 4, 6, 7, 9, 10, 11, 12, 14, 15]
path_all = []
for seq in train_seq:
    path_all.extend(glob(root_dir + "seq_{}/xml/*.txt".format(seq)))

for path in path_all:
    endovis_coco_label_path_train_full = os.path.join(endovis_coco_label_path_train, path.split('/')[1] + '_' + os.path.basename(path))
    shutil.copyfile(path, endovis_coco_label_path_train_full)
    img_path = os.path.join(path.split('/')[0], path.split('/')[1],'left_frames', os.path.basename(path[:-3])+'png')
    endovis_coco_img_path_train_full = os.path.join(endovis_coco_img_path_train, img_path.split('/')[1] + '_' + os.path.basename(img_path))
    shutil.copyfile(img_path, endovis_coco_img_path_train_full)

# %% [markdown]
# #Download Code and Trained Weights
#
# installation "super_gradients" lib

# %%
# !pip -q install super-gradients
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 57.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.5/684.5 kB 65.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 101.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 96.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.6/408.6 kB 47.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 108.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 91.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 94.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 95.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 113.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.6 MB/s eta 0:00:00
#   Building wheel for termcolor (setup.py) ... done
#   Building wheel for treelib (setup.py) ... done
#   Building wheel for coverage (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for stringcase (setup.py) ... done

# %% [markdown]
# Unfortunately, need to edit super_gradients/training/utils/utils.py.<br>
# To edit the file please pressed cmd (in mac) or ctrl in windows + click on this file dir

# %%
#1. To edit the file please pressed cmd (in mac) or ctrl in windows + click on this file dir. To get python version you need to run the code or check the installed directory for super_gradients
/usr/local/lib/python3.10/dist-packages/super_gradients/training/utils/utils.py

# Go to line 595:
#current: if isinstance(inputs, collections.Iterable) and not isinstance(inputs, str):
#modify to: if isinstance(inputs, collections.abc.Iterable) and not isinstance(inputs, str):

# %% [markdown]
# Download the code:

# %%
# !git clone https://github.com/Andrewhsin/YOLO-NAS-pytorch
# %cd YOLO-NAS-pytorch
# Out:
# Cloning into 'YOLO-NAS-pytorch'...
# remote: Enumerating objects: 1636, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 1636 (delta 16), reused 0 (delta 0), pack-reused 1559
# Receiving objects: 100% (1636/1636), 80.76 MiB | 15.29 MiB/s, done.
# Resolving deltas: 100% (367/367), done.
# Updating files: 100% (1350/1350), done.
# /content/YOLO-NAS-pytorch

# %% [markdown]
# #Training
# Validation on trained weights following: https://ieeexplore.ieee.org/abstract/document/9944843

# %% [markdown]
# 1. Creating yml file to set all dataset dirs:

# %%
import yaml

with open("dataset/data.yaml") as f:
     list_doc = yaml.safe_load(f)

list_doc['Dir'] = '/content/endovis18_coco/'
list_doc['images']['train'] = 'images/train'
list_doc['images']['val'] = 'images/val'
list_doc['images']['test'] = 'images/val'

list_doc['labels']['train'] = 'labels/train'
list_doc['labels']['val'] = 'labels/val'
list_doc['labels']['test'] = 'labels/val'

with open("dataset/data.yaml", "w") as f:
    yaml.dump(list_doc, f)

# %% [markdown]
# 2. Training

# %%
# !python3 train.py --data dataset/data.yaml --batch 6 --epoch 100 --model yolo_nas_m
# Out:
# The console stream is logged into /root/sg_logs/console.log
# [2023-06-10 14:59:22] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 2023-06-10 14:59:28.526731: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-10 14:59:32.771467: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2023-06-10 14:59:36] INFO - utils.py - NumExpr defaulting to 2 threads.
# [2023-06-10 14:59:37] WARNING - __init__.py - Failed to import pytorch_quantization
# [2023-06-10 14:59:37] WARNING - calibrator.py - Failed to import pytorch_quantization
# [2023-06-10 14:59:37] WARNING - export.py - Failed to import pytorch_quantization
# [2023-06-10 14:59:37] WARNING - selective_quantization_utils.py - Failed to import pytorch_quantization
# [INFO] Checkpoints saved in runs/train2
# Caching annotations: 100% 1560/1560 [00:00<00:00, 6974.37it/s]
# Caching annotations: 100% 447/447 [00:00<00:00, 7315.05it/s]
# Caching annotations: 100% 447/447 [00:00<00:00, 8163.86it/s]
# [2023-06-10 14:59:38] INFO - checkpoint_utils.py - License Notification: YOLO-NAS pre-trained weights are subjected to the specific license terms and conditions detailed in
# https://github.com/Deci-AI/super-gradients/blob/master/LICENSE.YOLONAS.md
# By downloading the pre-trained weight files you agree to comply with these terms.
# Downloading: "https://sghub.deci.ai/models/yolo_nas_m_coco.pth" to /root/.cache/torch/hub/checkpoints/yolo_nas_m_coco.pth
# 100% 196M/196M [00:12<00:00, 16.7MB/s]
# The console stream is now moved to runs/train2/console_Jun10_14_59_59.txt
# [2023-06-10 14:59:59] INFO - sg_trainer.py - Using EMA with params {'decay': 0.9, 'decay_type': 'threshold'}
# [2023-06-10 15:00:03] INFO - sg_trainer_utils.py - TRAINING PARAMETERS:
#     - Mode:                         Single GPU
#     - Number of GPUs:               1          (1 available on the machine)
#     - Dataset size:                 1560       (len(train_set))
#     - Batch size per GPU:           6          (batch_size)
#     - Batch Accumulate:             1          (batch_accumulate)
#     - Total batch size:             6          (num_gpus * batch_size)
#     - Effective Batch size:         6          (num_gpus * batch_size * batch_accumulate)
#     - Iterations per epoch:         260        (len(train_loader))
#     - Gradient updates per epoch:   260        (len(train_loader) / batch_accumulate)
#
# [2023-06-10 15:00:03] INFO - sg_trainer.py - Started training for 100 epochs (0/99)
#
# Train epoch 0: 100% 260/260 [04:50<00:00,  1.12s/it, PPYoloELoss/loss=3.69, PPYoloELoss/loss_cls=2.18, PPYoloELoss/loss_dfl=1.65, PPYoloELoss/loss_iou=0.272, gpu_mem=4.42]
# Validation epoch 0: 100% 75/75 [00:24<00:00,  3.01it/s]
# ===========================================================
# SUMMARY OF EPOCH 0
# ├── Training
# │   ├── Ppyoloeloss/loss = 3.6856
# │   ├── Ppyoloeloss/loss_cls = 2.1821
# │   ├── Ppyoloeloss/loss_dfl = 1.6486
# │   └── Ppyoloeloss/loss_iou = 0.2717
# └── Validation
#     ├── F1@0.50 = 0.0016
#     ├── Map@0.50 = 0.0012
#     ├── Ppyoloeloss/loss = 3.4652
#     ├── Ppyoloeloss/loss_cls = 2.3682
#     ├── Ppyoloeloss/loss_dfl = 1.3163
#     ├── Ppyoloeloss/loss_iou = 0.1755
#     ├── Precision@0.50 = 0.0026
#     └── Recall@0.50 = 0.0037
#
# ===========================================================
# [2023-06-10 15:05:28] INFO - base_sg_logger.py - Checkpoint saved in runs/train2/ckpt_best.pth
# [2023-06-10 15:05:28] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.001248706947080791
# Train epoch 1: 100% 260/260 [04:26<00:00,  1.03s/it, PPYoloELoss/loss=2.62, PPYoloELoss/loss_cls=1.36, PPYoloELoss/loss_dfl=1.44, PPYoloELoss/loss_iou=0.216, gpu_mem=4.5]
# Validation epoch 1: 100% 75/75 [00:22<00:00,  3.29it/s]
# ===========================================================
# SUMMARY OF EPOCH 1
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.617
# │   │   ├── Best until now = 3.6856 (↘ -1.0686)
# │   │   └── Epoch N-1      = 3.6856 (↘ -1.0686)
# │   ├── Ppyoloeloss/loss_cls = 1.3573
# │   │   ├── Best until now = 2.1821 (↘ -0.8248)
# │   │   └── Epoch N-1      = 2.1821 (↘ -0.8248)
# │   ├── Ppyoloeloss/loss_dfl = 1.4404
# │   │   ├── Best until now = 1.6486 (↘ -0.2082)
# │   │   └── Epoch N-1      = 1.6486 (↘ -0.2082)
# │   └── Ppyoloeloss/loss_iou = 0.2158
# │       ├── Best until now = 0.2717 (↘ -0.0559)
# │       └── Epoch N-1      = 0.2717 (↘ -0.0559)
# └── Validation
#     ├── F1@0.50 = 0.0481
#     │   ├── Best until now = 0.0016 (↗ 0.0465)
#     │   └── Epoch N-1      = 0.0016 (↗ 0.0465)
#     ├── Map@0.50 = 0.3023
#     │   ├── Best until now = 0.0012 (↗ 0.3011)
#     │   └── Epoch N-1      = 0.0012 (↗ 0.3011)
#     ├── Ppyoloeloss/loss = 2.1605
#     │   ├── Best until now = 3.4652 (↘ -1.3047)
#     │   └── Epoch N-1      = 3.4652 (↘ -1.3047)
#     ├── Ppyoloeloss/loss_cls = 1.2299
#     │   ├── Best until now = 2.3682 (↘ -1.1383)
#     │   └── Epoch N-1      = 2.3682 (↘ -1.1383)
#     ├── Ppyoloeloss/loss_dfl = 1.1374
#     │   ├── Best until now = 1.3163 (↘ -0.179)
#     │   └── Epoch N-1      = 1.3163 (↘ -0.179)
#     ├── Ppyoloeloss/loss_iou = 0.1448
#     │   ├── Best until now = 0.1755 (↘ -0.0308)
#     │   └── Epoch N-1      = 0.1755 (↘ -0.0308)
#     ├── Precision@0.50 = 0.026
#     │   ├── Best until now = 0.0026 (↗ 0.0234)
#     │   └── Epoch N-1      = 0.0026 (↗ 0.0234)
#     └── Recall@0.50 = 0.643
#         ├── Best until now = 0.0037 (↗ 0.6393)
#         └── Epoch N-1      = 0.0037 (↗ 0.6393)
#
# ===========================================================
# [2023-06-10 15:10:26] INFO - base_sg_logger.py - Checkpoint saved in runs/train2/ckpt_best.pth
# [2023-06-10 15:10:26] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.30234283208847046
# Train epoch 2: 100% 260/260 [04:29<00:00,  1.04s/it, PPYoloELoss/loss=2.46, PPYoloELoss/loss_cls=1.26, PPYoloELoss/loss_dfl=1.38, PPYoloELoss/loss_iou=0.203, gpu_mem=4.46]
# Validation epoch 2: 100% 75/75 [00:22<00:00,  3.30it/s]
# ===========================================================
# SUMMARY OF EPOCH 2
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.4613
# │   │   ├── Best until now = 2.617  (↘ -0.1557)
# │   │   └── Epoch N-1      = 2.617  (↘ -0.1557)
# │   ├── Ppyoloeloss/loss_cls = 1.2648
# │   │   ├── Best until now = 1.3573 (↘ -0.0924)
# │   │   └── Epoch N-1      = 1.3573 (↘ -0.0924)
# │   ├── Ppyoloeloss/loss_dfl = 1.3791
# │   │   ├── Best until now = 1.4404 (↘ -0.0613)
# │   │   └── Epoch N-1      = 1.4404 (↘ -0.0613)
# │   └── Ppyoloeloss/loss_iou = 0.2027
# │       ├── Best until now = 0.2158 (↘ -0.0131)
# │       └── Epoch N-1      = 0.2158 (↘ -0.0131)
# └── Validation
#     ├── F1@0.50 = 0.0377
#     │   ├── Best until now = 0.0481 (↘ -0.0103)
#     │   └── Epoch N-1      = 0.0481 (↘ -0.0103)
#     ├── Map@0.50 = 0.2927
#     │   ├── Best until now = 0.3023 (↘ -0.0097)
#     │   └── Epoch N-1      = 0.3023 (↘ -0.0097)
#     ├── Ppyoloeloss/loss = 2.1704
#     │   ├── Best until now = 2.1605 (↗ 0.0098)
#     │   └── Epoch N-1      = 2.1605 (↗ 0.0098)
#     ├── Ppyoloeloss/loss_cls = 1.2941
#     │   ├── Best until now = 1.2299 (↗ 0.0642)
#     │   └── Epoch N-1      = 1.2299 (↗ 0.0642)
#     ├── Ppyoloeloss/loss_dfl = 1.072
#     │   ├── Best until now = 1.1374 (↘ -0.0653)
#     │   └── Epoch N-1      = 1.1374 (↘ -0.0653)
#     ├── Ppyoloeloss/loss_iou = 0.1361
#     │   ├── Best until now = 0.1448 (↘ -0.0087)
#     │   └── Epoch N-1      = 0.1448 (↘ -0.0087)
#     ├── Precision@0.50 = 0.0195
#     │   ├── Best until now = 0.026  (↘ -0.0065)
#     │   └── Epoch N-1      = 0.026  (↘ -0.0065)
#     └── Recall@0.50 = 0.7119
#         ├── Best until now = 0.643  (↗ 0.0689)
#         └── Epoch N-1      = 0.643  (↗ 0.0689)
#
# ===========================================================
# Train epoch 3: 100% 260/260 [04:22<00:00,  1.01s/it, PPYoloELoss/loss=2.46, PPYoloELoss/loss_cls=1.26, PPYoloELoss/loss_dfl=1.38, PPYoloELoss/loss_iou=0.203, gpu_mem=4.55]
# Validation epoch 3: 100% 75/75 [00:21<00:00,  3.48it/s]
# ===========================================================
# SUMMARY OF EPOCH 3
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.4626
# │   │   ├── Best until now = 2.4613 (↗ 0.0013)
# │   │   └── Epoch N-1      = 2.4613 (↗ 0.0013)
# │   ├── Ppyoloeloss/loss_cls = 1.2642
# │   │   ├── Best until now = 1.2648 (↘ -0.0006)
# │   │   └── Epoch N-1      = 1.2648 (↘ -0.0006)
# │   ├── Ppyoloeloss/loss_dfl = 1.3839
# │   │   ├── Best until now = 1.3791 (↗ 0.0048)
# │   │   └── Epoch N-1      = 1.3791 (↗ 0.0048)
# │   └── Ppyoloeloss/loss_iou = 0.2026
# │       ├── Best until now = 0.2027 (↘ -0.0002)
# │       └── Epoch N-1      = 0.2027 (↘ -0.0002)
# └── Validation
#     ├── F1@0.50 = 0.0472
#     │   ├── Best until now = 0.0481 (↘ -0.0009)
#     │   └── Epoch N-1      = 0.0377 (↗ 0.0094)
#     ├── Map@0.50 = 0.2953
#     │   ├── Best until now = 0.3023 (↘ -0.007)
#     │   └── Epoch N-1      = 0.2927 (↗ 0.0027)
#     ├── Ppyoloeloss/loss = 2.1784
#     │   ├── Best until now = 2.1605 (↗ 0.0179)
#     │   └── Epoch N-1      = 2.1704 (↗ 0.0081)
#     ├── Ppyoloeloss/loss_cls = 1.2154
#     │   ├── Best until now = 1.2299 (↘ -0.0144)
#     │   └── Epoch N-1      = 1.2941 (↘ -0.0786)
#     ├── Ppyoloeloss/loss_dfl = 1.1768
#     │   ├── Best until now = 1.072  (↗ 0.1047)
#     │   └── Epoch N-1      = 1.072  (↗ 0.1047)
#     ├── Ppyoloeloss/loss_iou = 0.1498
#     │   ├── Best until now = 0.1361 (↗ 0.0137)
#     │   └── Epoch N-1      = 0.1361 (↗ 0.0137)
#     ├── Precision@0.50 = 0.0473
#     │   ├── Best until now = 0.026  (↗ 0.0213)
#     │   └── Epoch N-1      = 0.0195 (↗ 0.0278)
#     └── Recall@0.50 = 0.7082
#         ├── Best until now = 0.7119 (↘ -0.0037)
#         └── Epoch N-1      = 0.7119 (↘ -0.0037)
#
# ===========================================================
# Train epoch 4: 100% 260/260 [04:25<00:00,  1.02s/it, PPYoloELoss/loss=2.38, PPYoloELoss/loss_cls=1.22, PPYoloELoss/loss_dfl=1.34, PPYoloELoss/loss_iou=0.194, gpu_mem=4.5]
# Validation epoch 4: 100% 75/75 [00:21<00:00,  3.55it/s]
# ===========================================================
# SUMMARY OF EPOCH 4
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.3775
# │   │   ├── Best until now = 2.4613 (↘ -0.0838)
# │   │   └── Epoch N-1      = 2.4626 (↘ -0.0851)
# │   ├── Ppyoloeloss/loss_cls = 1.223
# │   │   ├── Best until now = 1.2642 (↘ -0.0412)
# │   │   └── Epoch N-1      = 1.2642 (↘ -0.0412)
# │   ├── Ppyoloeloss/loss_dfl = 1.3413
# │   │   ├── Best until now = 1.3791 (↘ -0.0378)
# │   │   └── Epoch N-1      = 1.3839 (↘ -0.0426)
# │   └── Ppyoloeloss/loss_iou = 0.1935
# │       ├── Best until now = 0.2026 (↘ -0.009)
# │       └── Epoch N-1      = 0.2026 (↘ -0.009)
# └── Validation
#     ├── F1@0.50 = 0.0367
#     │   ├── Best until now = 0.0481 (↘ -0.0113)
#     │   └── Epoch N-1      = 0.0472 (↘ -0.0104)
#     ├── Map@0.50 = 0.3692
#     │   ├── Best until now = 0.3023 (↗ 0.0668)
#     │   └── Epoch N-1      = 0.2953 (↗ 0.0738)
#     ├── Ppyoloeloss/loss = 2.1767
#     │   ├── Best until now = 2.1605 (↗ 0.0162)
#     │   └── Epoch N-1      = 2.1784 (↘ -0.0017)
#     ├── Ppyoloeloss/loss_cls = 1.2898
#     │   ├── Best until now = 1.2154 (↗ 0.0744)
#     │   └── Epoch N-1      = 1.2154 (↗ 0.0744)
#     ├── Ppyoloeloss/loss_dfl = 1.102
#     │   ├── Best until now = 1.072  (↗ 0.0299)
#     │   └── Epoch N-1      = 1.1768 (↘ -0.0748)
#     ├── Ppyoloeloss/loss_iou = 0.1344
#     │   ├── Best until now = 0.1361 (↘ -0.0017)
#     │   └── Epoch N-1      = 0.1498 (↘ -0.0155)
#     ├── Precision@0.50 = 0.0193
#     │   ├── Best until now = 0.0473 (↘ -0.0281)
#     │   └── Epoch N-1      = 0.0473 (↘ -0.0281)
#     └── Recall@0.50 = 0.7027
#         ├── Best until now = 0.7119 (↘ -0.0092)
#         └── Epoch N-1      = 0.7082 (↘ -0.0055)
#
# ===========================================================
# [2023-06-10 15:25:26] INFO - base_sg_logger.py - Checkpoint saved in runs/train2/ckpt_best.pth
# [2023-06-10 15:25:26] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.3691626489162445
# Train epoch 5: 100% 260/260 [04:24<00:00,  1.02s/it, PPYoloELoss/loss=2.33, PPYoloELoss/loss_cls=1.2, PPYoloELoss/loss_dfl=1.31, PPYoloELoss/loss_iou=0.188, gpu_mem=4.5]
# Validation epoch 5: 100% 75/75 [00:21<00:00,  3.52it/s]
# ===========================================================
# SUMMARY OF EPOCH 5
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.327
# │   │   ├── Best until now = 2.3775 (↘ -0.0505)
# │   │   └── Epoch N-1      = 2.3775 (↘ -0.0505)
# │   ├── Ppyoloeloss/loss_cls = 1.2027
# │   │   ├── Best until now = 1.223  (↘ -0.0203)
# │   │   └── Epoch N-1      = 1.223  (↘ -0.0203)
# │   ├── Ppyoloeloss/loss_dfl = 1.3106
# │   │   ├── Best until now = 1.3413 (↘ -0.0307)
# │   │   └── Epoch N-1      = 1.3413 (↘ -0.0307)
# │   └── Ppyoloeloss/loss_iou = 0.1876
# │       ├── Best until now = 0.1935 (↘ -0.0059)
# │       └── Epoch N-1      = 0.1935 (↘ -0.0059)
# └── Validation
#     ├── F1@0.50 = 0.0387
#     │   ├── Best until now = 0.0481 (↘ -0.0093)
#     │   └── Epoch N-1      = 0.0367 (↗ 0.002)
#     ├── Map@0.50 = 0.3188
#     │   ├── Best until now = 0.3692 (↘ -0.0503)
#     │   └── Epoch N-1      = 0.3692 (↘ -0.0503)
#     ├── Ppyoloeloss/loss = 2.0771
#     │   ├── Best until now = 2.1605 (↘ -0.0835)
#     │   └── Epoch N-1      = 2.1767 (↘ -0.0996)
#     ├── Ppyoloeloss/loss_cls = 1.2298
#     │   ├── Best until now = 1.2154 (↗ 0.0144)
#     │   └── Epoch N-1      = 1.2898 (↘ -0.06)
#     ├── Ppyoloeloss/loss_dfl = 1.0625
#     │   ├── Best until now = 1.072  (↘ -0.0095)
#     │   └── Epoch N-1      = 1.102  (↘ -0.0395)
#     ├── Ppyoloeloss/loss_iou = 0.1264
#     │   ├── Best until now = 0.1344 (↘ -0.008)
#     │   └── Epoch N-1      = 0.1344 (↘ -0.008)
#     ├── Precision@0.50 = 0.0202
#     │   ├── Best until now = 0.0473 (↘ -0.0271)
#     │   └── Epoch N-1      = 0.0193 (↗ 0.0009)
#     └── Recall@0.50 = 0.7254
#         ├── Best until now = 0.7119 (↗ 0.0135)
#         └── Epoch N-1      = 0.7027 (↗ 0.0227)
#
# ===========================================================
# Train epoch 6: 100% 260/260 [04:22<00:00,  1.01s/it, PPYoloELoss/loss=2.28, PPYoloELoss/loss_cls=1.17, PPYoloELoss/loss_dfl=1.3, PPYoloELoss/loss_iou=0.185, gpu_mem=4.55]
# Validation epoch 6: 100% 75/75 [00:21<00:00,  3.56it/s]
# ===========================================================
# SUMMARY OF EPOCH 6
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.2849
# │   │   ├── Best until now = 2.327  (↘ -0.0421)
# │   │   └── Epoch N-1      = 2.327  (↘ -0.0421)
# │   ├── Ppyoloeloss/loss_cls = 1.1731
# │   │   ├── Best until now = 1.2027 (↘ -0.0296)
# │   │   └── Epoch N-1      = 1.2027 (↘ -0.0296)
# │   ├── Ppyoloeloss/loss_dfl = 1.2982
# │   │   ├── Best until now = 1.3106 (↘ -0.0124)
# │   │   └── Epoch N-1      = 1.3106 (↘ -0.0124)
# │   └── Ppyoloeloss/loss_iou = 0.1851
# │       ├── Best until now = 0.1876 (↘ -0.0025)
# │       └── Epoch N-1      = 0.1876 (↘ -0.0025)
# └── Validation
#     ├── F1@0.50 = 0.0463
#     │   ├── Best until now = 0.0481 (↘ -0.0018)
#     │   └── Epoch N-1      = 0.0387 (↗ 0.0075)
#     ├── Map@0.50 = 0.3633
#     │   ├── Best until now = 0.3692 (↘ -0.0058)
#     │   └── Epoch N-1      = 0.3188 (↗ 0.0445)
#     ├── Ppyoloeloss/loss = 2.1996
#     │   ├── Best until now = 2.0771 (↗ 0.1225)
#     │   └── Epoch N-1      = 2.0771 (↗ 0.1225)
#     ├── Ppyoloeloss/loss_cls = 1.2346
#     │   ├── Best until now = 1.2154 (↗ 0.0192)
#     │   └── Epoch N-1      = 1.2298 (↗ 0.0048)
#     ├── Ppyoloeloss/loss_dfl = 1.1729
#     │   ├── Best until now = 1.0625 (↗ 0.1103)
#     │   └── Epoch N-1      = 1.0625 (↗ 0.1103)
#     ├── Ppyoloeloss/loss_iou = 0.1514
#     │   ├── Best until now = 0.1264 (↗ 0.025)
#     │   └── Epoch N-1      = 0.1264 (↗ 0.025)
#     ├── Precision@0.50 = 0.0241
#     │   ├── Best until now = 0.0473 (↘ -0.0232)
#     │   └── Epoch N-1      = 0.0202 (↗ 0.004)
#     └── Recall@0.50 = 0.7636
#         ├── Best until now = 0.7254 (↗ 0.0382)
#         └── Epoch N-1      = 0.7254 (↗ 0.0382)
#
# ===========================================================
# Train epoch 7: 100% 260/260 [04:27<00:00,  1.03s/it, PPYoloELoss/loss=2.28, PPYoloELoss/loss_cls=1.17, PPYoloELoss/loss_dfl=1.29, PPYoloELoss/loss_iou=0.184, gpu_mem=4.5]
# Validation epoch 7: 100% 75/75 [00:21<00:00,  3.45it/s]
# ===========================================================
# SUMMARY OF EPOCH 7
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.2751
# │   │   ├── Best until now = 2.2849 (↘ -0.0098)
# │   │   └── Epoch N-1      = 2.2849 (↘ -0.0098)
# │   ├── Ppyoloeloss/loss_cls = 1.1699
# │   │   ├── Best until now = 1.1731 (↘ -0.0032)
# │   │   └── Epoch N-1      = 1.1731 (↘ -0.0032)
# │   ├── Ppyoloeloss/loss_dfl = 1.2921
# │   │   ├── Best until now = 1.2982 (↘ -0.0061)
# │   │   └── Epoch N-1      = 1.2982 (↘ -0.0061)
# │   └── Ppyoloeloss/loss_iou = 0.1837
# │       ├── Best until now = 0.1851 (↘ -0.0014)
# │       └── Epoch N-1      = 0.1851 (↘ -0.0014)
# └── Validation
#     ├── F1@0.50 = 0.0517
#     │   ├── Best until now = 0.0481 (↗ 0.0036)
#     │   └── Epoch N-1      = 0.0463 (↗ 0.0054)
#     ├── Map@0.50 = 0.3968
#     │   ├── Best until now = 0.3692 (↗ 0.0276)
#     │   └── Epoch N-1      = 0.3633 (↗ 0.0335)
#     ├── Ppyoloeloss/loss = 1.9759
#     │   ├── Best until now = 2.0771 (↘ -0.1012)
#     │   └── Epoch N-1      = 2.1996 (↘ -0.2237)
#     ├── Ppyoloeloss/loss_cls = 1.136
#     │   ├── Best until now = 1.2154 (↘ -0.0795)
#     │   └── Epoch N-1      = 1.2346 (↘ -0.0987)
#     ├── Ppyoloeloss/loss_dfl = 1.0499
#     │   ├── Best until now = 1.0625 (↘ -0.0126)
#     │   └── Epoch N-1      = 1.1729 (↘ -0.123)
#     ├── Ppyoloeloss/loss_iou = 0.126
#     │   ├── Best until now = 0.1264 (↘ -0.0004)
#     │   └── Epoch N-1      = 0.1514 (↘ -0.0254)
#     ├── Precision@0.50 = 0.0277
#     │   ├── Best until now = 0.0473 (↘ -0.0196)
#     │   └── Epoch N-1      = 0.0241 (↗ 0.0035)
#     └── Recall@0.50 = 0.729
#         ├── Best until now = 0.7636 (↘ -0.0346)
#         └── Epoch N-1      = 0.7636 (↘ -0.0346)
#
# ===========================================================
# [2023-06-10 15:40:43] INFO - base_sg_logger.py - Checkpoint saved in runs/train2/ckpt_best.pth
# [2023-06-10 15:40:43] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.3967994749546051
# Train epoch 8: 100% 260/260 [04:25<00:00,  1.02s/it, PPYoloELoss/loss=2.23, PPYoloELoss/loss_cls=1.14, PPYoloELoss/loss_dfl=1.27, PPYoloELoss/loss_iou=0.18, gpu_mem=4.46]
# Validation epoch 8: 100% 75/75 [00:22<00:00,  3.33it/s]
# ===========================================================
# SUMMARY OF EPOCH 8
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.227
# │   │   ├── Best until now = 2.2751 (↘ -0.0481)
# │   │   └── Epoch N-1      = 2.2751 (↘ -0.0481)
# │   ├── Ppyoloeloss/loss_cls = 1.1417
# │   │   ├── Best until now = 1.1699 (↘ -0.0282)
# │   │   └── Epoch N-1      = 1.1699 (↘ -0.0282)
# │   ├── Ppyoloeloss/loss_dfl = 1.2714
# │   │   ├── Best until now = 1.2921 (↘ -0.0207)
# │   │   └── Epoch N-1      = 1.2921 (↘ -0.0207)
# │   └── Ppyoloeloss/loss_iou = 0.1799
# │       ├── Best until now = 0.1837 (↘ -0.0038)
# │       └── Epoch N-1      = 0.1837 (↘ -0.0038)
# └── Validation
#     ├── F1@0.50 = 0.05
#     │   ├── Best until now = 0.0517 (↘ -0.0017)
#     │   └── Epoch N-1      = 0.0517 (↘ -0.0017)
#     ├── Map@0.50 = 0.4225
#     │   ├── Best until now = 0.3968 (↗ 0.0257)
#     │   └── Epoch N-1      = 0.3968 (↗ 0.0257)
#     ├── Ppyoloeloss/loss = 2.0667
#     │   ├── Best until now = 1.9759 (↗ 0.0908)
#     │   └── Epoch N-1      = 1.9759 (↗ 0.0908)
#     ├── Ppyoloeloss/loss_cls = 1.1738
#     │   ├── Best until now = 1.136  (↗ 0.0379)
#     │   └── Epoch N-1      = 1.136  (↗ 0.0379)
#     ├── Ppyoloeloss/loss_dfl = 1.1118
#     │   ├── Best until now = 1.0499 (↗ 0.0619)
#     │   └── Epoch N-1      = 1.0499 (↗ 0.0619)
#     ├── Ppyoloeloss/loss_iou = 0.1348
#     │   ├── Best until now = 0.126  (↗ 0.0088)
#     │   └── Epoch N-1      = 0.126  (↗ 0.0088)
#     ├── Precision@0.50 = 0.034
#     │   ├── Best until now = 0.0473 (↘ -0.0133)
#     │   └── Epoch N-1      = 0.0277 (↗ 0.0063)
#     └── Recall@0.50 = 0.7072
#         ├── Best until now = 0.7636 (↘ -0.0564)
#         └── Epoch N-1      = 0.729  (↘ -0.0219)
#
# ===========================================================
# [2023-06-10 15:45:58] INFO - base_sg_logger.py - Checkpoint saved in runs/train2/ckpt_best.pth
# [2023-06-10 15:45:58] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.4224666655063629
# Train epoch 9: 100% 260/260 [04:27<00:00,  1.03s/it, PPYoloELoss/loss=2.21, PPYoloELoss/loss_cls=1.14, PPYoloELoss/loss_dfl=1.26, PPYoloELoss/loss_iou=0.177, gpu_mem=4.5]
# Validation epoch 9: 100% 75/75 [00:24<00:00,  3.03it/s]
# ===========================================================
# SUMMARY OF EPOCH 9
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.2139
# │   │   ├── Best until now = 2.227  (↘ -0.0131)
# │   │   └── Epoch N-1      = 2.227  (↘ -0.0131)
# │   ├── Ppyoloeloss/loss_cls = 1.1423
# │   │   ├── Best until now = 1.1417 (↗ 0.0006)
# │   │   └── Epoch N-1      = 1.1417 (↗ 0.0006)
# │   ├── Ppyoloeloss/loss_dfl = 1.2579
# │   │   ├── Best until now = 1.2714 (↘ -0.0135)
# │   │   └── Epoch N-1      = 1.2714 (↘ -0.0135)
# │   └── Ppyoloeloss/loss_iou = 0.1771
# │       ├── Best until now = 0.1799 (↘ -0.0028)
# │       └── Epoch N-1      = 0.1799 (↘ -0.0028)
# └── Validation
#     ├── F1@0.50 = 0.0518
#     │   ├── Best until now = 0.0517 (↗ 0.0001)
#     │   └── Epoch N-1      = 0.05   (↗ 0.0018)
#     ├── Map@0.50 = 0.4146
#     │   ├── Best until now = 0.4225 (↘ -0.0079)
#     │   └── Epoch N-1      = 0.4225 (↘ -0.0079)
#     ├── Ppyoloeloss/loss = 2.0941
#     │   ├── Best until now = 1.9759 (↗ 0.1182)
#     │   └── Epoch N-1      = 2.0667 (↗ 0.0274)
#     ├── Ppyoloeloss/loss_cls = 1.2151
#     │   ├── Best until now = 1.136  (↗ 0.0791)
#     │   └── Epoch N-1      = 1.1738 (↗ 0.0413)
#     ├── Ppyoloeloss/loss_dfl = 1.0762
#     │   ├── Best until now = 1.0499 (↗ 0.0263)
#     │   └── Epoch N-1      = 1.1118 (↘ -0.0356)
#     ├── Ppyoloeloss/loss_iou = 0.1364
#     │   ├── Best until now = 0.126  (↗ 0.0104)
#     │   └── Epoch N-1      = 0.1348 (↗ 0.0016)
#     ├── Precision@0.50 = 0.0272
#     │   ├── Best until now = 0.0473 (↘ -0.0201)
#     │   └── Epoch N-1      = 0.034  (↘ -0.0068)
#     └── Recall@0.50 = 0.7614
#         ├── Best until now = 0.7636 (↘ -0.0022)
#         └── Epoch N-1      = 0.7072 (↗ 0.0542)
#
# ===========================================================
# Train epoch 10: 100% 260/260 [04:25<00:00,  1.02s/it, PPYoloELoss/loss=2.23, PPYoloELoss/loss_cls=1.14, PPYoloELoss/loss_dfl=1.27, PPYoloELoss/loss_iou=0.178, gpu_mem=4.53]
# Validation epoch 10: 100% 75/75 [00:21<00:00,  3.52it/s]
# ===========================================================
# SUMMARY OF EPOCH 10
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.2261
# │   │   ├── Best until now = 2.2139 (↗ 0.0121)
# │   │   └── Epoch N-1      = 2.2139 (↗ 0.0121)
# │   ├── Ppyoloeloss/loss_cls = 1.1447
# │   │   ├── Best until now = 1.1417 (↗ 0.003)
# │   │   └── Epoch N-1      = 1.1423 (↗ 0.0023)
# │   ├── Ppyoloeloss/loss_dfl = 1.2718
# │   │   ├── Best until now = 1.2579 (↗ 0.0139)
# │   │   └── Epoch N-1      = 1.2579 (↗ 0.0139)
# │   └── Ppyoloeloss/loss_iou = 0.1782
# │       ├── Best until now = 0.1771 (↗ 0.0011)
# │       └── Epoch N-1      = 0.1771 (↗ 0.0011)
# └── Validation
#     ├── F1@0.50 = 0.0691
#     │   ├── Best until now = 0.0518 (↗ 0.0173)
#     │   └── Epoch N-1      = 0.0518 (↗ 0.0173)
#     ├── Map@0.50 = 0.3936
#     │   ├── Best until now = 0.4225 (↘ -0.0289)
#     │   └── Epoch N-1      = 0.4146 (↘ -0.021)
#     ├── Ppyoloeloss/loss = 2.0752
#     │   ├── Best until now = 1.9759 (↗ 0.0992)
#     │   └── Epoch N-1      = 2.0941 (↘ -0.019)
#     ├── Ppyoloeloss/loss_cls = 1.1737
#     │   ├── Best until now = 1.136  (↗ 0.0377)
#     │   └── Epoch N-1      = 1.2151 (↘ -0.0414)
#     ├── Ppyoloeloss/loss_dfl = 1.1106
#     │   ├── Best until now = 1.0499 (↗ 0.0608)
#     │   └── Epoch N-1      = 1.0762 (↗ 0.0344)
#     ├── Ppyoloeloss/loss_iou = 0.1385
#     │   ├── Best until now = 0.126  (↗ 0.0125)
#     │   └── Epoch N-1      = 0.1364 (↗ 0.0021)
#     ├── Precision@0.50 = 0.0394
#     │   ├── Best until now = 0.0473 (↘ -0.0079)
#     │   └── Epoch N-1      = 0.0272 (↗ 0.0122)
#     └── Recall@0.50 = 0.7532
#         ├── Best until now = 0.7636 (↘ -0.0104)
#         └── Epoch N-1      = 0.7614 (↘ -0.0082)
#
# ===========================================================
# Train epoch 11: 100% 260/260 [04:27<00:00,  1.03s/it, PPYoloELoss/loss=2.21, PPYoloELoss/loss_cls=1.13, PPYoloELoss/loss_dfl=1.26, PPYoloELoss/loss_iou=0.177, gpu_mem=4.55]
# Validation epoch 11: 100% 75/75 [00:23<00:00,  3.26it/s]
# ===========================================================
# SUMMARY OF EPOCH 11
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.2052
# │   │   ├── Best until now = 2.2139 (↘ -0.0087)
# │   │   └── Epoch N-1      = 2.2261 (↘ -0.0209)
# │   ├── Ppyoloeloss/loss_cls = 1.1308
# │   │   ├── Best until now = 1.1417 (↘ -0.0108)
# │   │   └── Epoch N-1      = 1.1447 (↘ -0.0138)
# │   ├── Ppyoloeloss/loss_dfl = 1.2617
# │   │   ├── Best until now = 1.2579 (↗ 0.0038)
# │   │   └── Epoch N-1      = 1.2718 (↘ -0.0101)
# │   └── Ppyoloeloss/loss_iou = 0.1774
# │       ├── Best until now = 0.1771 (↗ 0.0003)
# │       └── Epoch N-1      = 0.1782 (↘ -0.0008)
# └── Validation
#     ├── F1@0.50 = 0.0642
#     │   ├── Best until now = 0.0691 (↘ -0.0048)
#     │   └── Epoch N-1      = 0.0691 (↘ -0.0048)
#     ├── Map@0.50 = 0.3789
#     │   ├── Best until now = 0.4225 (↘ -0.0435)
#     │   └── Epoch N-1      = 0.3936 (↘ -0.0146)
#     ├── Ppyoloeloss/loss = 1.9764
#     │   ├── Best until now = 1.9759 (↗ 0.0005)
#     │   └── Epoch N-1      = 2.0752 (↘ -0.0987)
#     ├── Ppyoloeloss/loss_cls = 1.1261
#     │   ├── Best until now = 1.136  (↘ -0.0099)
#     │   └── Epoch N-1      = 1.1737 (↘ -0.0476)
#     ├── Ppyoloeloss/loss_dfl = 1.0617
#     │   ├── Best until now = 1.0499 (↗ 0.0119)
#     │   └── Epoch N-1      = 1.1106 (↘ -0.0489)
#     ├── Ppyoloeloss/loss_iou = 0.1278
#     │   ├── Best until now = 0.126  (↗ 0.0018)
#     │   └── Epoch N-1      = 0.1385 (↘ -0.0107)
#     ├── Precision@0.50 = 0.0345
#     │   ├── Best until now = 0.0473 (↘ -0.0128)
#     │   └── Epoch N-1      = 0.0394 (↘ -0.0049)
#     └── Recall@0.50 = 0.7536
#         ├── Best until now = 0.7636 (↘ -0.01)
#         └── Epoch N-1      = 0.7532 (↗ 0.0004)
#
# ===========================================================
# Train epoch 12: 100% 260/260 [04:35<00:00,  1.06s/it, PPYoloELoss/loss=2.18, PPYoloELoss/loss_cls=1.12, PPYoloELoss/loss_dfl=1.25, PPYoloELoss/loss_iou=0.176, gpu_mem=4.54]
# Validation epoch 12: 100% 75/75 [00:21<00:00,  3.47it/s]
# ===========================================================
# SUMMARY OF EPOCH 12
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1839
# │   │   ├── Best until now = 2.2052 (↘ -0.0213)
# │   │   └── Epoch N-1      = 2.2052 (↘ -0.0213)
# │   ├── Ppyoloeloss/loss_cls = 1.1192
# │   │   ├── Best until now = 1.1308 (↘ -0.0116)
# │   │   └── Epoch N-1      = 1.1308 (↘ -0.0116)
# │   ├── Ppyoloeloss/loss_dfl = 1.2498
# │   │   ├── Best until now = 1.2579 (↘ -0.0082)
# │   │   └── Epoch N-1      = 1.2617 (↘ -0.012)
# │   └── Ppyoloeloss/loss_iou = 0.1759
# │       ├── Best until now = 0.1771 (↘ -0.0011)
# │       └── Epoch N-1      = 0.1774 (↘ -0.0015)
# └── Validation
#     ├── F1@0.50 = 0.0525
#     │   ├── Best until now = 0.0691 (↘ -0.0165)
#     │   └── Epoch N-1      = 0.0642 (↘ -0.0117)
#     ├── Map@0.50 = 0.3939
#     │   ├── Best until now = 0.4225 (↘ -0.0285)
#     │   └── Epoch N-1      = 0.3789 (↗ 0.015)
#     ├── Ppyoloeloss/loss = 1.9915
#     │   ├── Best until now = 1.9759 (↗ 0.0156)
#     │   └── Epoch N-1      = 1.9764 (↗ 0.0151)
#     ├── Ppyoloeloss/loss_cls = 1.09
#     │   ├── Best until now = 1.1261 (↘ -0.0361)
#     │   └── Epoch N-1      = 1.1261 (↘ -0.0361)
#     ├── Ppyoloeloss/loss_dfl = 1.1117
#     │   ├── Best until now = 1.0499 (↗ 0.0618)
#     │   └── Epoch N-1      = 1.0617 (↗ 0.05)
#     ├── Ppyoloeloss/loss_iou = 0.1383
#     │   ├── Best until now = 0.126  (↗ 0.0123)
#     │   └── Epoch N-1      = 0.1278 (↗ 0.0105)
#     ├── Precision@0.50 = 0.0274
#     │   ├── Best until now = 0.0473 (↘ -0.0199)
#     │   └── Epoch N-1      = 0.0345 (↘ -0.0071)
#     └── Recall@0.50 = 0.7479
#         ├── Best until now = 0.7636 (↘ -0.0157)
#         └── Epoch N-1      = 0.7536 (↘ -0.0057)
#
# ===========================================================
# Train epoch 13: 100% 260/260 [04:31<00:00,  1.04s/it, PPYoloELoss/loss=2.17, PPYoloELoss/loss_cls=1.11, PPYoloELoss/loss_dfl=1.25, PPYoloELoss/loss_iou=0.174, gpu_mem=4.54]
# Validation epoch 13: 100% 75/75 [00:22<00:00,  3.26it/s]
# ===========================================================
# SUMMARY OF EPOCH 13
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1704
# │   │   ├── Best until now = 2.1839 (↘ -0.0134)
# │   │   └── Epoch N-1      = 2.1839 (↘ -0.0134)
# │   ├── Ppyoloeloss/loss_cls = 1.1108
# │   │   ├── Best until now = 1.1192 (↘ -0.0084)
# │   │   └── Epoch N-1      = 1.1192 (↘ -0.0084)
# │   ├── Ppyoloeloss/loss_dfl = 1.2477
# │   │   ├── Best until now = 1.2498 (↘ -0.002)
# │   │   └── Epoch N-1      = 1.2498 (↘ -0.002)
# │   └── Ppyoloeloss/loss_iou = 0.1743
# │       ├── Best until now = 0.1759 (↘ -0.0016)
# │       └── Epoch N-1      = 0.1759 (↘ -0.0016)
# └── Validation
#     ├── F1@0.50 = 0.0481
#     │   ├── Best until now = 0.0691 (↘ -0.021)
#     │   └── Epoch N-1      = 0.0525 (↘ -0.0044)
#     ├── Map@0.50 = 0.3903
#     │   ├── Best until now = 0.4225 (↘ -0.0321)
#     │   └── Epoch N-1      = 0.3939 (↘ -0.0036)
#     ├── Ppyoloeloss/loss = 2.1022
#     │   ├── Best until now = 1.9759 (↗ 0.1263)
#     │   └── Epoch N-1      = 1.9915 (↗ 0.1107)
#     ├── Ppyoloeloss/loss_cls = 1.1504
#     │   ├── Best until now = 1.09   (↗ 0.0604)
#     │   └── Epoch N-1      = 1.09   (↗ 0.0604)
#     ├── Ppyoloeloss/loss_dfl = 1.1623
#     │   ├── Best until now = 1.0499 (↗ 0.1124)
#     │   └── Epoch N-1      = 1.1117 (↗ 0.0506)
#     ├── Ppyoloeloss/loss_iou = 0.1483
#     │   ├── Best until now = 0.126  (↗ 0.0223)
#     │   └── Epoch N-1      = 0.1383 (↗ 0.01)
#     ├── Precision@0.50 = 0.025
#     │   ├── Best until now = 0.0473 (↘ -0.0223)
#     │   └── Epoch N-1      = 0.0274 (↘ -0.0025)
#     └── Recall@0.50 = 0.7815
#         ├── Best until now = 0.7636 (↗ 0.0178)
#         └── Epoch N-1      = 0.7479 (↗ 0.0336)
#
# ===========================================================
# Train epoch 14: 100% 260/260 [04:31<00:00,  1.04s/it, PPYoloELoss/loss=2.16, PPYoloELoss/loss_cls=1.1, PPYoloELoss/loss_dfl=1.24, PPYoloELoss/loss_iou=0.173, gpu_mem=4.54]
# Validation epoch 14: 100% 75/75 [00:21<00:00,  3.52it/s]
# ===========================================================
# SUMMARY OF EPOCH 14
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1591
# │   │   ├── Best until now = 2.1704 (↘ -0.0114)
# │   │   └── Epoch N-1      = 2.1704 (↘ -0.0114)
# │   ├── Ppyoloeloss/loss_cls = 1.1043
# │   │   ├── Best until now = 1.1108 (↘ -0.0065)
# │   │   └── Epoch N-1      = 1.1108 (↘ -0.0065)
# │   ├── Ppyoloeloss/loss_dfl = 1.2423
# │   │   ├── Best until now = 1.2477 (↘ -0.0055)
# │   │   └── Epoch N-1      = 1.2477 (↘ -0.0055)
# │   └── Ppyoloeloss/loss_iou = 0.1735
# │       ├── Best until now = 0.1743 (↘ -0.0009)
# │       └── Epoch N-1      = 0.1743 (↘ -0.0009)
# └── Validation
#     ├── F1@0.50 = 0.0928
#     │   ├── Best until now = 0.0691 (↗ 0.0237)
#     │   └── Epoch N-1      = 0.0481 (↗ 0.0447)
#     ├── Map@0.50 = 0.4595
#     │   ├── Best until now = 0.4225 (↗ 0.037)
#     │   └── Epoch N-1      = 0.3903 (↗ 0.0692)
#     ├── Ppyoloeloss/loss = 1.9483
#     │   ├── Best until now = 1.9759 (↘ -0.0276)
#     │   └── Epoch N-1      = 2.1022 (↘ -0.1539)
#     ├── Ppyoloeloss/loss_cls = 1.0579
#     │   ├── Best until now = 1.09   (↘ -0.0321)
#     │   └── Epoch N-1      = 1.1504 (↘ -0.0925)
#     ├── Ppyoloeloss/loss_dfl = 1.0948
#     │   ├── Best until now = 1.0499 (↗ 0.0449)
#     │   └── Epoch N-1      = 1.1623 (↘ -0.0674)
#     ├── Ppyoloeloss/loss_iou = 0.1372
#     │   ├── Best until now = 0.126  (↗ 0.0112)
#     │   └── Epoch N-1      = 0.1483 (↘ -0.011)
#     ├── Precision@0.50 = 0.0532
#     │   ├── Best until now = 0.0473 (↗ 0.0059)
#     │   └── Epoch N-1      = 0.025  (↗ 0.0282)
#     └── Recall@0.50 = 0.75
#         ├── Best until now = 0.7815 (↘ -0.0314)
#         └── Epoch N-1      = 0.7815 (↘ -0.0314)
#
# ===========================================================
# [2023-06-10 16:18:03] INFO - base_sg_logger.py - Checkpoint saved in runs/train2/ckpt_best.pth
# [2023-06-10 16:18:03] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.4594907760620117
# Train epoch 15: 100% 260/260 [04:30<00:00,  1.04s/it, PPYoloELoss/loss=2.15, PPYoloELoss/loss_cls=1.1, PPYoloELoss/loss_dfl=1.24, PPYoloELoss/loss_iou=0.173, gpu_mem=4.54]
# Validation epoch 15: 100% 75/75 [00:22<00:00,  3.32it/s]
# ===========================================================
# SUMMARY OF EPOCH 15
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1527
# │   │   ├── Best until now = 2.1591 (↘ -0.0063)
# │   │   └── Epoch N-1      = 2.1591 (↘ -0.0063)
# │   ├── Ppyoloeloss/loss_cls = 1.0974
# │   │   ├── Best until now = 1.1043 (↘ -0.0069)
# │   │   └── Epoch N-1      = 1.1043 (↘ -0.0069)
# │   ├── Ppyoloeloss/loss_dfl = 1.2441
# │   │   ├── Best until now = 1.2423 (↗ 0.0018)
# │   │   └── Epoch N-1      = 1.2423 (↗ 0.0018)
# │   └── Ppyoloeloss/loss_iou = 0.1733
# │       ├── Best until now = 0.1735 (↘ -1e-04)
# │       └── Epoch N-1      = 0.1735 (↘ -1e-04)
# └── Validation
#     ├── F1@0.50 = 0.0567
#     │   ├── Best until now = 0.0928 (↘ -0.0361)
#     │   └── Epoch N-1      = 0.0928 (↘ -0.0361)
#     ├── Map@0.50 = 0.3702
#     │   ├── Best until now = 0.4595 (↘ -0.0893)
#     │   └── Epoch N-1      = 0.4595 (↘ -0.0893)
#     ├── Ppyoloeloss/loss = 2.11
#     │   ├── Best until now = 1.9483 (↗ 0.1617)
#     │   └── Epoch N-1      = 1.9483 (↗ 0.1617)
#     ├── Ppyoloeloss/loss_cls = 1.1922
#     │   ├── Best until now = 1.0579 (↗ 0.1344)
#     │   └── Epoch N-1      = 1.0579 (↗ 0.1344)
#     ├── Ppyoloeloss/loss_dfl = 1.1304
#     │   ├── Best until now = 1.0499 (↗ 0.0806)
#     │   └── Epoch N-1      = 1.0948 (↗ 0.0356)
#     ├── Ppyoloeloss/loss_iou = 0.141
#     │   ├── Best until now = 0.126  (↗ 0.015)
#     │   └── Epoch N-1      = 0.1372 (↗ 0.0038)
#     ├── Precision@0.50 = 0.0298
#     │   ├── Best until now = 0.0532 (↘ -0.0234)
#     │   └── Epoch N-1      = 0.0532 (↘ -0.0234)
#     └── Recall@0.50 = 0.7745
#         ├── Best until now = 0.7815 (↘ -0.007)
#         └── Epoch N-1      = 0.75   (↗ 0.0245)
#
# ===========================================================
# Train epoch 16: 100% 260/260 [04:30<00:00,  1.04s/it, PPYoloELoss/loss=2.13, PPYoloELoss/loss_cls=1.09, PPYoloELoss/loss_dfl=1.23, PPYoloELoss/loss_iou=0.171, gpu_mem=4.54]
# Validation epoch 16: 100% 75/75 [00:22<00:00,  3.37it/s]
# ===========================================================
# SUMMARY OF EPOCH 16
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1297
# │   │   ├── Best until now = 2.1527 (↘ -0.023)
# │   │   └── Epoch N-1      = 2.1527 (↘ -0.023)
# │   ├── Ppyoloeloss/loss_cls = 1.0863
# │   │   ├── Best until now = 1.0974 (↘ -0.0111)
# │   │   └── Epoch N-1      = 1.0974 (↘ -0.0111)
# │   ├── Ppyoloeloss/loss_dfl = 1.2314
# │   │   ├── Best until now = 1.2423 (↘ -0.0109)
# │   │   └── Epoch N-1      = 1.2441 (↘ -0.0127)
# │   └── Ppyoloeloss/loss_iou = 0.1711
# │       ├── Best until now = 0.1733 (↘ -0.0022)
# │       └── Epoch N-1      = 0.1733 (↘ -0.0022)
# └── Validation
#     ├── F1@0.50 = 0.0382
#     │   ├── Best until now = 0.0928 (↘ -0.0546)
#     │   └── Epoch N-1      = 0.0567 (↘ -0.0185)
#     ├── Map@0.50 = 0.4079
#     │   ├── Best until now = 0.4595 (↘ -0.0516)
#     │   └── Epoch N-1      = 0.3702 (↗ 0.0378)
#     ├── Ppyoloeloss/loss = 2.0855
#     │   ├── Best until now = 1.9483 (↗ 0.1372)
#     │   └── Epoch N-1      = 2.11   (↘ -0.0245)
#     ├── Ppyoloeloss/loss_cls = 1.1713
#     │   ├── Best until now = 1.0579 (↗ 0.1134)
#     │   └── Epoch N-1      = 1.1922 (↘ -0.021)
#     ├── Ppyoloeloss/loss_dfl = 1.1208
#     │   ├── Best until now = 1.0499 (↗ 0.0709)
#     │   └── Epoch N-1      = 1.1304 (↘ -0.0096)
#     ├── Ppyoloeloss/loss_iou = 0.1415
#     │   ├── Best until now = 0.126  (↗ 0.0155)
#     │   └── Epoch N-1      = 0.141  (↗ 0.0005)
#     ├── Precision@0.50 = 0.0199
#     │   ├── Best until now = 0.0532 (↘ -0.0333)
#     │   └── Epoch N-1      = 0.0298 (↘ -0.01)
#     └── Recall@0.50 = 0.7778
#         ├── Best until now = 0.7815 (↘ -0.0036)
#         └── Epoch N-1      = 0.7745 (↗ 0.0033)
#
# ===========================================================
# Train epoch 17: 100% 260/260 [04:33<00:00,  1.05s/it, PPYoloELoss/loss=2.12, PPYoloELoss/loss_cls=1.08, PPYoloELoss/loss_dfl=1.22, PPYoloELoss/loss_iou=0.17, gpu_mem=4.55]
# Validation epoch 17: 100% 75/75 [00:21<00:00,  3.47it/s]
# ===========================================================
# SUMMARY OF EPOCH 17
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1172
# │   │   ├── Best until now = 2.1297 (↘ -0.0125)
# │   │   └── Epoch N-1      = 2.1297 (↘ -0.0125)
# │   ├── Ppyoloeloss/loss_cls = 1.0786
# │   │   ├── Best until now = 1.0863 (↘ -0.0077)
# │   │   └── Epoch N-1      = 1.0863 (↘ -0.0077)
# │   ├── Ppyoloeloss/loss_dfl = 1.2247
# │   │   ├── Best until now = 1.2314 (↘ -0.0066)
# │   │   └── Epoch N-1      = 1.2314 (↘ -0.0066)
# │   └── Ppyoloeloss/loss_iou = 0.1705
# │       ├── Best until now = 0.1711 (↘ -0.0006)
# │       └── Epoch N-1      = 0.1711 (↘ -0.0006)
# └── Validation
#     ├── F1@0.50 = 0.0586
#     │   ├── Best until now = 0.0928 (↘ -0.0342)
#     │   └── Epoch N-1      = 0.0382 (↗ 0.0203)
#     ├── Map@0.50 = 0.372
#     │   ├── Best until now = 0.4595 (↘ -0.0875)
#     │   └── Epoch N-1      = 0.4079 (↘ -0.0359)
#     ├── Ppyoloeloss/loss = 2.0859
#     │   ├── Best until now = 1.9483 (↗ 0.1376)
#     │   └── Epoch N-1      = 2.0855 (↗ 0.0004)
#     ├── Ppyoloeloss/loss_cls = 1.131
#     │   ├── Best until now = 1.0579 (↗ 0.0731)
#     │   └── Epoch N-1      = 1.1713 (↘ -0.0403)
#     ├── Ppyoloeloss/loss_dfl = 1.1607
#     │   ├── Best until now = 1.0499 (↗ 0.1108)
#     │   └── Epoch N-1      = 1.1208 (↗ 0.0399)
#     ├── Ppyoloeloss/loss_iou = 0.1498
#     │   ├── Best until now = 0.126  (↗ 0.0238)
#     │   └── Epoch N-1      = 0.1415 (↗ 0.0083)
#     ├── Precision@0.50 = 0.0311
#     │   ├── Best until now = 0.0532 (↘ -0.0221)
#     │   └── Epoch N-1      = 0.0199 (↗ 0.0113)
#     └── Recall@0.50 = 0.7023
#         ├── Best until now = 0.7815 (↘ -0.0791)
#         └── Epoch N-1      = 0.7778 (↘ -0.0755)
#
# ===========================================================
# Train epoch 18: 100% 260/260 [04:35<00:00,  1.06s/it, PPYoloELoss/loss=2.12, PPYoloELoss/loss_cls=1.08, PPYoloELoss/loss_dfl=1.23, PPYoloELoss/loss_iou=0.17, gpu_mem=4.55]
# Validation epoch 18: 100% 75/75 [00:21<00:00,  3.52it/s]
# ===========================================================
# SUMMARY OF EPOCH 18
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1242
# │   │   ├── Best until now = 2.1172 (↗ 0.007)
# │   │   └── Epoch N-1      = 2.1172 (↗ 0.007)
# │   ├── Ppyoloeloss/loss_cls = 1.0816
# │   │   ├── Best until now = 1.0786 (↗ 0.003)
# │   │   └── Epoch N-1      = 1.0786 (↗ 0.003)
# │   ├── Ppyoloeloss/loss_dfl = 1.2334
# │   │   ├── Best until now = 1.2247 (↗ 0.0086)
# │   │   └── Epoch N-1      = 1.2247 (↗ 0.0086)
# │   └── Ppyoloeloss/loss_iou = 0.1704
# │       ├── Best until now = 0.1705 (↘ -1e-04)
# │       └── Epoch N-1      = 0.1705 (↘ -1e-04)
# └── Validation
#     ├── F1@0.50 = 0.0395
#     │   ├── Best until now = 0.0928 (↘ -0.0532)
#     │   └── Epoch N-1      = 0.0586 (↘ -0.019)
#     ├── Map@0.50 = 0.4027
#     │   ├── Best until now = 0.4595 (↘ -0.0568)
#     │   └── Epoch N-1      = 0.372  (↗ 0.0307)
#     ├── Ppyoloeloss/loss = 1.9944
#     │   ├── Best until now = 1.9483 (↗ 0.0461)
#     │   └── Epoch N-1      = 2.0859 (↘ -0.0915)
#     ├── Ppyoloeloss/loss_cls = 1.1212
#     │   ├── Best until now = 1.0579 (↗ 0.0633)
#     │   └── Epoch N-1      = 1.131  (↘ -0.0097)
#     ├── Ppyoloeloss/loss_dfl = 1.0829
#     │   ├── Best until now = 1.0499 (↗ 0.033)
#     │   └── Epoch N-1      = 1.1607 (↘ -0.0778)
#     ├── Ppyoloeloss/loss_iou = 0.1327
#     │   ├── Best until now = 0.126  (↗ 0.0067)
#     │   └── Epoch N-1      = 0.1498 (↘ -0.0171)
#     ├── Precision@0.50 = 0.0204
#     │   ├── Best until now = 0.0532 (↘ -0.0328)
#     │   └── Epoch N-1      = 0.0311 (↘ -0.0107)
#     └── Recall@0.50 = 0.7842
#         ├── Best until now = 0.7815 (↗ 0.0027)
#         └── Epoch N-1      = 0.7023 (↗ 0.0818)
#
# ===========================================================
# Train epoch 19: 100% 260/260 [04:29<00:00,  1.04s/it, PPYoloELoss/loss=2.12, PPYoloELoss/loss_cls=1.08, PPYoloELoss/loss_dfl=1.23, PPYoloELoss/loss_iou=0.169, gpu_mem=4.53]
# Validation epoch 19: 100% 75/75 [00:21<00:00,  3.50it/s]
# ===========================================================
# SUMMARY OF EPOCH 19
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1196
# │   │   ├── Best until now = 2.1172 (↗ 0.0024)
# │   │   └── Epoch N-1      = 2.1242 (↘ -0.0046)
# │   ├── Ppyoloeloss/loss_cls = 1.0832
# │   │   ├── Best until now = 1.0786 (↗ 0.0046)
# │   │   └── Epoch N-1      = 1.0816 (↗ 0.0016)
# │   ├── Ppyoloeloss/loss_dfl = 1.2257
# │   │   ├── Best until now = 1.2247 (↗ 0.001)
# │   │   └── Epoch N-1      = 1.2334 (↘ -0.0077)
# │   └── Ppyoloeloss/loss_iou = 0.1694
# │       ├── Best until now = 0.1704 (↘ -0.0009)
# │       └── Epoch N-1      = 0.1704 (↘ -0.0009)
# └── Validation
#     ├── F1@0.50 = 0.0416
#     │   ├── Best until now = 0.0928 (↘ -0.0512)
#     │   └── Epoch N-1      = 0.0395 (↗ 0.002)
#     ├── Map@0.50 = 0.4347
#     │   ├── Best until now = 0.4595 (↘ -0.0248)
#     │   └── Epoch N-1      = 0.4027 (↗ 0.032)
#     ├── Ppyoloeloss/loss = 2.0016
#     │   ├── Best until now = 1.9483 (↗ 0.0533)
#     │   └── Epoch N-1      = 1.9944 (↗ 0.0072)
#     ├── Ppyoloeloss/loss_cls = 1.1369
#     │   ├── Best until now = 1.0579 (↗ 0.079)
#     │   └── Epoch N-1      = 1.1212 (↗ 0.0157)
#     ├── Ppyoloeloss/loss_dfl = 1.0717
#     │   ├── Best until now = 1.0499 (↗ 0.0219)
#     │   └── Epoch N-1      = 1.0829 (↘ -0.0112)
#     ├── Ppyoloeloss/loss_iou = 0.1316
#     │   ├── Best until now = 0.126  (↗ 0.0055)
#     │   └── Epoch N-1      = 0.1327 (↘ -0.0011)
#     ├── Precision@0.50 = 0.0216
#     │   ├── Best until now = 0.0532 (↘ -0.0315)
#     │   └── Epoch N-1      = 0.0204 (↗ 0.0012)
#     └── Recall@0.50 = 0.7732
#         ├── Best until now = 0.7842 (↘ -0.011)
#         └── Epoch N-1      = 0.7842 (↘ -0.011)
#
# ===========================================================
# Train epoch 20: 100% 260/260 [04:29<00:00,  1.03s/it, PPYoloELoss/loss=2.11, PPYoloELoss/loss_cls=1.07, PPYoloELoss/loss_dfl=1.23, PPYoloELoss/loss_iou=0.17, gpu_mem=4.46]
# Validation epoch 20: 100% 75/75 [00:23<00:00,  3.25it/s]
# ===========================================================
# SUMMARY OF EPOCH 20
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1107
# │   │   ├── Best until now = 2.1172 (↘ -0.0065)
# │   │   └── Epoch N-1      = 2.1196 (↘ -0.0089)
# │   ├── Ppyoloeloss/loss_cls = 1.0706
# │   │   ├── Best until now = 1.0786 (↘ -0.008)
# │   │   └── Epoch N-1      = 1.0832 (↘ -0.0126)
# │   ├── Ppyoloeloss/loss_dfl = 1.229
# │   │   ├── Best until now = 1.2247 (↗ 0.0043)
# │   │   └── Epoch N-1      = 1.2257 (↗ 0.0033)
# │   └── Ppyoloeloss/loss_iou = 0.1702
# │       ├── Best until now = 0.1694 (↗ 0.0008)
# │       └── Epoch N-1      = 0.1694 (↗ 0.0008)
# └── Validation
#     ├── F1@0.50 = 0.0569
#     │   ├── Best until now = 0.0928 (↘ -0.0359)
#     │   └── Epoch N-1      = 0.0416 (↗ 0.0153)
#     ├── Map@0.50 = 0.4147
#     │   ├── Best until now = 0.4595 (↘ -0.0448)
#     │   └── Epoch N-1      = 0.4347 (↘ -0.02)
#     ├── Ppyoloeloss/loss = 1.9229
#     │   ├── Best until now = 1.9483 (↘ -0.0255)
#     │   └── Epoch N-1      = 2.0016 (↘ -0.0788)
#     ├── Ppyoloeloss/loss_cls = 1.0538
#     │   ├── Best until now = 1.0579 (↘ -0.004)
#     │   └── Epoch N-1      = 1.1369 (↘ -0.083)
#     ├── Ppyoloeloss/loss_dfl = 1.0713
#     │   ├── Best until now = 1.0499 (↗ 0.0214)
#     │   └── Epoch N-1      = 1.0717 (↘ -0.0004)
#     ├── Ppyoloeloss/loss_iou = 0.1334
#     │   ├── Best until now = 0.126  (↗ 0.0074)
#     │   └── Epoch N-1      = 0.1316 (↗ 0.0018)
#     ├── Precision@0.50 = 0.03
#     │   ├── Best until now = 0.0532 (↘ -0.0232)
#     │   └── Epoch N-1      = 0.0216 (↗ 0.0084)
#     └── Recall@0.50 = 0.7163
#         ├── Best until now = 0.7842 (↘ -0.0679)
#         └── Epoch N-1      = 0.7732 (↘ -0.0569)
#
# ===========================================================
# Train epoch 21: 100% 260/260 [04:27<00:00,  1.03s/it, PPYoloELoss/loss=2.11, PPYoloELoss/loss_cls=1.07, PPYoloELoss/loss_dfl=1.22, PPYoloELoss/loss_iou=0.169, gpu_mem=4.54]
# Validation epoch 21: 100% 75/75 [00:21<00:00,  3.50it/s]
# ===========================================================
# SUMMARY OF EPOCH 21
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.1072
# │   │   ├── Best until now = 2.1107 (↘ -0.0035)
# │   │   └── Epoch N-1      = 2.1107 (↘ -0.0035)
# │   ├── Ppyoloeloss/loss_cls = 1.0731
# │   │   ├── Best until now = 1.0706 (↗ 0.0025)
# │   │   └── Epoch N-1      = 1.0706 (↗ 0.0025)
# │   ├── Ppyoloeloss/loss_dfl = 1.2224
# │   │   ├── Best until now = 1.2247 (↘ -0.0024)
# │   │   └── Epoch N-1      = 1.229  (↘ -0.0066)
# │   └── Ppyoloeloss/loss_iou = 0.1692
# │       ├── Best until now = 0.1694 (↘ -0.0003)
# │       └── Epoch N-1      = 0.1702 (↘ -0.0011)
# └── Validation
#     ├── F1@0.50 = 0.0592
#     │   ├── Best until now = 0.0928 (↘ -0.0336)
#     │   └── Epoch N-1      = 0.0569 (↗ 0.0024)
#     ├── Map@0.50 = 0.4579
#     │   ├── Best until now = 0.4595 (↘ -0.0016)
#     │   └── Epoch N-1      = 0.4147 (↗ 0.0431)
#     ├── Ppyoloeloss/loss = 1.9576
#     │   ├── Best until now = 1.9229 (↗ 0.0347)
#     │   └── Epoch N-1      = 1.9229 (↗ 0.0347)
#     ├── Ppyoloeloss/loss_cls = 1.102
#     │   ├── Best until now = 1.0538 (↗ 0.0481)
#     │   └── Epoch N-1      = 1.0538 (↗ 0.0481)
#     ├── Ppyoloeloss/loss_dfl = 1.0521
#     │   ├── Best until now = 1.0499 (↗ 0.0022)
#     │   └── Epoch N-1      = 1.0713 (↘ -0.0192)
#     ├── Ppyoloeloss/loss_iou = 0.1318
#     │   ├── Best until now = 0.126  (↗ 0.0058)
#     │   └── Epoch N-1      = 0.1334 (↘ -0.0015)
#     ├── Precision@0.50 = 0.0316
#     │   ├── Best until now = 0.0532 (↘ -0.0216)
#     │   └── Epoch N-1      = 0.03   (↗ 0.0016)
#     └── Recall@0.50 = 0.8083
#         ├── Best until now = 0.7842 (↗ 0.0241)
#         └── Epoch N-1      = 0.7163 (↗ 0.092)
#
# ===========================================================
# Train epoch 22: 100% 260/260 [04:32<00:00,  1.05s/it, PPYoloELoss/loss=2.07, PPYoloELoss/loss_cls=1.05, PPYoloELoss/loss_dfl=1.21, PPYoloELoss/loss_iou=0.166, gpu_mem=4.5]
# Validation epoch 22: 100% 75/75 [00:21<00:00,  3.41it/s]
# ===========================================================
# SUMMARY OF EPOCH 22
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.0734
# │   │   ├── Best until now = 2.1072 (↘ -0.0338)
# │   │   └── Epoch N-1      = 2.1072 (↘ -0.0338)
# │   ├── Ppyoloeloss/loss_cls = 1.0543
# │   │   ├── Best until now = 1.0706 (↘ -0.0163)
# │   │   └── Epoch N-1      = 1.0731 (↘ -0.0188)
# │   ├── Ppyoloeloss/loss_dfl = 1.2091
# │   │   ├── Best until now = 1.2224 (↘ -0.0132)
# │   │   └── Epoch N-1      = 1.2224 (↘ -0.0132)
# │   └── Ppyoloeloss/loss_iou = 0.1658
# │       ├── Best until now = 0.1692 (↘ -0.0033)
# │       └── Epoch N-1      = 0.1692 (↘ -0.0033)
# └── Validation
#     ├── F1@0.50 = 0.0496
#     │   ├── Best until now = 0.0928 (↘ -0.0432)
#     │   └── Epoch N-1      = 0.0592 (↘ -0.0096)
#     ├── Map@0.50 = 0.3602
#     │   ├── Best until now = 0.4595 (↘ -0.0993)
#     │   └── Epoch N-1      = 0.4579 (↘ -0.0976)
#     ├── Ppyoloeloss/loss = 2.0628
#     │   ├── Best until now = 1.9229 (↗ 0.1399)
#     │   └── Epoch N-1      = 1.9576 (↗ 0.1051)
#     ├── Ppyoloeloss/loss_cls = 1.1714
#     │   ├── Best until now = 1.0538 (↗ 0.1175)
#     │   └── Epoch N-1      = 1.102  (↗ 0.0694)
#     ├── Ppyoloeloss/loss_dfl = 1.0986
#     │   ├── Best until now = 1.0499 (↗ 0.0488)
#     │   └── Epoch N-1      = 1.0521 (↗ 0.0465)
#     ├── Ppyoloeloss/loss_iou = 0.1368
#     │   ├── Best until now = 0.126  (↗ 0.0108)
#     │   └── Epoch N-1      = 0.1318 (↗ 0.005)
#     ├── Precision@0.50 = 0.0262
#     │   ├── Best until now = 0.0532 (↘ -0.027)
#     │   └── Epoch N-1      = 0.0316 (↘ -0.0054)
#     └── Recall@0.50 = 0.7683
#         ├── Best until now = 0.8083 (↘ -0.0399)
#         └── Epoch N-1      = 0.8083 (↘ -0.0399)
#
# ===========================================================
# Train epoch 23: 100% 260/260 [04:32<00:00,  1.05s/it, PPYoloELoss/loss=2.06, PPYoloELoss/loss_cls=1.05, PPYoloELoss/loss_dfl=1.21, PPYoloELoss/loss_iou=0.166, gpu_mem=4.53]
# Validation epoch 23: 100% 75/75 [00:22<00:00,  3.34it/s]
# ...
# │   ├── Ppyoloeloss/loss = 2.0653
# │   │   ├── Best until now = 2.0637 (↗ 0.0016)
# │   │   └── Epoch N-1      = 2.0637 (↗ 0.0016)
# │   ├── Ppyoloeloss/loss_cls = 1.0468
# │   │   ├── Best until now = 1.0462 (↗ 0.0006)
# │   │   └── Epoch N-1      = 1.0462 (↗ 0.0006)
# │   ├── Ppyoloeloss/loss_dfl = 1.2055
# │   │   ├── Best until now = 1.2064 (↘ -0.0009)
# │   │   └── Epoch N-1      = 1.2064 (↘ -0.0009)
# │   └── Ppyoloeloss/loss_iou = 0.1663
# │       ├── Best until now = 0.1657 (↗ 0.0006)
# │       └── Epoch N-1      = 0.1657 (↗ 0.0006)
# └── Validation
#     ├── F1@0.50 = 0.0534
#     │   ├── Best until now = 0.0928 (↘ -0.0394)
#     │   └── Epoch N-1      = 0.0517 (↗ 0.0017)
#     ├── Map@0.50 = 0.4509
#     │   ├── Best until now = 0.4595 (↘ -0.0086)
#     │   └── Epoch N-1      = 0.4131 (↗ 0.0378)
#     ├── Ppyoloeloss/loss = 1.9425
#     │   ├── Best until now = 1.9229 (↗ 0.0196)
#     │   └── Epoch N-1      = 1.9655 (↘ -0.023)
#     ├── Ppyoloeloss/loss_cls = 1.0541
#     │   ├── Best until now = 1.0538 (↗ 0.0003)
#     │   └── Epoch N-1      = 1.1214 (↘ -0.0673)
#     ├── Ppyoloeloss/loss_dfl = 1.0964
#     │   ├── Best until now = 1.0499 (↗ 0.0466)
#     │   └── Epoch N-1      = 1.0558 (↗ 0.0407)
#     ├── Ppyoloeloss/loss_iou = 0.1361
#     │   ├── Best until now = 0.126  (↗ 0.01)
#     │   └── Epoch N-1      = 0.1265 (↗ 0.0096)
#     ├── Precision@0.50 = 0.0282
#     │   ├── Best until now = 0.0532 (↘ -0.0249)
#     │   └── Epoch N-1      = 0.0275 (↗ 0.0007)
#     └── Recall@0.50 = 0.7849
#         ├── Best until now = 0.8083 (↘ -0.0233)
#         └── Epoch N-1      = 0.7907 (↘ -0.0058)
#
# ===========================================================
# Train epoch 25: 100% 260/260 [04:25<00:00,  1.02s/it, PPYoloELoss/loss=2.08, PPYoloELoss/loss_cls=1.05, PPYoloELoss/loss_dfl=1.22, PPYoloELoss/loss_iou=0.167, gpu_mem=4.53]
# Validation epoch 25: 100% 75/75 [00:21<00:00,  3.51it/s]
# ===========================================================
# SUMMARY OF EPOCH 25
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.0767
# │   │   ├── Best until now = 2.0637 (↗ 0.013)
# │   │   └── Epoch N-1      = 2.0653 (↗ 0.0114)
# │   ├── Ppyoloeloss/loss_cls = 1.0517
# │   │   ├── Best until now = 1.0462 (↗ 0.0055)
# │   │   └── Epoch N-1      = 1.0468 (↗ 0.005)
# │   ├── Ppyoloeloss/loss_dfl = 1.2152
# │   │   ├── Best until now = 1.2055 (↗ 0.0097)
# │   │   └── Epoch N-1      = 1.2055 (↗ 0.0097)
# │   └── Ppyoloeloss/loss_iou = 0.1669
# │       ├── Best until now = 0.1657 (↗ 0.0012)
# │       └── Epoch N-1      = 0.1663 (↗ 0.0006)
# └── Validation
#     ├── F1@0.50 = 0.0628
#     │   ├── Best until now = 0.0928 (↘ -0.03)
#     │   └── Epoch N-1      = 0.0534 (↗ 0.0094)
#     ├── Map@0.50 = 0.4203
#     │   ├── Best until now = 0.4595 (↘ -0.0392)
#     │   └── Epoch N-1      = 0.4509 (↘ -0.0305)
#     ├── Ppyoloeloss/loss = 1.9681
#     │   ├── Best until now = 1.9229 (↗ 0.0452)
#     │   └── Epoch N-1      = 1.9425 (↗ 0.0257)
#     ├── Ppyoloeloss/loss_cls = 1.1026
#     │   ├── Best until now = 1.0538 (↗ 0.0488)
#     │   └── Epoch N-1      = 1.0541 (↗ 0.0485)
#     ├── Ppyoloeloss/loss_dfl = 1.0775
#     │   ├── Best until now = 1.0499 (↗ 0.0276)
#     │   └── Epoch N-1      = 1.0964 (↘ -0.0189)
#     ├── Ppyoloeloss/loss_iou = 0.1307
#     │   ├── Best until now = 0.126  (↗ 0.0047)
#     │   └── Epoch N-1      = 0.1361 (↘ -0.0053)
#     ├── Precision@0.50 = 0.0336
#     │   ├── Best until now = 0.0532 (↘ -0.0196)
#     │   └── Epoch N-1      = 0.0282 (↗ 0.0053)
#     └── Recall@0.50 = 0.7906
#         ├── Best until now = 0.8083 (↘ -0.0177)
#         └── Epoch N-1      = 0.7849 (↗ 0.0056)
#
# ===========================================================
# Train epoch 26: 100% 260/260 [04:27<00:00,  1.03s/it, PPYoloELoss/loss=2.04, PPYoloELoss/loss_cls=1.03, PPYoloELoss/loss_dfl=1.2, PPYoloELoss/loss_iou=0.164, gpu_mem=4.5]
# Validation epoch 26: 100% 75/75 [00:22<00:00,  3.34it/s]
# ===========================================================
# SUMMARY OF EPOCH 26
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.042
# │   │   ├── Best until now = 2.0637 (↘ -0.0217)
# │   │   └── Epoch N-1      = 2.0767 (↘ -0.0346)
# │   ├── Ppyoloeloss/loss_cls = 1.0344
# │   │   ├── Best until now = 1.0462 (↘ -0.0118)
# │   │   └── Epoch N-1      = 1.0517 (↘ -0.0173)
# │   ├── Ppyoloeloss/loss_dfl = 1.1969
# │   │   ├── Best until now = 1.2055 (↘ -0.0086)
# │   │   └── Epoch N-1      = 1.2152 (↘ -0.0183)
# │   └── Ppyoloeloss/loss_iou = 0.1637
# │       ├── Best until now = 0.1657 (↘ -0.002)
# │       └── Epoch N-1      = 0.1669 (↘ -0.0033)
# └── Validation
#     ├── F1@0.50 = 0.0602
#     │   ├── Best until now = 0.0928 (↘ -0.0326)
#     │   └── Epoch N-1      = 0.0628 (↘ -0.0026)
#     ├── Map@0.50 = 0.4375
#     │   ├── Best until now = 0.4595 (↘ -0.022)
#     │   └── Epoch N-1      = 0.4203 (↗ 0.0172)
#     ├── Ppyoloeloss/loss = 1.9796
#     │   ├── Best until now = 1.9229 (↗ 0.0568)
#     │   └── Epoch N-1      = 1.9681 (↗ 0.0115)
#     ├── Ppyoloeloss/loss_cls = 1.106
#     │   ├── Best until now = 1.0538 (↗ 0.0522)
#     │   └── Epoch N-1      = 1.1026 (↗ 0.0034)
#     ├── Ppyoloeloss/loss_dfl = 1.0783
#     │   ├── Best until now = 1.0499 (↗ 0.0284)
#     │   └── Epoch N-1      = 1.0775 (↗ 0.0007)
#     ├── Ppyoloeloss/loss_iou = 0.1338
#     │   ├── Best until now = 0.126  (↗ 0.0078)
#     │   └── Epoch N-1      = 0.1307 (↗ 0.0031)
#     ├── Precision@0.50 = 0.0352
#     │   ├── Best until now = 0.0532 (↘ -0.0179)
#     │   └── Epoch N-1      = 0.0336 (↗ 0.0017)
#     └── Recall@0.50 = 0.7473
#         ├── Best until now = 0.8083 (↘ -0.061)
#         └── Epoch N-1      = 0.7906 (↘ -0.0433)
#
# ===========================================================
# Train epoch 27: 100% 260/260 [04:29<00:00,  1.04s/it, PPYoloELoss/loss=2.04, PPYoloELoss/loss_cls=1.03, PPYoloELoss/loss_dfl=1.19, PPYoloELoss/loss_iou=0.163, gpu_mem=4.5]
# Validation epoch 27: 100% 75/75 [00:21<00:00,  3.50it/s]
# ===========================================================
# SUMMARY OF EPOCH 27
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.0397
# │   │   ├── Best until now = 2.042  (↘ -0.0023)
# │   │   └── Epoch N-1      = 2.042  (↘ -0.0023)
# │   ├── Ppyoloeloss/loss_cls = 1.0349
# │   │   ├── Best until now = 1.0344 (↗ 0.0005)
# │   │   └── Epoch N-1      = 1.0344 (↗ 0.0005)
# │   ├── Ppyoloeloss/loss_dfl = 1.1934
# │   │   ├── Best until now = 1.1969 (↘ -0.0035)
# │   │   └── Epoch N-1      = 1.1969 (↘ -0.0035)
# │   └── Ppyoloeloss/loss_iou = 0.1633
# │       ├── Best until now = 0.1637 (↘ -0.0004)
# │       └── Epoch N-1      = 0.1637 (↘ -0.0004)
# └── Validation
#     ├── F1@0.50 = 0.0406
#     │   ├── Best until now = 0.0928 (↘ -0.0522)
#     │   └── Epoch N-1      = 0.0602 (↘ -0.0196)
#     ├── Map@0.50 = 0.3664
#     │   ├── Best until now = 0.4595 (↘ -0.0931)
#     │   └── Epoch N-1      = 0.4375 (↘ -0.0711)
#     ├── Ppyoloeloss/loss = 2.2786
#     │   ├── Best until now = 1.9229 (↗ 0.3557)
#     │   └── Epoch N-1      = 1.9796 (↗ 0.2989)
#     ├── Ppyoloeloss/loss_cls = 1.3078
#     │   ├── Best until now = 1.0538 (↗ 0.254)
#     │   └── Epoch N-1      = 1.106  (↗ 0.2018)
#     ├── Ppyoloeloss/loss_dfl = 1.184
#     │   ├── Best until now = 1.0499 (↗ 0.1341)
#     │   └── Epoch N-1      = 1.0783 (↗ 0.1057)
#     ├── Ppyoloeloss/loss_iou = 0.1515
#     │   ├── Best until now = 0.126  (↗ 0.0255)
#     │   └── Epoch N-1      = 0.1338 (↗ 0.0177)
#     ├── Precision@0.50 = 0.021
#     │   ├── Best until now = 0.0532 (↘ -0.0322)
#     │   └── Epoch N-1      = 0.0352 (↘ -0.0142)
#     └── Recall@0.50 = 0.7439
#         ├── Best until now = 0.8083 (↘ -0.0643)
#         └── Epoch N-1      = 0.7473 (↘ -0.0033)
#
# ===========================================================
# Train epoch 28: 100% 260/260 [04:28<00:00,  1.03s/it, PPYoloELoss/loss=2.03, PPYoloELoss/loss_cls=1.03, PPYoloELoss/loss_dfl=1.18, PPYoloELoss/loss_iou=0.163, gpu_mem=4.53]
# Validation epoch 28: 100% 75/75 [00:21<00:00,  3.52it/s]
# ===========================================================
# SUMMARY OF EPOCH 28
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.0256
# │   │   ├── Best until now = 2.0397 (↘ -0.0141)
# │   │   └── Epoch N-1      = 2.0397 (↘ -0.0141)
# │   ├── Ppyoloeloss/loss_cls = 1.0254
# │   │   ├── Best until now = 1.0344 (↘ -0.009)
# │   │   └── Epoch N-1      = 1.0349 (↘ -0.0095)
# │   ├── Ppyoloeloss/loss_dfl = 1.1845
# │   │   ├── Best until now = 1.1934 (↘ -0.0089)
# │   │   └── Epoch N-1      = 1.1934 (↘ -0.0089)
# │   └── Ppyoloeloss/loss_iou = 0.1632
# │       ├── Best until now = 0.1633 (↘ -1e-04)
# │       └── Epoch N-1      = 0.1633 (↘ -1e-04)
# └── Validation
#     ├── F1@0.50 = 0.0445
#     │   ├── Best until now = 0.0928 (↘ -0.0483)
#     │   └── Epoch N-1      = 0.0406 (↗ 0.0039)
#     ├── Map@0.50 = 0.3988
#     │   ├── Best until now = 0.4595 (↘ -0.0607)
#     │   └── Epoch N-1      = 0.3664 (↗ 0.0325)
#     ├── Ppyoloeloss/loss = 2.0143
#     │   ├── Best until now = 1.9229 (↗ 0.0915)
#     │   └── Epoch N-1      = 2.2786 (↘ -0.2642)
#     ├── Ppyoloeloss/loss_cls = 1.1794
#     │   ├── Best until now = 1.0538 (↗ 0.1256)
#     │   └── Epoch N-1      = 1.3078 (↘ -0.1284)
#     ├── Ppyoloeloss/loss_dfl = 1.0402
#     │   ├── Best until now = 1.0499 (↘ -0.0097)
#     │   └── Epoch N-1      = 1.184  (↘ -0.1438)
#     ├── Ppyoloeloss/loss_iou = 0.1259
#     │   ├── Best until now = 0.126  (↘ -1e-04)
#     │   └── Epoch N-1      = 0.1515 (↘ -0.0256)
#     ├── Precision@0.50 = 0.0235
#     │   ├── Best until now = 0.0532 (↘ -0.0297)
#     │   └── Epoch N-1      = 0.021  (↗ 0.0025)
#     └── Recall@0.50 = 0.7367
#         ├── Best until now = 0.8083 (↘ -0.0715)
#         └── Epoch N-1      = 0.7439 (↘ -0.0072)
#
# ===========================================================
# Train epoch 29: 100% 260/260 [04:28<00:00,  1.03s/it, PPYoloELoss/loss=2.02, PPYoloELoss/loss_cls=1.02, PPYoloELoss/loss_dfl=1.19, PPYoloELoss/loss_iou=0.162, gpu_mem=4.5]
# Validation epoch 29: 100% 75/75 [00:23<00:00,  3.23it/s]
# ===========================================================
# SUMMARY OF EPOCH 29
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.0224
# │   │   ├── Best until now = 2.0256 (↘ -0.0032)
# │   │   └── Epoch N-1      = 2.0256 (↘ -0.0032)
# │   ├── Ppyoloeloss/loss_cls = 1.0238
# │   │   ├── Best until now = 1.0254 (↘ -0.0016)
# │   │   └── Epoch N-1      = 1.0254 (↘ -0.0016)
# │   ├── Ppyoloeloss/loss_dfl = 1.1882
# │   │   ├── Best until now = 1.1845 (↗ 0.0037)
# │   │   └── Epoch N-1      = 1.1845 (↗ 0.0037)
# │   └── Ppyoloeloss/loss_iou = 0.1618
# │       ├── Best until now = 0.1632 (↘ -0.0014)
# │       └── Epoch N-1      = 0.1632 (↘ -0.0014)
# └── Validation
#     ├── F1@0.50 = 0.0623
#     │   ├── Best until now = 0.0928 (↘ -0.0304)
#     │   └── Epoch N-1      = 0.0445 (↗ 0.0178)
#     ├── Map@0.50 = 0.4264
#     │   ├── Best until now = 0.4595 (↘ -0.0331)
#     │   └── Epoch N-1      = 0.3988 (↗ 0.0276)
#     ├── Ppyoloeloss/loss = 1.9416
#     │   ├── Best until now = 1.9229 (↗ 0.0187)
#     │   └── Epoch N-1      = 2.0143 (↘ -0.0728)
#     ├── Ppyoloeloss/loss_cls = 1.0691
#     │   ├── Best until now = 1.0538 (↗ 0.0153)
#     │   └── Epoch N-1      = 1.1794 (↘ -0.1103)
#     ├── Ppyoloeloss/loss_dfl = 1.0731
#     │   ├── Best until now = 1.0402 (↗ 0.0329)
#     │   └── Epoch N-1      = 1.0402 (↗ 0.0329)
#     ├── Ppyoloeloss/loss_iou = 0.1344
#     │   ├── Best until now = 0.1259 (↗ 0.0084)
#     │   └── Epoch N-1      = 0.1259 (↗ 0.0084)
#     ├── Precision@0.50 = 0.0333
#     │   ├── Best until now = 0.0532 (↘ -0.0199)
#     │   └── Epoch N-1      = 0.0235 (↗ 0.0098)
#     └── Recall@0.50 = 0.7578
#         ├── Best until now = 0.8083 (↘ -0.0504)
#         └── Epoch N-1      = 0.7367 (↗ 0.0211)
#
# ===========================================================
# Train epoch 30: 100% 260/260 [04:27<00:00,  1.03s/it, PPYoloELoss/loss=2.01, PPYoloELoss/loss_cls=1.01, PPYoloELoss/loss_dfl=1.18, PPYoloELoss/loss_iou=0.163, gpu_mem=4.54]
# Validation epoch 30: 100% 75/75 [00:21<00:00,  3.46it/s]
# ===========================================================
# SUMMARY OF EPOCH 30
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.0107
# │   │   ├── Best until now = 2.0224 (↘ -0.0117)
# │   │   └── Epoch N-1      = 2.0224 (↘ -0.0117)
# │   ├── Ppyoloeloss/loss_cls = 1.0142
# │   │   ├── Best until now = 1.0238 (↘ -0.0096)
# │   │   └── Epoch N-1      = 1.0238 (↘ -0.0096)
# │   ├── Ppyoloeloss/loss_dfl = 1.1799
# │   │   ├── Best until now = 1.1845 (↘ -0.0045)
# │   │   └── Epoch N-1      = 1.1882 (↘ -0.0083)
# │   └── Ppyoloeloss/loss_iou = 0.1626
# │       ├── Best until now = 0.1618 (↗ 0.0008)
# │       └── Epoch N-1      = 0.1618 (↗ 0.0008)
# └── Validation
#     ├── F1@0.50 = 0.055
#     │   ├── Best until now = 0.0928 (↘ -0.0378)
#     │   └── Epoch N-1      = 0.0623 (↘ -0.0073)
#     ├── Map@0.50 = 0.4135
#     │   ├── Best until now = 0.4595 (↘ -0.046)
#     │   └── Epoch N-1      = 0.4264 (↘ -0.0129)
#     ├── Ppyoloeloss/loss = 2.019
#     │   ├── Best until now = 1.9229 (↗ 0.0961)
#     │   └── Epoch N-1      = 1.9416 (↗ 0.0774)
#     ├── Ppyoloeloss/loss_cls = 1.1504
#     │   ├── Best until now = 1.0538 (↗ 0.0966)
#     │   └── Epoch N-1      = 1.0691 (↗ 0.0813)
#     ├── Ppyoloeloss/loss_dfl = 1.0716
#     │   ├── Best until now = 1.0402 (↗ 0.0314)
#     │   └── Epoch N-1      = 1.0731 (↘ -0.0015)
#     ├── Ppyoloeloss/loss_iou = 0.1331
#     │   ├── Best until now = 0.1259 (↗ 0.0072)
#     │   └── Epoch N-1      = 0.1344 (↘ -0.0013)
#     ├── Precision@0.50 = 0.0292
#     │   ├── Best until now = 0.0532 (↘ -0.024)
#     │   └── Epoch N-1      = 0.0333 (↘ -0.0041)
#     └── Recall@0.50 = 0.8127
#         ├── Best until now = 0.8083 (↗ 0.0044)
#         └── Epoch N-1      = 0.7578 (↗ 0.0549)
#
# ===========================================================
# Train epoch 31: 100% 260/260 [04:28<00:00,  1.03s/it, PPYoloELoss/loss=1.99, PPYoloELoss/loss_cls=1, PPYoloELoss/loss_dfl=1.17, PPYoloELoss/loss_iou=0.161, gpu_mem=4.46]
# Validation epoch 31: 100% 75/75 [00:21<00:00,  3.47it/s]
# ===========================================================
# SUMMARY OF EPOCH 31
# ├── Training
# │   ├── Ppyoloeloss/loss = 1.9927
# │   │   ├── Best until now = 2.0107 (↘ -0.0181)
# │   │   └── Epoch N-1      = 2.0107 (↘ -0.0181)
# │   ├── Ppyoloeloss/loss_cls = 1.0048
# │   │   ├── Best until now = 1.0142 (↘ -0.0094)
# │   │   └── Epoch N-1      = 1.0142 (↘ -0.0094)
# │   ├── Ppyoloeloss/loss_dfl = 1.1719
# │   │   ├── Best until now = 1.1799 (↘ -0.0081)
# │   │   └── Epoch N-1      = 1.1799 (↘ -0.0081)
# │   └── Ppyoloeloss/loss_iou = 0.1608
# │       ├── Best until now = 0.1618 (↘ -0.001)
# │       └── Epoch N-1      = 0.1626 (↘ -0.0019)
# └── Validation
#     ├── F1@0.50 = 0.0481
#     │   ├── Best until now = 0.0928 (↘ -0.0447)
#     │   └── Epoch N-1      = 0.055  (↘ -0.0069)
#     ├── Map@0.50 = 0.418
#     │   ├── Best until now = 0.4595 (↘ -0.0415)
#     │   └── Epoch N-1      = 0.4135 (↗ 0.0045)
#     ├── Ppyoloeloss/loss = 2.0369
#     │   ├── Best until now = 1.9229 (↗ 0.114)
#     │   └── Epoch N-1      = 2.019  (↗ 0.0179)
#     ├── Ppyoloeloss/loss_cls = 1.1254
#     │   ├── Best until now = 1.0538 (↗ 0.0715)
#     │   └── Epoch N-1      = 1.1504 (↘ -0.025)
#     ├── Ppyoloeloss/loss_dfl = 1.1059
#     │   ├── Best until now = 1.0402 (↗ 0.0657)
#     │   └── Epoch N-1      = 1.0716 (↗ 0.0344)
#     ├── Ppyoloeloss/loss_iou = 0.1434
#     │   ├── Best until now = 0.1259 (↗ 0.0175)
#     │   └── Epoch N-1      = 0.1331 (↗ 0.0103)
#     ├── Precision@0.50 = 0.0256
#     │   ├── Best until now = 0.0532 (↘ -0.0276)
#     │   └── Epoch N-1      = 0.0292 (↘ -0.0036)
#     └── Recall@0.50 = 0.8056
#         ├── Best until now = 0.8127 (↘ -0.0071)
#         └── Epoch N-1      = 0.8127 (↘ -0.0071)
#
# ===========================================================
# Train epoch 32:  98% 256/260 [04:25<00:04,  1.04s/it, PPYoloELoss/loss=1.99, PPYoloELoss/loss_cls=1, PPYoloELoss/loss_dfl=1.17, PPYoloELoss/loss_iou=0.16, gpu_mem=4.54]
# [2023-06-10 17:55:16] INFO - sg_trainer.py -
# [MODEL TRAINING EXECUTION HAS BEEN INTERRUPTED]... Please wait until SOFT-TERMINATION process finishes and saves all of the Model Checkpoints and log files before terminating...
# [2023-06-10 17:55:16] INFO - sg_trainer.py - For HARD Termination - Stop the process again
# [2023-06-10 17:55:16] INFO - base_sg_logger.py - [CLEANUP] - Successfully stopped system monitoring process
# [2023-06-10 17:55:21] INFO - checkpoint_utils.py - Successfully loaded model weights from runs/train2/ckpt_best.pth EMA checkpoint.
# Test:  23% 17/75 [00:04<00:14,  3.95it/s]^C
