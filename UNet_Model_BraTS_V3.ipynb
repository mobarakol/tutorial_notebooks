# %% [markdown]
# <a href="https://colab.research.google.com/github/mobarakol/tutorial_notebooks/blob/main/UNet_Model_BraTS_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Medical Image Segmentation with U-NET

# %%
# Import libraries
import tarfile
import re
import imageio.v2 as iio
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
import numpy as np
import time
import os
import random
import matplotlib.pyplot as plt
from matplotlib import colors
import scipy.ndimage
import textwrap

# %% [markdown]
# ## Download the imaging dataset

# %%
# !gdown https://drive.google.com/uc?id=1nHZWlCBpudbT4zzPyqyu2Vi5uILcxSrv

# Assuming the downloaded file is a ZIP file and its name is 'downloaded_data.zip'
import zipfile
with zipfile.ZipFile('Slices.zip', 'r') as zip_ref:
    zip_ref.extractall()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1nHZWlCBpudbT4zzPyqyu2Vi5uILcxSrv
# To: /content/Slices.zip
# 100% 56.1M/56.1M [00:00<00:00, 83.4MB/s]

# %% [markdown]
# # Implement a dataset class
#
# It can read the imaging dataset and get items, pairs of images and label maps, as training batches.

# %%
def normalise_intensity(image, ROI_thres=0.1):
    """
    The function identifies the ROI in the image by applying a percentile-based threshold,
    then standardizes the pixel values in this region by subtracting the mean and dividing
    by the standard deviation.

    Args:
        image (np.array): Input image as a NumPy array.
        ROI_thres (float): Percentile threshold for defining the ROI (default is 0.1).

    Returns:
        np.array: Image array with normalized intensity in the ROI.
    """
    pixel_thres = np.percentile(image, ROI_thres)
    ROI = np.where(image > pixel_thres, image, 0) # If image value is greater than pixel threshold, return image value, otherwise return 0
    mean = np.mean(ROI)
    std = np.std(ROI)
    ROI_norm = (ROI - mean) / (std + 1e-8) # Normalise ROI
    return ROI_norm

def sort_key(filename):
    """ Extracts the numerical part from the filename and returns it for sorting. """
    numbers = re.findall(r'\d+', filename)
    return int(numbers[-1]) if numbers else filename

class BrainImageSet():
    def __init__(self, image_path, label_path, modality, deploy=False, train_ratio=0.75):
        self.image_path = image_path
        self.label_path = label_path
        self.deploy = deploy
        self.images = []
        self.labels = []
        self.image_names = []  # Store image names
        self.label_names = []  # Store label names

        image_names = sorted(os.listdir(image_path), key=sort_key)
        for image_name in image_names:
            patient_id = image_name.split('-')[2]  # Extract patient ID from filename
            idx = len(self.images)

            full_image_path = os.path.join(image_path, image_name)
            image = iio.imread(full_image_path)
            self.images.append(image)
            self.image_names.append(image_name)

            if not deploy:
                label_name = image_name.replace(modality, 'seg')
                full_label_path = os.path.join(label_path, label_name)
                label = iio.imread(full_label_path)
                self.labels.append(label)
                self.label_names.append(label_name)

    def map_labels(self, label):
        """
        Maps label values to the correct class indices.
        """
        label_map = {0: 0, 85: 1, 170: 2, 255: 3}
        mapped_label = label.copy()
        for k, v in label_map.items():
            mapped_label[label == k] = v
        return mapped_label

    def __len__(self):
      return len(self.image_names)

    def __getitem__(self, idx):
        # Get an image and perform intensity normalisation
        image = normalise_intensity(self.images[idx])

        # Get its label map
        label = self.labels[idx]
        label = self.map_labels(label)

        return image, label

    def get_random_batch(self, batch_size):
        # Get a batch of paired images and label maps
        images_batch, labels_batch = [], []

        idx_array = range(0, len(self.images)) # Creates an array of indices ranging from 0 to len(self.images)
        batch_idx = random.sample(idx_array, batch_size) # Randomly selects a batch_size number of indices
        for i in range(batch_size):
            image, label = self.__getitem__(batch_idx[i])
            images_batch.append(image)
            labels_batch.append(label)

        images_batch, labels_batch = np.array(images_batch), np.array(labels_batch)
        images_batch = np.expand_dims(images_batch, 1)
        return images_batch, labels_batch

# %% [markdown]
# # Build a U-net architecture
#
# You will implement a U-net architecture. If you are not familiar with U-net, please read this paper:
#
# [1] Olaf Ronneberger et al. [U-Net: Convolutional networks for biomedical image segmentation](https://link.springer.com/chapter/10.1007/978-3-319-24574-4_28). MICCAI, 2015.

# %%
class conv_block(nn.Module):
  def __init__(self, in_channels, out_channels, stride=1):
    super().__init__()
    # Convolution layer, a ReLU activation to add non-linearity, and Batch Normalisation
    # Bias is set as false, as Batch Normalisation would remove the bias
    self.conv = nn.Sequential(
        nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1),
        nn.BatchNorm2d(out_channels),
        nn.ReLU()
    )
  def forward(self, x):
    return self.conv(x)

class UNet(nn.Module):
  # U-Net Model involves an encoder, a bottleneck and decoder section
  def __init__(self, num_classes=4):
    super().__init__()
    # Encoder with 4 blocks of Double_Convolution layers
    # Includes 4 sets of max pooling operations with kernel 2x2 and stride 2 for downsampling
    self.down_1 = nn.Sequential(
        conv_block(1, 16),
        conv_block(16, 16),
    )
    self.down_2 = nn.Sequential(
        conv_block(16, 32, 2),
        conv_block(32, 32),
    )
    self.down_3 = nn.Sequential(
        conv_block(32, 64, 2),
        conv_block(64, 64),
    )
    # Bottleneck
    # Includes a Double Convolution layer followed by upsampling with ConvTranspose2d
    self.bottle = nn.Sequential(
        conv_block(64, 128, 2),
        conv_block(128, 128),
        nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1)
    )

    # Decoder
    # Concatinating with skip connections causes feature channels to double
    # Double_Convolution and ConvTranspose2d each causes feature channels to halve
    self.up_1 = nn.Sequential(
        conv_block(128, 64),
        conv_block(64, 64),
        nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1)
    )
    self.up_2 = nn.Sequential(
        conv_block(64, 32),
        conv_block(32, 32),
        nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1)
    )
    # Final Output Layer
    self.out = nn.Sequential(
        conv_block(32, 16),
        conv_block(16, 16),
        nn.Conv2d(16, 4, kernel_size=1, padding=0)
    )

  def forward(self, x):
      # Use the convolutional operators defined above to build the U-net
      # Encoder
      x1 = self.down_1(x)
      x2 = self.down_2(x1)
      x3 = self.down_3(x2)

      x4 = self.bottle(x3)

      # Decoder
      ### Insert your code ###
      x5 = torch.cat((x4, x3), dim=1)
      x6 = self.up_1(x5)
      x7 = torch.cat((x6, x2), dim=1)
      x8 = self.up_2(x7)
      x9 = torch.cat((x8, x1), dim=1)
      x10 = self.out(x9)
      return x10

# %%
import os
import torch
import torch.optim as optim
import torch.nn as nn

def train_per_epoch(model, trainloader, loss_fn, optimizer):
    model.train()
    loss_per_epoch = []
    for batch_idx, (images, labels) in enumerate(trainloader):
        images, labels = images.unsqueeze(1).to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)
        # images, labels = trainloader.get_random_batch(train_batch_size)
        # images, labels = torch.from_numpy(images), torch.from_numpy(labels)
        # images, labels = images.to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)
        logits = model(images)
        optimizer.zero_grad() # Clear previous gradients
        loss = loss_fn(logits, labels) # Compute loss
        loss.backward() # Carry out backpropagation and calculate gradients
        optimizer.step() # Update model parameters
        loss_per_epoch.append(loss.item())

    return torch.tensor(loss_per_epoch).mean().item()

def test_per_epoch(model, testloader, loss_fn, optimizer):
    model.eval()
    loss_per_epoch = []
    with torch.no_grad():  # Disabling gradient calculation during reference to reduce memory consumption
        for batch_idx, (images, labels) in enumerate(testloader):
            images, labels = images.unsqueeze(1).to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)
        # images, labels = testloader.get_random_batch(train_batch_size)
        # images, labels = torch.from_numpy(images), torch.from_numpy(labels)
        # images, labels = images.to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)
            logits = model(images)
            loss = loss_fn(logits, labels)
            loss_per_epoch.append(loss.item())

    return torch.tensor(loss_per_epoch).mean().item()

device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_classes=4
model = UNet(num_classes=num_classes)
model = model.to(device)

epochs = 150
train_batch_size = 25
eval_batch_size = 300
train_dataset = BrainImageSet("Slices/Train/BraTS-GLI-t1c", "Slices/Train/BraTS-GLI-seg", "t1c")
test_dataset = BrainImageSet("Slices/Test/BraTS-GLI-t1c", "Slices/Test/BraTS-GLI-seg", "t1c")


model_dir = 'saved_models'
os.makedirs(model_dir, exist_ok = True)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.CrossEntropyLoss(ignore_index=128)

train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=2)
print('Training on:', device, 'train sample size:', len(train_dataset), 'test sample size:', len(test_dataset))

best_epoch, best_loss = 0.0, np.inf
for epoch in range(epochs):

    loss_training = train_per_epoch(model, train_loader, loss_fn, optimizer)
    # if epoch % 1000 == 0:
    loss_testing = test_per_epoch(model, test_loader, loss_fn, optimizer)

    # Save the best model
    if loss_testing < best_loss:
        best_loss = loss_testing
        best_epoch = epoch
        torch.save(model.state_dict(), os.path.join(model_dir, 'model_best.pt'))


    print('--- Epoch {}\{}: Training loss = {:.4f}, Testing loss = {:.4f}, Best loss = {:.4f}, Best epoch = {} '.\
            format(epoch, epochs, loss_training, loss_testing, best_loss, best_epoch))
# Out:
# Training on: cuda train sample size: 1395 test sample size: 310
# --- Epoch 0\150: Training loss = 1.0857, Testing loss = 0.6947, Best loss = 0.6947, Best epoch = 0
# --- Epoch 1\150: Training loss = 0.6289, Testing loss = 0.4030, Best loss = 0.4030, Best epoch = 1
# --- Epoch 2\150: Training loss = 0.3409, Testing loss = 0.2260, Best loss = 0.2260, Best epoch = 2
# --- Epoch 3\150: Training loss = 0.1879, Testing loss = 0.1369, Best loss = 0.1369, Best epoch = 3
# --- Epoch 4\150: Training loss = 0.1210, Testing loss = 0.0863, Best loss = 0.0863, Best epoch = 4
# --- Epoch 5\150: Training loss = 0.0900, Testing loss = 0.0678, Best loss = 0.0678, Best epoch = 5
# --- Epoch 6\150: Training loss = 0.0731, Testing loss = 0.0584, Best loss = 0.0584, Best epoch = 6
# --- Epoch 7\150: Training loss = 0.0631, Testing loss = 0.0487, Best loss = 0.0487, Best epoch = 7
# --- Epoch 8\150: Training loss = 0.0543, Testing loss = 0.0493, Best loss = 0.0487, Best epoch = 7
# --- Epoch 9\150: Training loss = 0.0488, Testing loss = 0.0444, Best loss = 0.0444, Best epoch = 9
# --- Epoch 10\150: Training loss = 0.0442, Testing loss = 0.0379, Best loss = 0.0379, Best epoch = 10
# --- Epoch 11\150: Training loss = 0.0407, Testing loss = 0.0378, Best loss = 0.0378, Best epoch = 11
# --- Epoch 12\150: Training loss = 0.0378, Testing loss = 0.0354, Best loss = 0.0354, Best epoch = 12
# --- Epoch 13\150: Training loss = 0.0347, Testing loss = 0.0320, Best loss = 0.0320, Best epoch = 13
# --- Epoch 14\150: Training loss = 0.0320, Testing loss = 0.0348, Best loss = 0.0320, Best epoch = 13
# --- Epoch 15\150: Training loss = 0.0315, Testing loss = 0.0335, Best loss = 0.0320, Best epoch = 13
# --- Epoch 16\150: Training loss = 0.0268, Testing loss = 0.0317, Best loss = 0.0317, Best epoch = 16
# --- Epoch 17\150: Training loss = 0.0259, Testing loss = 0.0260, Best loss = 0.0260, Best epoch = 17
# --- Epoch 18\150: Training loss = 0.0228, Testing loss = 0.0286, Best loss = 0.0260, Best epoch = 17
# --- Epoch 19\150: Training loss = 0.0220, Testing loss = 0.0278, Best loss = 0.0260, Best epoch = 17
# --- Epoch 20\150: Training loss = 0.0201, Testing loss = 0.0310, Best loss = 0.0260, Best epoch = 17
# --- Epoch 21\150: Training loss = 0.0185, Testing loss = 0.0291, Best loss = 0.0260, Best epoch = 17
# --- Epoch 22\150: Training loss = 0.0172, Testing loss = 0.0330, Best loss = 0.0260, Best epoch = 17
# --- Epoch 23\150: Training loss = 0.0172, Testing loss = 0.0270, Best loss = 0.0260, Best epoch = 17
# --- Epoch 24\150: Training loss = 0.0155, Testing loss = 0.0343, Best loss = 0.0260, Best epoch = 17
# --- Epoch 25\150: Training loss = 0.0134, Testing loss = 0.0304, Best loss = 0.0260, Best epoch = 17
# --- Epoch 26\150: Training loss = 0.0131, Testing loss = 0.0367, Best loss = 0.0260, Best epoch = 17
# --- Epoch 27\150: Training loss = 0.0125, Testing loss = 0.0306, Best loss = 0.0260, Best epoch = 17
# --- Epoch 28\150: Training loss = 0.0124, Testing loss = 0.0361, Best loss = 0.0260, Best epoch = 17
# --- Epoch 29\150: Training loss = 0.0119, Testing loss = 0.0323, Best loss = 0.0260, Best epoch = 17
# --- Epoch 30\150: Training loss = 0.0112, Testing loss = 0.0331, Best loss = 0.0260, Best epoch = 17
# --- Epoch 31\150: Training loss = 0.0094, Testing loss = 0.0321, Best loss = 0.0260, Best epoch = 17
# --- Epoch 32\150: Training loss = 0.0104, Testing loss = 0.0320, Best loss = 0.0260, Best epoch = 17
# --- Epoch 33\150: Training loss = 0.0096, Testing loss = 0.0333, Best loss = 0.0260, Best epoch = 17
# --- Epoch 34\150: Training loss = 0.0079, Testing loss = 0.0286, Best loss = 0.0260, Best epoch = 17
# --- Epoch 35\150: Training loss = 0.0078, Testing loss = 0.0357, Best loss = 0.0260, Best epoch = 17
# --- Epoch 36\150: Training loss = 0.0076, Testing loss = 0.0312, Best loss = 0.0260, Best epoch = 17
# --- Epoch 37\150: Training loss = 0.0070, Testing loss = 0.0294, Best loss = 0.0260, Best epoch = 17
# --- Epoch 38\150: Training loss = 0.0064, Testing loss = 0.0337, Best loss = 0.0260, Best epoch = 17
# --- Epoch 39\150: Training loss = 0.0065, Testing loss = 0.0330, Best loss = 0.0260, Best epoch = 17
# --- Epoch 40\150: Training loss = 0.0060, Testing loss = 0.0322, Best loss = 0.0260, Best epoch = 17
# --- Epoch 41\150: Training loss = 0.0062, Testing loss = 0.0309, Best loss = 0.0260, Best epoch = 17
# --- Epoch 42\150: Training loss = 0.0056, Testing loss = 0.0356, Best loss = 0.0260, Best epoch = 17
# --- Epoch 43\150: Training loss = 0.0054, Testing loss = 0.0303, Best loss = 0.0260, Best epoch = 17
# --- Epoch 44\150: Training loss = 0.0053, Testing loss = 0.0344, Best loss = 0.0260, Best epoch = 17
# --- Epoch 45\150: Training loss = 0.0050, Testing loss = 0.0356, Best loss = 0.0260, Best epoch = 17
# --- Epoch 46\150: Training loss = 0.0056, Testing loss = 0.0386, Best loss = 0.0260, Best epoch = 17
# --- Epoch 47\150: Training loss = 0.0047, Testing loss = 0.0320, Best loss = 0.0260, Best epoch = 17
# --- Epoch 48\150: Training loss = 0.0045, Testing loss = 0.0321, Best loss = 0.0260, Best epoch = 17
# --- Epoch 49\150: Training loss = 0.0045, Testing loss = 0.0323, Best loss = 0.0260, Best epoch = 17
# --- Epoch 50\150: Training loss = 0.0043, Testing loss = 0.0337, Best loss = 0.0260, Best epoch = 17
# --- Epoch 51\150: Training loss = 0.0040, Testing loss = 0.0365, Best loss = 0.0260, Best epoch = 17
# --- Epoch 52\150: Training loss = 0.0042, Testing loss = 0.0356, Best loss = 0.0260, Best epoch = 17
# --- Epoch 53\150: Training loss = 0.0041, Testing loss = 0.0355, Best loss = 0.0260, Best epoch = 17
# --- Epoch 54\150: Training loss = 0.0038, Testing loss = 0.0352, Best loss = 0.0260, Best epoch = 17
# --- Epoch 55\150: Training loss = 0.0040, Testing loss = 0.0372, Best loss = 0.0260, Best epoch = 17
# --- Epoch 56\150: Training loss = 0.0038, Testing loss = 0.0342, Best loss = 0.0260, Best epoch = 17
# --- Epoch 57\150: Training loss = 0.0036, Testing loss = 0.0330, Best loss = 0.0260, Best epoch = 17
# --- Epoch 58\150: Training loss = 0.0042, Testing loss = 0.0404, Best loss = 0.0260, Best epoch = 17
# --- Epoch 59\150: Training loss = 0.0039, Testing loss = 0.0334, Best loss = 0.0260, Best epoch = 17
# --- Epoch 60\150: Training loss = 0.0036, Testing loss = 0.0347, Best loss = 0.0260, Best epoch = 17
# --- Epoch 61\150: Training loss = 0.0036, Testing loss = 0.0363, Best loss = 0.0260, Best epoch = 17
# --- Epoch 62\150: Training loss = 0.0034, Testing loss = 0.0314, Best loss = 0.0260, Best epoch = 17
# --- Epoch 63\150: Training loss = 0.0031, Testing loss = 0.0346, Best loss = 0.0260, Best epoch = 17
# --- Epoch 64\150: Training loss = 0.0030, Testing loss = 0.0403, Best loss = 0.0260, Best epoch = 17
# --- Epoch 65\150: Training loss = 0.0032, Testing loss = 0.0352, Best loss = 0.0260, Best epoch = 17
# --- Epoch 66\150: Training loss = 0.0034, Testing loss = 0.0355, Best loss = 0.0260, Best epoch = 17
# --- Epoch 67\150: Training loss = 0.0033, Testing loss = 0.0361, Best loss = 0.0260, Best epoch = 17
# --- Epoch 68\150: Training loss = 0.0030, Testing loss = 0.0425, Best loss = 0.0260, Best epoch = 17
# --- Epoch 69\150: Training loss = 0.0029, Testing loss = 0.0382, Best loss = 0.0260, Best epoch = 17
# --- Epoch 70\150: Training loss = 0.0033, Testing loss = 0.0433, Best loss = 0.0260, Best epoch = 17
# --- Epoch 71\150: Training loss = 0.0030, Testing loss = 0.0383, Best loss = 0.0260, Best epoch = 17
# --- Epoch 72\150: Training loss = 0.0026, Testing loss = 0.0369, Best loss = 0.0260, Best epoch = 17
# --- Epoch 73\150: Training loss = 0.0025, Testing loss = 0.0386, Best loss = 0.0260, Best epoch = 17
# --- Epoch 74\150: Training loss = 0.0028, Testing loss = 0.0377, Best loss = 0.0260, Best epoch = 17
# --- Epoch 75\150: Training loss = 0.0025, Testing loss = 0.0362, Best loss = 0.0260, Best epoch = 17
# --- Epoch 76\150: Training loss = 0.0023, Testing loss = 0.0393, Best loss = 0.0260, Best epoch = 17
# --- Epoch 77\150: Training loss = 0.0026, Testing loss = 0.0389, Best loss = 0.0260, Best epoch = 17
# --- Epoch 78\150: Training loss = 0.0024, Testing loss = 0.0351, Best loss = 0.0260, Best epoch = 17
# --- Epoch 79\150: Training loss = 0.0026, Testing loss = 0.0372, Best loss = 0.0260, Best epoch = 17
# --- Epoch 80\150: Training loss = 0.0024, Testing loss = 0.0385, Best loss = 0.0260, Best epoch = 17
# --- Epoch 81\150: Training loss = 0.0021, Testing loss = 0.0384, Best loss = 0.0260, Best epoch = 17
# --- Epoch 82\150: Training loss = 0.0022, Testing loss = 0.0344, Best loss = 0.0260, Best epoch = 17
# --- Epoch 83\150: Training loss = 0.0028, Testing loss = 0.0403, Best loss = 0.0260, Best epoch = 17
# --- Epoch 84\150: Training loss = 0.0022, Testing loss = 0.0424, Best loss = 0.0260, Best epoch = 17
# --- Epoch 85\150: Training loss = 0.0021, Testing loss = 0.0420, Best loss = 0.0260, Best epoch = 17
# --- Epoch 86\150: Training loss = 0.0019, Testing loss = 0.0396, Best loss = 0.0260, Best epoch = 17
# --- Epoch 87\150: Training loss = 0.0018, Testing loss = 0.0422, Best loss = 0.0260, Best epoch = 17
# --- Epoch 88\150: Training loss = 0.0018, Testing loss = 0.0417, Best loss = 0.0260, Best epoch = 17
# --- Epoch 89\150: Training loss = 0.0019, Testing loss = 0.0410, Best loss = 0.0260, Best epoch = 17
# --- Epoch 90\150: Training loss = 0.0021, Testing loss = 0.0431, Best loss = 0.0260, Best epoch = 17
# --- Epoch 91\150: Training loss = 0.0018, Testing loss = 0.0445, Best loss = 0.0260, Best epoch = 17
# --- Epoch 92\150: Training loss = 0.0016, Testing loss = 0.0444, Best loss = 0.0260, Best epoch = 17
# --- Epoch 93\150: Training loss = 0.0015, Testing loss = 0.0431, Best loss = 0.0260, Best epoch = 17
# --- Epoch 94\150: Training loss = 0.0014, Testing loss = 0.0453, Best loss = 0.0260, Best epoch = 17
# --- Epoch 95\150: Training loss = 0.0016, Testing loss = 0.0417, Best loss = 0.0260, Best epoch = 17
# --- Epoch 96\150: Training loss = 0.0016, Testing loss = 0.0446, Best loss = 0.0260, Best epoch = 17
# --- Epoch 97\150: Training loss = 0.0015, Testing loss = 0.0450, Best loss = 0.0260, Best epoch = 17
# --- Epoch 98\150: Training loss = 0.0026, Testing loss = 0.0407, Best loss = 0.0260, Best epoch = 17
# --- Epoch 99\150: Training loss = 0.0021, Testing loss = 0.0376, Best loss = 0.0260, Best epoch = 17
# --- Epoch 100\150: Training loss = 0.0022, Testing loss = 0.0415, Best loss = 0.0260, Best epoch = 17
# --- Epoch 101\150: Training loss = 0.0017, Testing loss = 0.0396, Best loss = 0.0260, Best epoch = 17
# --- Epoch 102\150: Training loss = 0.0015, Testing loss = 0.0479, Best loss = 0.0260, Best epoch = 17
# --- Epoch 103\150: Training loss = 0.0013, Testing loss = 0.0473, Best loss = 0.0260, Best epoch = 17
# --- Epoch 104\150: Training loss = 0.0013, Testing loss = 0.0454, Best loss = 0.0260, Best epoch = 17
# --- Epoch 105\150: Training loss = 0.0013, Testing loss = 0.0460, Best loss = 0.0260, Best epoch = 17
# --- Epoch 106\150: Training loss = 0.0013, Testing loss = 0.0479, Best loss = 0.0260, Best epoch = 17
# --- Epoch 107\150: Training loss = 0.0012, Testing loss = 0.0452, Best loss = 0.0260, Best epoch = 17
# --- Epoch 108\150: Training loss = 0.0012, Testing loss = 0.0461, Best loss = 0.0260, Best epoch = 17
# --- Epoch 109\150: Training loss = 0.0011, Testing loss = 0.0480, Best loss = 0.0260, Best epoch = 17
# --- Epoch 110\150: Training loss = 0.0013, Testing loss = 0.0424, Best loss = 0.0260, Best epoch = 17
# --- Epoch 111\150: Training loss = 0.0013, Testing loss = 0.0466, Best loss = 0.0260, Best epoch = 17
# --- Epoch 112\150: Training loss = 0.0013, Testing loss = 0.0493, Best loss = 0.0260, Best epoch = 17
# --- Epoch 113\150: Training loss = 0.0012, Testing loss = 0.0488, Best loss = 0.0260, Best epoch = 17
# --- Epoch 114\150: Training loss = 0.0013, Testing loss = 0.0541, Best loss = 0.0260, Best epoch = 17
# --- Epoch 115\150: Training loss = 0.0023, Testing loss = 0.0390, Best loss = 0.0260, Best epoch = 17
# --- Epoch 116\150: Training loss = 0.0023, Testing loss = 0.0419, Best loss = 0.0260, Best epoch = 17
# --- Epoch 117\150: Training loss = 0.0099, Testing loss = 0.0231, Best loss = 0.0231, Best epoch = 117
# --- Epoch 118\150: Training loss = 0.0066, Testing loss = 0.0318, Best loss = 0.0231, Best epoch = 117
# --- Epoch 119\150: Training loss = 0.0027, Testing loss = 0.0373, Best loss = 0.0231, Best epoch = 117
# --- Epoch 120\150: Training loss = 0.0021, Testing loss = 0.0431, Best loss = 0.0231, Best epoch = 117
# --- Epoch 121\150: Training loss = 0.0016, Testing loss = 0.0454, Best loss = 0.0231, Best epoch = 117
# --- Epoch 122\150: Training loss = 0.0014, Testing loss = 0.0448, Best loss = 0.0231, Best epoch = 117
# --- Epoch 123\150: Training loss = 0.0013, Testing loss = 0.0479, Best loss = 0.0231, Best epoch = 117
# --- Epoch 124\150: Training loss = 0.0012, Testing loss = 0.0469, Best loss = 0.0231, Best epoch = 117
# --- Epoch 125\150: Training loss = 0.0011, Testing loss = 0.0490, Best loss = 0.0231, Best epoch = 117
# --- Epoch 126\150: Training loss = 0.0011, Testing loss = 0.0504, Best loss = 0.0231, Best epoch = 117
# --- Epoch 127\150: Training loss = 0.0011, Testing loss = 0.0503, Best loss = 0.0231, Best epoch = 117
# --- Epoch 128\150: Training loss = 0.0010, Testing loss = 0.0506, Best loss = 0.0231, Best epoch = 117
# --- Epoch 129\150: Training loss = 0.0011, Testing loss = 0.0495, Best loss = 0.0231, Best epoch = 117
# --- Epoch 130\150: Training loss = 0.0011, Testing loss = 0.0478, Best loss = 0.0231, Best epoch = 117
# --- Epoch 131\150: Training loss = 0.0010, Testing loss = 0.0513, Best loss = 0.0231, Best epoch = 117
# --- Epoch 132\150: Training loss = 0.0009, Testing loss = 0.0528, Best loss = 0.0231, Best epoch = 117
# --- Epoch 133\150: Training loss = 0.0009, Testing loss = 0.0523, Best loss = 0.0231, Best epoch = 117
# --- Epoch 134\150: Training loss = 0.0010, Testing loss = 0.0529, Best loss = 0.0231, Best epoch = 117
# --- Epoch 135\150: Training loss = 0.0010, Testing loss = 0.0497, Best loss = 0.0231, Best epoch = 117
# --- Epoch 136\150: Training loss = 0.0009, Testing loss = 0.0528, Best loss = 0.0231, Best epoch = 117
# --- Epoch 137\150: Training loss = 0.0009, Testing loss = 0.0531, Best loss = 0.0231, Best epoch = 117
# --- Epoch 138\150: Training loss = 0.0009, Testing loss = 0.0514, Best loss = 0.0231, Best epoch = 117
# --- Epoch 139\150: Training loss = 0.0009, Testing loss = 0.0542, Best loss = 0.0231, Best epoch = 117
# --- Epoch 140\150: Training loss = 0.0009, Testing loss = 0.0541, Best loss = 0.0231, Best epoch = 117
# --- Epoch 141\150: Training loss = 0.0008, Testing loss = 0.0533, Best loss = 0.0231, Best epoch = 117
# --- Epoch 142\150: Training loss = 0.0010, Testing loss = 0.0525, Best loss = 0.0231, Best epoch = 117
# --- Epoch 143\150: Training loss = 0.0009, Testing loss = 0.0513, Best loss = 0.0231, Best epoch = 117
# --- Epoch 144\150: Training loss = 0.0008, Testing loss = 0.0548, Best loss = 0.0231, Best epoch = 117
# --- Epoch 145\150: Training loss = 0.0009, Testing loss = 0.0536, Best loss = 0.0231, Best epoch = 117
# --- Epoch 146\150: Training loss = 0.0009, Testing loss = 0.0522, Best loss = 0.0231, Best epoch = 117
# --- Epoch 147\150: Training loss = 0.0009, Testing loss = 0.0531, Best loss = 0.0231, Best epoch = 117
# --- Epoch 148\150: Training loss = 0.0009, Testing loss = 0.0546, Best loss = 0.0231, Best epoch = 117
# --- Epoch 149\150: Training loss = 0.0008, Testing loss = 0.0515, Best loss = 0.0231, Best epoch = 117

# %%
# !pip install -q torchmetrics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 14.6 MB/s eta 0:00:00

# %%
from torch.utils.data import Dataset, DataLoader
from glob import glob
import imageio.v2 as iio
import matplotlib.pyplot as plt
from glob import glob
import numpy as np

def normalise_intensity(image, ROI_thres=0.1):
    pixel_thres = np.percentile(image, ROI_thres)
    ROI = np.where(image > pixel_thres, image, 0) # If image value is greater than pixel threshold, return image value, otherwise return 0
    mean = np.mean(ROI)
    std = np.std(ROI)
    ROI_norm = (ROI - mean) / (std + 1e-8) # Normalise ROI
    return ROI_norm

def map_labels(label):
    label_map = {0: 0, 85: 1, 170: 2, 255: 3}
    mapped_label = label.copy()
    for k, v in label_map.items():
        mapped_label[label == k] = v
    return mapped_label

class BratsDataset(Dataset):
    def __init__(self, root='brats_train'):
        self.img_path_all = glob(root + '/BraTS-GLI-t1c/*.png')
        self.mask_path_all = [img_path.replace('t1c', 'seg') for img_path in self.img_path_all]
        # self.mask_path_all = [mask_path.replace('t1c', 'seg') for mask_path in self.mask_path_all]

    def __len__(self):
      return len(self.img_path_all)

    def __getitem__(self, index):
        image = iio.imread(self.img_path_all[index])
        image = normalise_intensity(image)
        label = iio.imread(self.mask_path_all[index])
        label = map_labels(label)
        return image, label

train_dataset = BratsDataset(root='Slices/Train')
test_dataset = BratsDataset(root='Slices/Test')
print('Train Sample:', len(train_dataset), 'Test Sample:', len(test_dataset))
input, label = test_dataset[3]
plt.subplot(1,2,1), plt.axis('OFF'), plt.title('input:{}'.format(input.shape)), plt.imshow(input, cmap='gray')
plt.subplot(1,2,2), plt.axis('OFF'), plt.title('label:{}'.format(label.shape)), plt.imshow(label, cmap='gray');
# Out:
# Train Sample: 1395 Test Sample: 310

# %%
from torchmetrics import Dice
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader

def calculate_confusion_matrix_from_arrays(prediction, ground_truth, nr_labels):
    replace_indices = np.vstack((
        ground_truth.flatten(),
        prediction.flatten())
    ).T
    confusion_matrix, _ = np.histogramdd(
        replace_indices,
        bins=(nr_labels, nr_labels),
        range=[(0, nr_labels), (0, nr_labels)]
    )
    confusion_matrix = confusion_matrix.astype(np.uint32)
    return confusion_matrix

def calculate_dice(confusion_matrix):
    dices = []
    for index in range(confusion_matrix.shape[0]):
        true_positives = confusion_matrix[index, index]
        false_positives = confusion_matrix[:, index].sum() - true_positives
        false_negatives = confusion_matrix[index, :].sum() - true_positives
        denom = 2 * true_positives + false_positives + false_negatives
        if denom == 0:
            dice = 0
        else:
            dice = 2 * float(true_positives) / denom
        dices.append(dice)
    return dices


def test_per_epoch(model, testloader):
    model.eval()
    fig, axs = plt.subplots(len(testloader), 3, figsize=(1*3, len(testloader)*1), subplot_kw=dict(xticks=[],yticks=[]))
    confusion_matrix = np.zeros((num_classes, num_classes), dtype=np.uint32)
    class_wise_dice = []
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(testloader):
            images, labels = images.unsqueeze(1).to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)
            logits = model(images)
            prob = F.softmax(logits, dim=1)
            pred_seg = torch.argmax(prob, dim=1)
            confusion_matrix += calculate_confusion_matrix_from_arrays(pred_seg.cpu(), labels.cpu(), num_classes)
            img_num = 0
            axs[batch_idx, 0].imshow(images[img_num, 0].cpu().numpy(), cmap='gray')
            axs[batch_idx, 1].imshow(labels[img_num].cpu().numpy(), cmap='gray')
            axs[batch_idx, 2].imshow(pred_seg[img_num].cpu().numpy(), cmap='gray')

    confusion_matrix = confusion_matrix[1:, 1:]  # exclude background
    dices_per_class = {'dice_cls:{}'.format(cls + 1): dice
                for cls, dice in enumerate(calculate_dice(confusion_matrix))}

    plt.axis('OFF')
    plt.tight_layout()
    plt.show()
    return dices_per_class

num_classes=4
model = UNet(num_classes=num_classes).to(device)
model.load_state_dict(torch.load('/content/saved_models/model_best.pt'))
eval_batch_size = 80
print('Test Sample:', len(test_dataset))
test_loader = DataLoader(test_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=2)
dices_per_class = test_per_epoch(model, test_loader)
dices_per_class_list = np.array(list(dices_per_class.values()))
print('Class Wise Dice:', dices_per_class)
print('Overall Dice:', np.mean(dices_per_class_list))
# Out:
# Test Sample: 310
# Class Wise Dice: {'dice_cls:1': 0.7470981486923303, 'dice_cls:2': 0.745758400529087, 'dice_cls:3': 0.8642752588046488}
# Overall Dice: 0.7857106026753554
