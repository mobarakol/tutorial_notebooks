# %% [markdown]
# <a href="https://colab.research.google.com/github/mobarakol/tutorial_notebooks/blob/main/llama_inference_zeroshot_chartqa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install "torch==2.4.0" tensorboard pillow torchvision accelerate huggingface_hub
# !pip -q install  --upgrade \
  "transformers==4.45.1" \
  "datasets==3.0.1" \
  "accelerate==0.34.2" \
  "evaluate==0.4.3" \
  "bitsandbytes==0.44.0" \
  "trl==0.11.1" \
  "peft==0.13.0" \
  "qwen_vl_utils"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 57.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 45.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 82.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 85.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 33.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.4/318.4 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 68.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 40.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.6.1 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.

# %% [markdown]
# from google.colab import drive
#
# drive.mount('/content/drive')

# %% [markdown]
# import os
#
# os.environ['HF_HOME'] = '/home/sa5u24/VQA'
#
# hf_home = os.path.expanduser(
#     os.getenv("HF_HOME", os.path.join(os.getenv("XDG_CACHE_HOME", "~/.cache"), "huggingface"))
# )
#
# print(hf_home)
#
# from huggingface_hub import login
#
# login(token="")

# %% [markdown]
# Dataset Template:

# %%
system_message = """You are a Vision Language Model specialized in interpreting visual data from chart images.
Your task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.
The charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.
Focus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary."""

def format_data(sample):
    return [
        {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": system_message
                }
            ],
        },
        {
            "role": "user",
            "content": [
                {
                    "type": "image",
                    "image": sample["image"],
                },
                {
                    "type": "text",
                    "text": sample['query'],
                }
            ],
        },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": sample["label"][0]
                }
            ],
        },
    ]

from datasets import load_dataset

dataset_id = "HuggingFaceM4/ChartQA"
train_dataset, eval_dataset, test_dataset = load_dataset(dataset_id, split=['train[:10%]', 'val[:10%]', 'test[:10%]'])

train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]
test_dataset = [format_data(sample) for sample in test_dataset]

train_dataset[200], len(train_dataset), len(eval_dataset), len(test_dataset)
# Out:
# README.md:   0%|          | 0.00/852 [00:00<?, ?B/s]
# (…)-00000-of-00003-49492f364babfa44.parquet:   0%|          | 0.00/219M [00:00<?, ?B/s]
# (…)-00001-of-00003-7302bae5e425bbc7.parquet:   0%|          | 0.00/311M [00:00<?, ?B/s]
# (…)-00002-of-00003-194c9400785577a2.parquet:   0%|          | 0.00/315M [00:00<?, ?B/s]
# (…)-00000-of-00001-0f11003c77497969.parquet:   0%|          | 0.00/50.2M [00:00<?, ?B/s]
# (…)-00000-of-00001-e2cd0b7a0f9eb20d.parquet:   0%|          | 0.00/68.9M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/28299 [00:00<?, ? examples/s]
# Generating val split:   0%|          | 0/1920 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2500 [00:00<?, ? examples/s]
# ([{'role': 'system',
#    'content': [{'type': 'text',
#      'text': 'You are a Vision Language Model specialized in interpreting visual data from chart images.\nYour task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.\nThe charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.\nFocus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary.'}]},
#   {'role': 'user',
#    'content': [{'type': 'image',
#      'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=308x369>},
#     {'type': 'text',
#      'text': 'Is the rightmost value of light brown graph 58?'}]},
#   {'role': 'assistant', 'content': [{'type': 'text', 'text': 'No'}]}],
#  2830,
#  192,
#  250)

# %%
import gc
import time
import torch

def clear_memory():
    # Delete variables if they exist in the current global scope
    if 'inputs' in globals(): del globals()['inputs']
    if 'model' in globals(): del globals()['model']
    if 'processor' in globals(): del globals()['processor']
    if 'trainer' in globals(): del globals()['trainer']
    if 'peft_model' in globals(): del globals()['peft_model']
    if 'bnb_config' in globals(): del globals()['bnb_config']
    time.sleep(2)

    # Garbage collection and clearing CUDA memory
    gc.collect()
    time.sleep(2)
    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    time.sleep(2)
    gc.collect()
    time.sleep(2)

    print(f"GPU allocated memory: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
    print(f"GPU reserved memory: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")



def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    # Prepare the text input by applying the chat template
    text_input = processor.apply_chat_template(
        sample[1:2],  # Use the sample without the system message
        tokenize=False,
        add_generation_prompt=True
    )

    # Process the visual input from the sample
    # image_inputs, _ = process_vision_info(sample)
    image_inputs = sample[1]['content'][0]['image'].convert("RGB")
    # Prepare the inputs for the model
    model_inputs = processor(
        text=[text_input],
        images=image_inputs,
        return_tensors="pt",
    ).to(device)  # Move inputs to the specified device

    # Generate text with the model
    generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)

    # Trim the generated ids to remove the input ids
    trimmed_generated_ids = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    # Decode the output text
    output_text = processor.batch_decode(
        trimmed_generated_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return output_text[0]  # Return the first decoded output text

# %%
clear_memory()
# Out:
# GPU allocated memory: 0.00 GB
# GPU reserved memory: 0.00 GB

# %%
import evaluate
import torch
from nltk.translate.meteor_score import meteor_score, single_meteor_score
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
import requests
from torch import nn
from transformers import MllamaForConditionalGeneration, AutoProcessor, MllamaConfig, AutoModelForCausalLM
from typing import List, Optional, Tuple, Union
from PIL import Image
import matplotlib.pyplot as plt
from qwen_vl_utils import process_vision_info
from transformers import BitsAndBytesConfig



quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    # low_cpu_mem_usage=True,
    # bnb_4bit_compute_dtype=torch.float16
)

model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
processor = AutoProcessor.from_pretrained(model_id)
model = MllamaForConditionalGeneration.from_pretrained(
            model_id, torch_dtype=torch.bfloat16, device_map="auto", low_cpu_mem_usage=True,
            quantization_config=quantization_config,
        )

all_pred = []
all_ans = []
model.eval()
with torch.no_grad():
    for sample in test_dataset:
        output = generate_text_from_sample(model, processor, sample)
        ans = sample[2]['content'][0]['text']
        all_pred.append(output)
        all_ans.append(ans)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/55.8k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/5.07k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/5.09k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/89.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.47G [00:00<?, ?B/s]
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %%
for i in range(len(all_pred)):
    print("pred:", all_pred[i])
    print("ans:", all_ans[i])
# Out:
# pred: There are 11 food items shown in the bar graph.
# ans: 14
# pred: To calculate the difference in value between Lamb and Corn, subtract the value of Corn from the value of Lamb.
#
# • Lamb: 103.7
# • Corn: 103.13
#
# **Calculation:**
# 103.7 - 103.13 = 0.57
#
# *Answer*: 0.57
# ans: 0.57
# pred: There are 3 bars shown in the chart.
# ans: 3
# pred: To determine if the value of Madagascar exceeds that of Fiji, a comparison of their respective values is necessary.
#
# **Values:**
#
# * Madagascar: 0.21%
# * Fiji: 0.38%
#
# **Result:**
# Since 0.21% is less than 0.38%, the value of Madagascar is not greater than that of Fiji.
#
# *Answer*: No
# ans: No
# pred: The lowest bar has a value of 23.
# ans: 23
# pred: To calculate the difference between the highest and lowest green bars, the following steps are taken:
#
# * Identify the values of the green bars:
# 	+ Highest value: 29% in 2016
# 	+ Lowest value: 23% in 2015
# * Calculate the difference by subtracting the lowest value from the highest value: 29 - 23 = 6
#
# *Answer*: 6
# ans: 6
# pred: According to the graph, 62% of people think of President Donald Trump as dangerous.
# ans: 62
# pred: To determine if the sum of the percentages of Charismatic and Well-qualified to be president exceeds that of A strong leader, we need to calculate the sum of the former two percentages and compare it with the percentage of A strong leader.
#
# **Given Percentages:**
#
# * Charismatic: 39%
# * Well-qualified to be president: 26%
# * A strong leader: 55%
#
# **Calculation:**
#
# Sum of Charismatic and Well-qualified to be president = 39% + 26% = 65%
#
# **Comparison:**
#
# 65% (Sum of Charismatic and Well-qualified to be president) is less than 55% (A strong leader).
#
# *Answer*: No
# ans: Yes
# pred: The 4th most popular emotion is Inspired.
# ans: Inspired
# pred: To calculate the difference between the number of people who felt inspired frequently and those who felt depressed frequently, we subtract the number of people who felt depressed frequently from the number of people who felt inspired frequently.
#
# Key statistics:
# • 16% of people felt inspired frequently.
# • 13% of people felt depressed frequently.
#
# *Answer*: 3
# ans: 0.03
# pred: The value of Slovenia in the graph is 1 GPI.
# ans: 1
# pred: To find the difference between the Green bar and Orange bar, we need to subtract the value of the Orange bar from the value of the Green bar. The value of the Green bar is 0.79 and the value of the Orange bar is 0.71.
#
# The difference between the Green bar and Orange bar is 0.08.
# ans: 0.08
# pred: The leftmost value of the bar in China is 17.
# ans: 17
# pred: To calculate the average, we need to add up all the values in the green bars and divide by the number of values.
#
# **Green Bar Values:**
#
# * 29%
# * 19
# * 17
#
# **Step 1: Add Up the Values**
# 29 + 19 + 17 = 65
#
# **Step 2: Divide by the Number of Values**
# 65 / 3 = 21.67
#
# **Result:**
# The average of all the values in the green bars is 21.7.
#
# *Answer*: 21.7
# ans: 21.6
# pred: The percentage of U.S adults who refused is 2%.
# ans: 2
# pred: **Identical Segments: 2%**
#
# The two segments that share the same percentage value are **"Don't Know"** and **"Refused"**, both accounting for **2%** of the total.
# ans: 2
# pred: The line reaches its peak in 2014.
# ans: 2014
# pred: The line has its sharpest increase between 2012 and 2013.
# ans: 2011
# pred: The graph features a single color, blue, which is used for all bars representing the percentage of people who believe that vaccines are important for children to have.
# ans: 1
# pred: To determine if the sum of the largest two bars exceeds the sum of the smallest three bars, we must calculate the sum of each set.
#
# * Largest two bars: United Arab Emirates (94%) and Mauritania (91%)
# 	+ Sum: 185%
# * Smallest three bars: Armenia (73%), South Korea (72%), and Spain (88%)
# 	+ Sum: 233%
#
# **Comparison:**
# The sum of the largest two bars (185%) is less than the sum of the smallest three bars (233%).
#
# *Answer*: No
# ans: No
# pred: The line that represents data about boys is the green line.
# ans: green line
# pred: The gap between data about boys and girls reaches its largest in 2007.
# ans: 2008
# pred: The missing data in the sequence is 29.
#
# The sequence provided is: 24, _, 32, 33, 42. The missing data is 29, which is the percentage of tweeters in Australia.
# ans: 29
# pred: The ratio of the lowest value of green bars to blue bars is 0.5.
# ans: 1.216666667
# pred: Yes, the percentage value of the 'STEM' segment is 52%.
# ans: Yes
# pred: To determine if the largest segment exceeds the combined total of all other segments, a comparison with the sum of the other segments is necessary.
#
# * The largest segment is STEM, which accounts for 52% of the total.
# * The sum of the other segments is:
# 	+ 17% (Management, business, finance)
# 	+ 11% (Social services, legal, education)
# 	+ 20% (Other non-STEM)
# 	Total: 48%
#
# **Comparison:**
# The sum of the other segments (48%) is less than the largest segment (52%).
#
# *Answer*: Yes
# ans: Yes
# pred: The biggest segment is Support with 80%.
# ans: 80
# pred: To calculate the difference between the largest and smallest segments, we must first identify their values.
#
# * The largest segment is "Support" with a value of 80%.
# * The smallest segment is "DK" with a value of 3%.
#
# The difference is calculated by subtracting the smaller value from the larger value:
#
# 80% - 3% = 77%
#
# *Answer*: 77%
# ans: 77
# pred: According to the graph, 8% of people in Jordan want fewer Syrian refugees.
# ans: 0.6
# pred: To calculate the difference between the highest and lowest percentages, we must first identify these values.
#
# * Highest percentage: 64% (Syrian)
# * Lowest percentage: 3% (Jordanian)
#
# **Calculation:**
# Subtract the lowest percentage from the highest percentage: 64 - 3 = 61
#
# *Answer*: 61
# ans: 61
# pred: There are 13 years represented on this graph.
# ans: 13
# pred: To determine the answer, examine the Lithuania line on the graph and count the number of points or years with values exceeding 10.
#
# The graph displays the following values for Lithuania:
# * 2007: 10
# * 2008: 16
# * 2009: 6
# * 2010: 8
# * 2011: 12
# * 2012: 14
# * 2013: 20
# * 2014: 3
# * 2015: 1
# * 2016: 9
# * 2017: 16
# * 2018: 1
# * 2019: 20
#
# *Answer*: 7
# ans: 5
# pred: 21% of people are somewhat confident that Donald Trump can manage the executive branch effectively.
# ans: 24
# pred: To determine if the "Not at all" value of "Use military force wisely" exceeds that of "Handle an international crisis", a comparison of the two values is necessary.
#
# * "Not at all" value for "Use military force wisely": 51
# * "Not at all" value for "Handle an international crisis": 54
#
# Since 54 is greater than 51, the "Not at all" value of "Handle an international crisis" is indeed higher.
#
# *Answer*: No
# ans: No
# pred: Italy has the highest secondary graduation rate in 2018, with a rate of around 88%.
# ans: Italy
# pred: The line representing Mexico remains all time lower than the other two.
# ans: Mexico
# pred: According to the chart, 14% of people waited in line for 10-30 minutes.
# ans: 33
# pred: The maximum time people waited when they went to vote is 30 minutes.
# ans: Over 30 mins
# pred: There are 4 categories in the chart.
# ans: 4
# pred: To determine the difference in degree distribution between Asians and Whites, we subtract the percentage of Whites from the percentage of Asians.
#
# **Degree Distribution Percentages:**
#
# * Asians: 63%
# * Whites: 41%
#
# **Calculating the Difference:**
#
# 63 - 41 = 22
#
# *Answer*: 22
# ans: 22
# pred: The value of the blue bar is 92%.
# ans: 92
# pred: To find the product of the smallest value on the blue bar and the smallest value on the upper bar, we need to identify these values first. The smallest value on the blue bar is 8 and the smallest value on the upper bar is 12.
#
# The product of these two values is 96.
# ans: 96
# pred: The percentage of people choosing 'approve' in Sep 2015 is 21%.
# ans: 21
# pred: To find the difference, we need to subtract the value of Approve in Jul 2015 from the value of Approve in Sep 2015. The value of Approve in Jul 2015 is 33 and the value of Approve in Sep 2015 is 21. So, the difference is 33 - 21 = 12.
#
# The value of Approve decreases by 12 from Jul 2015 to Sep 2015.
# ans: 12
# pred: The value of Satisfied is 20 in the year 2009.
# ans: 2009
# pred: To calculate the average, we add the values together and divide by 3. The values are:
#
# * 30
# * 29
# * 30
#
# **Calculation:**
# 30 + 29 + 30 = 89
# 89 / 3 = 29.67
#
# *Answer*: 29.7
# ans: 28.6
# pred: In 2020, 68% of respondents believed that economic ties between the U.S. and China were Bad.
# ans: 68
# pred: The difference between the percentages of people who say current economic ties between the U.S. and China are bad and good is minimum in 2020, with a difference of 29%.
# ans: 2019
# pred: According to the bar graph, 83% of Russians approve of the way Vladimir Putin is handling relations with Ukraine.
# ans: 83
# pred: To determine the ratio of people who approve and those who don't approve of Putin's handling of corruption, we need to calculate the percentage of those who approve and those who disapprove.
#
# **Key Figures:**
#
# * Percentage of people who approve: 62%
# * Percentage of people who disapprove: 29%
#
# **Ratio Calculation:**
#
# To find the ratio, we divide the percentage of people who approve by the percentage of people who disapprove:
#
# 62 ÷ 29 = 2.14
#
# **Result:**
#
# The ratio of people who approve to those who don't approve of Putin's handling of corruption is approximately 2.14:1.
#
# *Answer*: 2.14
# ans: 2.13
# pred: The least popular game in the chart is Simulation, with 32% of respondents reporting playing it.
# ans: Simulation
# pred: There are 4 games in the chart with over 40 ratings. These games are:
#
# 1. Puzzle (62)
# 2. Strategy (62)
# 3. Adventure (49)
# 4. Shooter (42)
# ans: 4
# pred: Yes, the light blue bar with a value of 22 is the smallest.
# ans: Yes
# pred: To determine the median value of the light green bars, we need to look at the values for each group:
#
# * EU: 51%
# * WHO: 40%
# * Chinese government: 13%
#
# **Arranging the Values in Ascending Order**
#
# * 13%
# * 40%
# * 51%
#
# Since there are an odd number of values (three), the middle value is the median. In this case, the median value is 40%.
#
# **Conclusion**
#
# The median value of the light green bars is not greater than 45.
#
# *Answer*: No
# ans: No
# pred: Yes, the 15% segment is light green.
# ans: Yes
# pred: The ratio of the smallest segment (7%) to the second largest segment (21%) is 0.33333333333.
# ans: 0.33333333
# pred: The political party with the highest rate of 'confirmed respondents' is the Democrat party, with a rate of 51%.
# ans: Democrat (scores 60 to 100)
# pred: According to the graph, 89% of pollers did not have a phone number.
# ans: 0.01
# pred: The country represented by the brown color bar is Libya.
# ans: Libya
# pred: To calculate the difference between the maximum and minimum Human Development Index (HDI) values across all countries, we must first identify the highest and lowest values.
#
# * Highest value: 0.81 (Denmark)
# * Lowest value: 0.58 (Botswana)
#
# **Calculation:**
#
# Difference = Maximum - Minimum
# = 0.81 - 0.58
# = 0.23
#
# *Answer*: 0.23
# ans: 0.23
# pred: The least value of the blue graph is 28%.
# ans: 28
# pred: To determine the answer, we must first identify the median values of both the blue and green graphs.
#
# * The blue graph represents China's military strength.
# * The green graph represents China's economic strength.
#
# The median values are:
# * Blue graph: 36
# * Green graph: 50
#
# To calculate the sum, we add these values together.
#
# *Answer*: 86
# ans: 87.5
# pred: The country data shown in the bottom bar is the UK.
# ans: UK
# pred: To calculate the average, we will add the percentages for the last four countries and divide by 4.
#
# **Percentages:**
#
# * Poland: 62
# * France: 54
# * Spain: 48
# * UK: 37
#
# **Step 1: Add the percentages**
# 62 + 54 + 48 + 37 = 201
#
# **Step 2: Divide the sum by 4**
# 201 / 4 = 50.25
#
# *Answer*: 50.25
# ans: 50.25
# pred: The largest yellow bar represents 72.
# ans: 72
# pred: The ratio of the smallest brown bar to the largest yellow bar is 0.12.
# ans: 0.633333333
# pred: The missing value is 4.1, which represents the number of Hispanic voters in 1998.
# ans: 4.1
# pred: The median value of the red graph is 12.4 million.
# ans: 14.5
# pred: The number of deaths per 100,000 in Colombia in 2002 is 175.
# ans: 175
# pred: To determine if the number of deaths per 100,000 in 2002 in Slovenia exceeds the combined total of Costa Rica and Colombia, we must calculate the sum of deaths in Costa Rica and Colombia and compare it with the number of deaths in Slovenia.
#
# * Costa Rica: 173 deaths per 100,000
# * Colombia: 175 deaths per 100,000
# * Total: 348 deaths per 100,000
#
# **Step 2: Compare with Slovenia**
#
# * Slovenia: 262 deaths per 100,000
#
# **Result**
#
# Since 262 is less than 348, the number of deaths per 100,000 in 2002 in Slovenia is not more than that of Costa Rica and Colombia combined.
#
# *Answer*: No
# ans: No
# pred: The largest bar represents Egypt with a value of 93.45%.
# ans: 93.45
# pred: To calculate the average, we need to add the percentages of the bottom two countries and divide by 2.
#
# The two countries are Madagascar (58.09%) and Mozambique (44%).
#
# The average is (58.09 + 44) / 2 = 51.045%.
# ans: 51.04
# pred: The value of the light green bar in 1989 is 35.
# ans: Yes
# pred: To calculate the average, we must first determine the values of the smallest gray bar and the largest light blue bar.
#
# * The smallest gray bar represents 1% and is found in 1979.
# * The largest light blue bar represents 42% and is found in 1979.
#
# **Calculation:**
#
# 1. Add the values of the two bars: 1 + 42 = 43
# 2. Divide by 2 to find the average: 43 / 2 = 21.5
#
# *Answer*: 21.5
# ans: 21.5
# pred: The largest bar value is 302.38%.
# ans: 3.0238
# pred: To calculate the sum of the three smallest bars, we must first identify their values.
#
# * The smallest bar represents "Regulatory capital to assets" with a value of 4%.
# * The second smallest bar is "Return on assets" with a value of 0.1%.
# * The third smallest bar is "Non-performing loans to total gross loans" with a value of 15.12%.
#
# The sum of these three values is calculated by adding them together.
#
# *Answer*: 19.22%
# ans: 0.1922
# pred: The total value of the 'More' bar is 52.
# ans: 52
# pred: To determine the median, the values must be arranged in ascending order: 13, 27, 33, 39, 41, and 58. With an even number of values (6), the median is calculated as the average of the two middle values, which are 33 and 39.
#
# *Answer*: Yes
# ans: Yes
# pred: The dark green represents the U.S.
# ans: U.S.
# pred: The country that ranked second highest in the bar chart is the UK.
# ans: UK
# pred: According to the graph, 67% of people believe that everything possible should be done to make it easy to vote.
# ans: 67
# pred: To determine the ratio of Conservatives who believe citizens should prove what they want to want versus those who think everything should be done to make it possible to vote, we need to divide the percentage of Conservatives who think citizens should have to prove they want to vote by registering ahead of time by the percentage of Conservatives who think everything should be done to make it easy to vote.
#
# **Key Figures:**
#
# * Percentage of Conservatives who think citizens should have to prove they want to vote by registering ahead of time: 63
# * Percentage of Conservatives who think everything should be done to make it easy to vote: 36
#
# **Calculation:**
#
# Ratio = (Percentage of Conservatives who think citizens should have to prove they want to vote by registering ahead of time) / (Percentage of Conservatives who think everything should be done to make it easy to vote)
# = 63 / 36
#
# **Result:**
#
# The ratio is approximately 1.75.
#
# *Answer*: 1.75
# ans: 1.051388889
# pred: According to the chart, 55% of people chose 'very' for their state officials.
# ans: 55
# pred: The category with the highest satisfaction rating is 'Poll workers in your community' with 68%.
# ans: Poll workers in your community
# pred: The category with a value of 82 and 15 is Rep/Lean Rep.
# ans: Rep/Lean Rep
# pred: To calculate the ratio of good to bad responses, the percentage of good responses is divided by the percentage of bad responses.
#
# * Good responses: 31%
# * Bad responses: 64%
#
# The ratio is calculated as follows: 31 / 64 = 0.484.
#
# *Answer*: 0.484
# ans: 0.484375
# pred: The two values that are the same in the upper graph are 47 and 47.
# ans: 77
# pred: To calculate the sum of the three identical values in the lower graph, we must first identify the values in question. The three values are:
#
# * 47
# * 47
# * 47
#
# The sum of these values is calculated by adding them together.
#
# *Answer*: 141
# ans: 141
# pred: According to the chart, 41% of all adults say the coronavirus outbreak is a major threat to their personal financial situation.
# ans: 41
# pred: To find the ratio of yellow bar to blue bar for Ages 18-29, we need to divide the value of yellow bar by the value of blue bar. The yellow bar represents 40% and the blue bar represents 26%.
#
# The ratio is 40/26 = 1.5384615384615385.
# ans: 1.684722222
# pred: The middle bar represents Nicaragua.
# ans: Nicaragua
# pred: To determine the answer, we must identify the two extreme values and the middle bar value in the graph.
#
# * The highest value is 73.3% (Thailand)
# * The lowest value is 35% (Lesotho)
# * The middle bar value is 55.7% (Nicaragua)
#
# **Calculating the Average**
#
# The average of these two values is calculated by adding them together and dividing by 2:
#
# (73.3 + 35) / 2 = 54.15
#
# **Comparison**
#
# The average of the two extreme values (54.15) is compared to the middle bar value (55.7). The average is less than the middle bar value.
#
# *Answer*: No
# ans: No
# pred: There are 8 factors shown in the chart.
# ans: 3
# pred: To calculate the sum value, the percentages for each category must be added together.
#
# The percentages are:
# * Major factor: 8%
# * Minor factor: 34%
# * Not a factor: 57%
#
# *Answer*: 99
# ans: 99
# pred: The country that received the highest Programmable aid over the years is Solomon Islands.
# ans: Solomon Islands
# pred: Jamaica received a higher Country Programmable aid than Tonga.
# ans: Jamaica
# pred: The highest value of the green graph is 50, which occurred in 2007.
# ans: 50
# pred: To determine the median value of the Japan graph from 2013 to 2015, we must examine the values for those years. The values are as follows:
#
# • 27
# • 35
# • 37
#
# **Step 1: Arrange Values in Order**
# Arrange the values in order from smallest to largest: 27, 35, 37
#
# **Step 2: Find the Middle Value**
# Since there are an odd number of values (3), the middle value is the second value.
#
# *Answer*: 35
# ans: 35
# pred: The value of Slovenia is 977,633 t.
# ans: 977633
# pred: To determine the difference between the values of South Korea and Spain, we subtract the value of Spain from the value of South Korea.
#
# **Values:**
# * South Korea: 21.32 million t
# * Spain: 19.72 million t
#
# **Calculation:**
# 21.32 - 19.72 = 1.60
#
# *Answer*: 1.60
# ans: 1.6
# pred: There are 4 color bars in the graph.
# ans: 4
# pred: To determine the answer, we must identify the two smallest bars and the largest bar in the graph. The values of these bars are:
#
# * The smallest two bars:
# 	+ Mauritius: <1
# 	+ Mali: <1
# * The largest bar:
# 	+ Cote d'Ivoire: <1
#
# Next, we compare the sum of the values of the smallest two bars with the value of the largest bar. Since both are equal to <1, the sum of the smallest two bars is not greater than the value of the largest bar.
#
# *Answer*: No
# ans: No
# pred: The largest dark red bar value is 26, which corresponds to the Silent/Greatest age group.
# ans: 0.08
# pred: To determine the difference between the percentage of Hispanic youth who are Mexican and those who are Spanish, we subtract the percentage of Spanish Hispanics from the percentage of Mexican Hispanics.
#
# * Percentage of Hispanic youth who are Mexican: 69%
# * Percentage of Hispanic youth who are Spanish: 4%
#
# **Calculating the Difference:**
#
# 69% - 4% = 65%
#
# *Answer*: 65%
# ans: 65
# pred: In 2002, 25% of people regularly watched CNN.
# ans: 25
# pred: MSNBC's viewership was more than 12 for 2 years.
# ans: 2
# pred: The next data in the Men category is 28%.
# ans: 28
# pred: To determine the ratio between the green bars 28 and 19, we divide the value of the first green bar (28) by the value of the second green bar (19).
#
# *Answer*: 1.47
# ans: 1.179861111
# pred: There are 5 colors used to represent the bar graph.
# ans: 4
# pred: The median value of the light blue bar is 37%.
# ans: 37
# pred: The smallest segment is the grey one, representing 11% of the total.
# ans: Gray
# pred: To determine the answer, the following steps are taken:
#
# * Identify the median opinion: 19% of people prefer Vigorous enforcement.
# * Identify the minimum opinion: 11% of people prefer No choice.
# * Subtract the minimum from the median: 19 - 11 = 8.
#
# *Answer*: 8
# ans: 8
# pred: The population of Asia, including the UN projection until 2100, 1950, is 1.4 billion.
# ans: 1.4
# pred: To verify the statement, we compare the population of Africa, North America, and South America with that of Europe.
#
# **Population Figures:**
#
# * Africa: 227.79 million
# * North America: 172.6 million
# * South America: 113.77 million
# * Europe: 549.33 million
#
# **Comparison:**
#
# The combined population of Africa, North America, and South America (503.16 million) is less than the population of Europe (549.33 million).
#
# *Answer*: No
# ans: No
# pred: The value of India Bar is 2.42 tonnes per hectare.
# ans: 2.42
# pred: To determine the difference in yield values between South America and India, we subtract the value of India from the value of South America.
#
# **Values:**
# * South America: 3.19 t
# * India: 2.42 t
#
# **Calculation:**
# 3.19 - 2.42 = 0.77
#
# *Answer*: 0.77
# ans: 0.77
# pred: The rightmost value of the upper bars is 12.
# ans: 12
# pred: To determine if the result of multiplying the average of gray bars by 2 is greater than the largest navy blue bar, we must first calculate the average of the gray bars and then multiply it by 2.
#
# **Step 1: Calculate the Average of Gray Bars**
#
# The gray bars represent the percentage of U.S. adults who have never seen videos on YouTube that seem false/untrue, or show people doing dangerous things.
#
# * Never: 12%
# * Hardly ever: 14%
# * Sometimes: 19%
#
# **Average Calculation:**
# (12 + 14 + 19) / 3 = 45 / 3 = 15
#
# **Step 2: Multiply the Average by 2**
#
# 15 * 2 = 30
#
# **Step 3: Compare with the Largest Navy Blue Bar**
#
# The largest navy blue bar represents 48%.
#
# **Result:**
# Since 30 is less than 48, the result of multiplying the average of gray bars by 2 is not greater than the largest navy blue bar.
#
# *Answer*: No
# ans: Yes
# pred: The smallest bar in the graph represents 3%.
# ans: 3
# pred: To find the average value of all orange bars in the chart, we need to add up all the values and divide by the number of bars. The values are 97%, 92%, 77%, and 50%.
#
# The average value is (97 + 92 + 77 + 50) / 4 = 71.25%.
# ans: 21
# pred: The largest grey bar represents 23%.
# ans: 0.3
# pred: To calculate the difference between the number of people who were very worried and very enthusiastic, we subtract the percentage of people who were very enthusiastic from the percentage of people who were very worried.
#
# * Percentage of people who were very enthusiastic: 15%
# * Percentage of people who were very worried: 22%
#
# The difference is calculated as follows: 22% - 15% = 7%.
#
# *Answer*: 7%
# ans: 0.07
# pred: The type of plastic that was most produced was PP, or polypropylene, with 68 million tonnes.
# ans: PP
# pred: There are 3 types of plastic that had a production of less than 30 million tonnes.
# ans: 3
# pred: The value of the unaffiliated segment is 71.
# ans: 71
# pred: To calculate the average, we need to add up all the segments and divide by the number of segments. The segments are 3,292, 3,410, 821, and 71.
#
# The sum of these numbers is 7,494. Dividing this by 4 gives an average of 1,873.5.
#
# The median is the middle value when the numbers are arranged in order. In this case, the median is 821.
#
# Since 1,873.5 is greater than 821, the average is indeed greater than the median.
#
# The average of all the segments is greater than the median of all the segments.
# ans: No
# pred: The value of 'Increase' is 30%.
# ans: 30
# pred: To determine if the Decrease value is two times the value of Increase, we need to compare the percentages of Americans who say the number of people killed or injured in traffic accidents will decrease or increase if driverless vehicles become widespread.
#
# The Decrease value is 39% and the Increase value is 30%.
#
# The Decrease value is not two times the value of Increase.
# ans: No
# pred: The country represented by the red line on the graph is Saudi Arabia.
# ans: Saudi Arabia
# pred: Saudi Arabia took 3 years to increase the important terrestrial biodiversity sites that are protected.
# ans: 1
# pred: The 'Don't Know' category in the pie chart represents 30%.
# ans: 30
# pred: The color of the pie represented 'More' is light blue.
# ans: gray
# pred: The peak value of the dark brown graph is 83%.
# ans: 83
# pred: To determine the ratio, we must identify the least value of the light brown graph and the leftmost value of the dark brown graph.
#
# * The least value of the light brown graph is 16.
# * The leftmost value of the dark brown graph is 50.
#
# **Calculation:**
#
#  Divide the least value of the light brown graph by the leftmost value of the dark brown graph.
#
# *Answer*: 0.32
# ans: 0.32
# pred: The value of the dark brown bar in the Total category is 57.
# ans: 57
# pred: The ratio of bars in the Dem/Lean Dem category is approximately 0.5, as there are 50% of respondents who believe that the country can always find ways to solve its problems and 48% who believe that the country can't solve many of its important problems.
# ans: 1.058333333
# pred: The value of the Middle bar in 1971 is 61.
# ans: 61
# pred: No, the median of the green bar is not greater than the median of the blue bar.
# ans: No
# pred: Yes, the green graph represents Satisfied.
# ans: Yes
# pred: To determine the ratio, we must identify the highest and lowest points on the blue graph and the green graph.
#
# **Key Values:**
#
# * Highest point on the blue graph: 71
# * Lowest point on the blue graph: 20
# * Highest point on the green graph: 58
# * Lowest point on the green graph: 23
#
# **Calculating the Differences:**
#
# * Difference between the highest and lowest points on the blue graph: 71 - 20 = 51
# * Difference between the highest and lowest points on the green graph: 58 - 23 = 35
#
# **Calculating the Ratio:**
#
# * Ratio = (Difference between blue graph / Difference between green graph) = 51 / 35
#
# *Answer*: 1.457142857142857
# ans: 2.125694444
# pred: The ratings of EU reach their peak in 2013.
# ans: 2013
# pred: The ratings of the US and EU stayed over 50 for 2 years.
# ans: 1
# pred: No, the median of the green graph from 2002 to 2006 is not greater than the smallest value of the orange graph.
# ans: No
# pred: To calculate the product of all values below 50 in the orange graph, we must identify the relevant values and multiply them together.
#
# The values below 50 in the orange graph are:
# • 71
# • 64
# • 69
# • 62
# • 56
# • 54
# • 45
# • 37
#
# The product of these values is calculated as follows:
# 71 * 64 = 4,544
# 4,544 * 69 = 312,576
# 312,576 * 62 = 19,380,672
# 19,380,672 * 56 = 1,086,291,872
# 1,086,291,872 * 45 = 48,855,879,200
# 48,855,879,200 * 37 = 1,805,944,703,600
#
# *Answer*: 1,805,944,703,600
# ans: 2577420
# pred: The graph with the largest value of 52 is the red line, which represents the Republican.
# ans: Red
# pred: There are 2 points on the blue graph with a value of 56.
# ans: 3
# pred: The highest point of this graph is 92, which represents the percentage of voters who say there was more mudslinging in past elections.
# ans: 92
# pred: To find the average of 'more mudslinging', we need to add up all the values and divide by the number of data points. The values are 68, 49, 36, 34, 72, 54, 68, and 92.
#
# The average of 'more mudslinging' is 56.25.
# ans: 62.43
# pred: The green line has lower values across all years.
# ans: Favorable
# pred: To calculate the ratio of absolute change in unfavorable sentiment to that of favorable sentiment from 2006 to 2016, the following steps are taken:
#
# * Calculate the absolute change in unfavorable sentiment: 86 - 71 = 15
# * Calculate the absolute change in favorable sentiment: 11 - 27 = -16
# * Calculate the ratio of the absolute change in unfavorable sentiment to that of favorable sentiment: 15 / 16 = 0.9375
#
# *Answer*: 0.9375
# ans: 0.9375
# pred: The leftmost value of the Approve graph is 54.53%.
# ans: 54
# pred: To determine if the product of the smallest value of the Approve graph and the largest value of the Disapprove graph is greater than 2000, we need to identify these values first.
#
# * The smallest value on the Approve graph is 26.
# * The largest value on the Disapprove graph is 64.
#
# Now, let's calculate the product:
#
# **Product Calculation**
#
# 26 * 64 = 1,664
#
# **Conclusion**
#
# Since 1,664 is less than 2,000, the product of the smallest value of the Approve graph and the largest value of the Disapprove graph is not greater than 2000.
#
# *Answer*: No
# ans: No
# pred: The percentage of people who support legalization reaches its peak in 1989.
# ans: 2014
# pred: The gap between support and against legalization reaches its peak in 1989.
# ans: 1969
# pred: The colour of India in the graph is orange.
# ans: orange
# pred: To find the lowest sum value of India and Taliban, we need to look at the values for each year and find the smallest sum. The lowest sum value is 53 + 32 = 85.
#
# The lowest sum value of India and Taliban is 85.
# ans: 57
# pred: To determine the greatest gap between the orange and green lines, we must identify the largest difference in values between the two lines.
#
# * The orange line represents China's economic power, while the green line represents the United States'.
# * The highest point on the orange line is 57, while the lowest point on the green line is 28.
# * The greatest gap between the two lines is calculated by subtracting the lowest value from the highest value: 57 - 28 = 29.
#
# *Answer*: 29
# ans: 29
# pred: To find the year with the smallest difference in values between China and the US as leading economic powers, we need to compare the percentages for each year. The year with the smallest difference will be the one where the values are closest to each other.
#
# The year with the smallest difference is 2014, where China had 49% and the US had 34%, resulting in a difference of 15%.
# ans: 2010
# pred: Yes, the Approve and Disapprove lines are almost merged in March, with a difference of only 1 point.
# ans: Yes
# pred: There are 2 data points that exceed the value of 50.
# ans: 3
# pred: The value of favor is 57 in the year 2011.
# ans: March 2011
# pred: In September 2008, the group 'Favor' has a higher value than 'Oppose'.
# ans: Favor
# pred: Yes, the value 30 is present in the dark blue line.
# ans: Yes
# pred: The product of the largest value on the light blue line (57) and the leftmost value on the dark blue line (34) is 1938.
# ans: 2210
# pred: The value of the gray segment is 26%.
# ans: 1
# pred: To calculate the gap percentage between the "bad" and "better" scenarios, we subtract the percentage of people who can agree on basic facts from the percentage of people who cannot agree on basic facts.
#
# * Percentage of people who can agree on basic facts: 26%
# * Percentage of people who cannot agree on basic facts: 73%
#
# **Calculating the Gap Percentage**
#
#  Gap percentage = Percentage of people who cannot agree on basic facts - Percentage of people who can agree on basic facts
# = 73% - 26%
# = 47%
#
# *Answer*: 47%
# ans: 47
# pred: Yes, the color of the DK segment is gray.
# ans: Yes
# pred: To find the result of dividing the second largest segment by the smallest segment, we need to identify these segments first. The second largest segment is 39% and the smallest is 3%.
#
# The result of dividing the second largest segment by the smallest segment is 13.33.
# ans: 13
# pred: The largest segment is blue.
# ans: Blue
# pred: No, the smallest segment's value is not one-third of the largest segment's value.
# ans: No
# pred: The smallest segment represents 'Don't know'.
# ans: Don't Know
# pred: To determine if the sum of the two smallest segment values exceeds the largest segment value, we must identify the values of each segment.
#
# * The largest segment accounts for 55% of the pie chart.
# * The two smallest segments account for 6% and 39% of the pie chart, respectively.
#
# The sum of the two smallest segments is calculated as follows: 6% + 39% = 45%.
#
# Since 45% is less than 55%, the sum of the two smallest segments does not exceed the largest segment value.
#
# *Answer*: No
# ans: No
# pred: According to the pie chart, 10% of people have a favorable opinion of Boko Haram.
# ans: 10
# pred: To calculate the difference between the "very unfavorable" and "Favorable" opinions, subtract the percentage of "Favorable" opinions from the percentage of "very unfavorable" opinions.
#
# Key statistics:
# * "Very unfavorable": 79%
# * "Favorable": 10%
#
# *Answer*: 69%
# ans: 69
# pred: According to the pie chart, 41% of seniors do not go online.
# ans: 41
# pred: To determine if the median of all three data values is equal to 32, we need to first arrange the values in order from smallest to largest: 27%, 32%, and 41%. The middle value is 32%, which is the median.
#
# The median of all three data values is indeed 32.
# ans: Yes
# pred: The value for 'Providing treatment' in the graph is 67%.
# ans: 67
# pred: To calculate the average, we add up all the values and divide by the number of values. The values are:
#
# * 26%
# * 7%
# * 67%
#
# **Step 1: Add up the values**
# 26 + 7 + 67 = 100
#
# **Step 2: Divide by the number of values**
# 100 / 3 = 33.33
#
# **Result:** The average of all the data values is 33.33%, which is less than 40.
#
# *Answer*: No
# ans: No
# pred: The orange portion indicates that 22% of people think the country is Bad.
# ans: Bad
# pred: To calculate the difference between "Good" and "Bad", subtract the percentage of "Bad" from the percentage of "Good".
#
# * "Good": 75%
# * "Bad": 22%
#
# **Calculation:**
# 75% - 22% = 53%
#
# *Answer*: 53
# ans: 53
# pred: The most popular answer is 'Better off', chosen by 72% of Latinos.
# ans: Better off
# pred: The largest pie represents 72%.
# ans: Better off
# pred: The most popular option is 'Top priority', with 35% of the vote.
# ans: Important, but lower priority
# pred: To determine the percentage of people who consider something important, we must sum the percentages of the two categories that represent "important" or "very important" responses.
#
# * "Important, but lower priority": 40%
# * "Top priority": 35%
#
# **Calculation:**
# 40% + 35% = 75%
#
# *Answer*: 75%
# ans: 75
# pred: The majority of the pie chart is occupied by 'Dissatisfied' with 78%.
# ans: Dissatisfied
# pred: To determine the answer, the percentage of Dissatisfied individuals must be divided by the percentage of Satisfied individuals.
#
# *Answer*: 3
# ans: 3.9
# pred: According to the pie chart, 76% of respondents believe that food near Fukushima is not safe.
# ans: 76
# pred: To determine if the sum of the two smallest segments exceeds the largest segment, we must first identify the values of these segments.
#
# * The largest segment is "Not safe" with a value of 76%.
# * The two smallest segments are "Safe" with a value of 19% and "DK" with a value of 6%.
#
# We calculate the sum of the two smallest segments by adding their values: 19% + 6% = 25%.
#
# Comparing this sum to the largest segment, we find that 25% is less than 76%.
#
# *Answer*: No
# ans: No
# pred: Yes, the color of the right-side bars is the lightest.
# ans: Yes
# pred: The value of 'minor' in Rep/Leap Rep is 30.
# ans: 30
# pred: The percentage of US adults choosing never is 16%.
# ans: 16
# pred: People aged 18-29 are more likely to choose 'Never'.
# ans: 65+
# pred: The value of the rightmost upper bar is 30.
# ans: 11
# pred: The largest value of the navy blue bar is 60.
# ans: 60
# pred: The green bar represents 'No role'.
# ans: No role
# pred: The average of all green bar values is 11.5.
# ans: 15
# pred: The country data shown in the chart is Japan.
# ans: Japan
# pred: To calculate the average of the last two bars, the following steps are taken:
#
# * The last two bars represent "Tensions with Russia" and "U.S. power and influence".
# * The values of these two bars are 33 and 52, respectively.
# * The average is calculated by adding the two numbers and dividing by 2.
#
# *Answer*: 42.5
# ans: 36
# pred: The second largest bar value in the graph is Libya, at 5.32%.
# ans: 5.32
# pred: To calculate the sum of all bars above 5, we must first identify the bars that meet this condition. The relevant bars are:
#
# * Haiti: 6.12%
# * Libya: 5.32%
# * Morocco: 5.11%
#
# The sum of these values is calculated by adding them together: 6.12 + 5.32 + 5.11 = 16.55.
#
# *Answer*: 16.55
# ans: 5.95
# pred: The green bar represents Finland with the greatest meat consumption.
# ans: Finland
# pred: To determine if the combined value of Georgia and Western Asia exceeds that of Finland, we must calculate the sum of their values and compare it to Finland's value.
#
# **Values:**
#
# * Georgia: 79.84 grams
# * Western Asia: 69.62 grams
# * Finland: 175.09 grams
#
# **Calculation:**
#
# 79.84 + 69.62 = 149.46 grams
#
# **Comparison:**
#
# The sum of Georgia and Western Asia (149.46 grams) is less than Finland's value (175.09 grams).
#
# *Answer*: No
# ans: No
# pred: China is represented by the color pink.
# ans: Pink
# pred: No, the sum of the two lowest bars is not greater than the largest bar.
# ans: No
# pred: The major cause of death in the U.S. is heart disease.
# ans: Heart disease
# pred: To determine the median value of all the bars, the values must be arranged in ascending order. The values are as follows:
#
# * 3.9
# * 10.9
# * 17.7
# * 27.1
# * 32.5
# * 58.1
# * 104.7
# * 155.3
# * 371.7
#
# Since there are an odd number of values (9), the middle value is the median. In this case, the median value is 27.1.
#
# *Answer*: No
# ans: Yes
# pred: According to the graph, North America has the highest installed geothermal energy capacity, with 3,245 MW.
# ans: North America
# pred: To determine if the average value of Philippines and North America exceeds 2500 MW, we must calculate the average value of these two regions.
#
# **Values:**
#
# * Philippines: 1846.5 MW
# * North America: 3245 MW
#
# **Calculation:**
#
# Average = (1846.5 + 3245) / 2 = 2545.75 MW
#
# Since 2545.75 is greater than 2500 MW, the answer is affirmative.
#
# *Answer*: Yes
# ans: Yes
# pred: The largest bar represents Obesity.
# ans: Obesity
# pred: To find the difference, we need to subtract the value of High blood pressure from High blood sugar.
#
# The difference is 676 - 879 = -203.
# ans: 203
# pred: There are 2 colors used in the bar chart.
# ans: 2
# pred: To find the average of the two bars, we need to add the values of both bars and divide by 2.
#
# The first bar represents Cayman Islands with a value of 95.45% and the second bar represents Belize with a value of 7.21%.
#
# The average of these two values is (95.45 + 7.21) / 2 = 51.33%.
# ans: 51.33
# pred: There are 2 bars that show the same value in the graph.
# ans: 2
# pred: To determine if the value of Gabon exceeds that of Tonga, a comparison of their values is necessary.
#
# * **Values:**
# 	+ Gabon: 0.13
# 	+ Tonga: less than 0.01
#
# Since 0.13 is greater than less than 0.01, the value of Gabon is indeed higher than that of Tonga.
#
# *Answer*: Yes.
# ans: Yes
# pred: The data for Colombia is 0.1%.
# ans: 0.1
# pred: To determine the answer, we must divide the value of the United Kingdom by the value of Mauritius.
#
# **Values:**
#
# * United Kingdom: 0.3
# * Mauritius: 0.06
#
# **Calculation:**
#
# 0.3 ÷ 0.06 = 5
#
# *Answer*: 5
# ans: 5
# pred: The value for France is 1.93 tonnes per hectare.
# ans: 1931
# pred: To determine the answer, we must compare the values of France and Argentina.
#
# * France: 1.93 tonnes per hectare
# * Argentina: 0.67 tonnes per hectare
#
# **Calculation:**
# To find the ratio of France to Argentina, we divide the value of France by the value of Argentina:
#
# 1.93 ÷ 0.67 = 2.88
#
# *Answer*: 2.88
# ans: 2.88
# pred: The smallest bar represents Low bone mineral density.
# ans: Low bone mineral density
# pred: To determine if the sum of the two smallest bars equals the value of the 3rd smallest bar, we must first identify these values.
#
# * The two smallest bars are:
# 	+ "Low physical activity" with a value of 48,930
# 	+ "Low bone mineral density" with a value of 13,135
# * The 3rd smallest bar is "Poor sanitation" with a value of 92,072
#
# Calculating the sum of the two smallest bars:
# 48,930 + 13,135 = 62,065
#
# Comparing this sum to the value of the 3rd smallest bar:
# 62,065 is less than 92,072
#
# *Answer*: No
# ans: No
# pred: The percentage value of Mali is 27.5%.
# ans: 27.5
# pred: To calculate the difference between the highest and lowest values, the following steps are taken:
#
# * Identify the highest value: 27.5% for Mali
# * Identify the lowest value: 17.3% for Kenya
# * Calculate the difference by subtracting the lowest value from the highest value
#
# *Answer*: 10.2
# ans: 10.2
# pred: There are 12 products shown in the bar graph.
# ans: 16
# pred: To determine if the sum value of Milk and Cheese is more than Lamb and Mutton, we need to calculate the sum of their values. The value of Milk is 27.1 m^2 and the value of Cheese is 39.8 m^2. The sum of these values is 66.9 m^2, which is less than the value of Lamb and Mutton, which is 184.8 m^2.
#
# The sum value of Milk product and cheese is not more than Lamb and Mutton.
# ans: No
# pred: There are 2 bars in the graph.
# ans: 2
# pred: To calculate the difference between the two bars, subtract the value of Nicaragua from the value of Cuba.
#
# • Value of Cuba: 3.52%
# • Value of Nicaragua: 0.28%
#
# *Answer*: 3.24
# ans: 3.24
# pred: The country/region with the highest percentage of pregnant women receiving antiretroviral therapy is Burkina Faso, with 75%.
# ans: Burkina Faso
# pred: To find the difference, we need to subtract the value of Cambodia from that of Burkina Faso.
#
# The difference is 75% - 70% = 5%.
# ans: 5
# pred: Lithuania has the longest bar.
# ans: Lithuania
# pred: To calculate the total value, we need to add the values of Lithuania and Bolivia.
#
# **Values:**
#
# * Lithuania: 19
# * Bolivia: 9.3
#
# **Calculation:**
#
# 19 + 9.3 = 28.3
#
# *Answer*: 28.3
# ans: 28.3
# pred: The longest bar has a value of 0.6 tonnes per hectare.
# ans: 0.6
# pred: The average value of the smallest two bars and the longest two bars is 0.48 tonnes per hectare.
# ans: 0.475
# pred: The largest bar has a value of 0.01%.
# ans: 0.01
# pred: To calculate the total value, we must sum the values of each bar:
#
# • Egypt: 0.01%
# • Namibia: <0.01%
# • Luxembourg: 0%
#
# The total value is the sum of these percentages.
#
# *Answer*: 0.01%
# ans: 0.02
# pred: The value for Major depression is 1.6.
# ans: 1.6
# pred: The two smallest values in the chart are 1.6 and 1.6, which are for Generalized anxiety disorder (GAD) and Major depression respectively.
#
# The sum of these two values is 3.2.
# ans: 3.2
# pred: The land use per 100 kilocalories by Mutton & Goat Meat production is 20.98 square meters.
# ans: 20.98
# pred: The average land use per 100 kilocalories by Wheat and Milk production is 0.17 m^2 and 0.27 m^2 respectively.
# ans: 0.2
# pred: The percentage value for personal contact is 41%.
# ans: 41
# pred: To find the percentage difference between adverts and agencies, we need to subtract the percentage of agencies from the percentage of adverts.
#
# The percentage of adverts is 7%, and the percentage of agencies is 1.6%.
#
# The percentage difference between adverts and agencies is 5.4%.
# ans: 5.4
# pred: The place with the lowest value of Tuberculosis rate is Nepal, with 163 cases per 100,000 people.
# ans: Nepal
# pred: To determine if the value of Ghana is more than Vietnam in Tuberculosis cases, a comparison of the values of Ghana and Vietnam is necessary.
#
# **Values:**
#
# * Ghana: 216
# * Vietnam: 197
#
# **Result:**
# *Answer*: Yes
# ans: Yes
# pred: The largest bar has a value of 5.25 trillion.
# ans: 5.25
# pred: To calculate the total value of the largest and smallest bars, we must first identify these values.
#
# * The largest bar represents the global ocean with a value of 5.25 trillion.
# * The smallest bar represents the Mediterranean Sea with a value of 247.4 billion.
#
# **Conversion to Same Unit**
#
# To combine these values, we convert the smaller value to trillion by dividing by 1,000:
# 247.4 billion / 1,000 = 0.2474 trillion
#
# **Adding the Values**
#
# Now, we add the values:
# 5.25 trillion + 0.2474 trillion = 5.4974 trillion
#
# *Answer*: 5.4974 trillion
# ans: 252.65
# pred: The graph uses a single color, blue, to represent the data for each country. The color is used consistently throughout the graph to show the share of population with severe food insecurity from 2015 to 2017 for each country.
#
# There is only one color used in the graph.
# ans: 1
# pred: To calculate the sum of bars with the same value, we need to identify the values that appear more than once in the graph. The values are:
#
# * 0.8%
# * 2.8%
# * 4%
# * 12.7%
#
# We then add up these values:
# 0.8 + 0.8 + 2.8 + 4 + 12.7 = 20.3
#
# *Answer*: 20.3
# ans: 1.6
# pred: Indonesia's share of primary energy from fossil fuels is 96.4%.
# ans: 96.4
# pred: To calculate the average percentage share of primary energy from fossil fuels for the three countries, the following steps are taken:
#
# * Algeria: 99.67%
# * Indonesia: 96.4%
# * Portugal: 87.63%
#
# **Step 1: Add up the percentages**
# 99.67 + 96.4 + 87.63 = 283.7
#
# **Step 2: Divide by the number of countries**
# 283.7 / 3 = 94.9
#
# The average percentage share of primary energy from fossil fuels is 94.9%, which is more than 90%.
#
# *Answer*: Yes
# ans: Yes
# pred: The highest bar in the graph is green, representing Vanuatu.
# ans: Teal Blue
# pred: To calculate the total value, the values of Somalia and Togo must be added together.
#
# * Value of Somalia: 8
# * Value of Togo: 30
#
# *Answer*: 38
# ans: 38

# %%
rouge = evaluate.load("rouge")
rouge_results = rouge.compute(predictions= all_pred, references=all_ans)
print(rouge_results)
# Out:
# {'rouge1': 0.11616600174635018, 'rouge2': 0.02590092336534345, 'rougeL': 0.11651964551335531, 'rougeLsum': 0.11640484997088382}

# %%
bleu_score = corpus_bleu(all_ans, all_pred, weights=(1.0, 0.0, 0.0, 0.0))
print(bleu_score)
# Out:
# 0.0187011969745184
# /home/sa5u24/anaconda3/envs/lit_llama/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/sa5u24/anaconda3/envs/lit_llama/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/sa5u24/anaconda3/envs/lit_llama/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
import nltk
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

m_score=0
for line in zip(all_ans, all_pred):
    ref = word_tokenize(line[0])
    hypo = word_tokenize(line[1])
    m_score += meteor_score([ref], hypo)
meteors = m_score/len(all_ans)
print(meteors)
# Out:
# [nltk_data] Downloading package wordnet to /home/sa5u24/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/sa5u24/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 0.1374583098003345
