# %% [markdown]
# <a href="https://colab.research.google.com/github/mobarakol/tutorial_notebooks/blob/main/grid_plot_customized_spacing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Playing with Grid plot to controlling the spacing between subplot

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(3, 3)
ax1 = plt.subplot(gs[0, :])
ax2 = plt.subplot(gs[1:, :])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(2, 2)
ax1 = plt.subplot(gs[0, :])
ax2 = plt.subplot(gs[1:, :])

# %%
gs1 = gridspec.GridSpec(3, 3)
gs1.update(left=0.05, right=0.48, wspace=0.05)
ax1 = plt.subplot(gs1[:-1, :])
ax2 = plt.subplot(gs1[-1, :-1])
ax3 = plt.subplot(gs1[-1, -1])

# %%
import matplotlib.gridspec as gridspec
gs1_w = 1

gs1 = gridspec.GridSpec(2, 2)
gs1.update(left=0.01, right=1, wspace=0.08, hspace=0.0)
ax1 = plt.subplot(gs1[:,:-1])
ax2 = plt.subplot(gs1[:, -1])
ax2.set_yticks([])

gs2 = gridspec.GridSpec(2, 2)
gs2.update(left=1.20, right=2.2, wspace=0.08, hspace=0.0)
ax3 = plt.subplot(gs2[:,:-1])
ax4 = plt.subplot(gs2[:, -1])
ax4.set_yticks([]);

ax1.set_title('ViT disease detection (No Finding)', x=1, pad=38, fontsize=16, fontweight="bold");
ax1.legend(loc='upper center', bbox_to_anchor=(1, 1.12),
          fancybox=True, shadow=True, ncol=2, labels=( 'White', 'Asian'), fontsize='large');

# %%
ptech_list = [r'$\bf{IID}$'+'\n'+r'$\bf{Test}$','GC\n (-)','GC\n (+)', 'Con\n (-)','Con\n (+)', 'Bri\n (-)', 'Bri\n (+)', 'Sha\n (-)', 'Sha\n (+)',
              'Blur']
ptech_listm = [r'$\bf{ID}$'+'\n'+r'$\bf{Test}$','GC\n (-)','GC\n (+)', 'Con\n (-)','Con\n (+)', 'Bri\n (-)', 'Bri\n (+)', 'Sha\n (-)', 'Sha\n (+)',
              'Blur']

fig = plt.figure(figsize=(10, 5))
gs1_w = 22
gh = 15
gw = 40
gs1 = gridspec.GridSpec(gh, gw)
gs1.update(left=0.001, right=1 + gs1_w, wspace=0.01, hspace=0.0)
ax1 = plt.subplot(gs1[:, gw-2])

ax1.set_prop_cycle(None)

ax1.set_prop_cycle(None)


ax2 = plt.subplot(gs1[:, -1:])

ax2.set_prop_cycle(None)

ax2.set_prop_cycle(None)

ax2.set_yticks([])

ax1.set_ylabel('Threshold(dotted) / FPR(dashed) / TPR(solid)', fontsize=14)
ax1.set_xlabel('ChexPert', fontsize=14, fontweight="bold")
ax2.set_xlabel('MIMIC-CXR', fontsize=14, fontweight="bold")
ax1.set_xticklabels(ptech_list, fontsize=12);
ax2.set_xticklabels(ptech_listm, fontsize=12);
ax1.set_xticks(np.arange(10))
ax2.set_xticks(np.arange(10))
ax1.xaxis.grid(True)
ax2.xaxis.grid(True)
ax1.set_ylim([0.0, 1])
ax2.set_ylim([0.0, 1])


gs2 = gridspec.GridSpec(gh, gw)
gs2.update(left=1.5, right=2.2 + gs1_w, wspace=0.01, hspace=0.0)
ax3 = plt.subplot(gs2[:, gw-2])


ax3.set_prop_cycle(None)

ax3.set_prop_cycle(None)


ax4 = plt.subplot(gs2[:, -1:])

ax4.set_prop_cycle(None)

ax4.set_prop_cycle(None)

ax4.set_yticks([])

ax3.set_xlabel('ChexPert',fontsize=14, fontweight="bold")
ax4.set_xlabel('MIMIC-CXR',fontsize=14, fontweight="bold")
ax3.set_xticklabels(ptech_list, fontsize=14);
ax4.set_xticklabels(ptech_listm, fontsize=14);
ax3.set_xticks(np.arange(10))
ax4.set_xticks(np.arange(10))
ax3.xaxis.grid(True)
ax4.xaxis.grid(True)
ax3.set_ylim([0.0, 1])
ax4.set_ylim([0.0, 1]);

ax1.set_title('ViT disease detection (No Finding)', x=1, pad=38, fontsize=16, fontweight="bold");
ax1.legend(loc='upper center', bbox_to_anchor=(1, 1.12),
          fancybox=True, shadow=True, ncol=8, labels=( 'White', 'Asian', 'Black', 'Female', 'Male'), fontsize='large')

ax3.set_title('ViT disease detection (Pleural Effusion)', x=1, pad=38, fontsize=16, fontweight="bold");
ax3.legend(loc='upper center', bbox_to_anchor=(1, 1.12),
          fancybox=True, shadow=True, ncol=8, labels=( 'White', 'Asian', 'Black', 'Female', 'Male'), fontsize='large')

#fig.savefig("vitsplit.pdf", bbox_inches='tight', dpi=1200)

# %%
import matplotlib.gridspec as gridspec
gs1_w = 1

gs1 = gridspec.GridSpec(2, 2)
gs1.update(left=0.01, right=1, wspace=0.00, hspace=0.0)
ax1 = plt.subplot(gs1[:,:-1])
ax2 = plt.subplot(gs1[:, -1])
ax1.set_yticks([])
ax2.set_yticks([])
ax1.set_xticks([])
ax2.set_xticks([])

gs2 = gridspec.GridSpec(2, 2)
gs2.update(left=1.10, right=2.1, wspace=0.00, hspace=0.0)
ax1 = plt.subplot(gs2[:,:-1])
ax2 = plt.subplot(gs2[:, -1])
ax1.set_yticks([])
ax2.set_yticks([]);
ax1.set_xticks([])
ax2.set_xticks([])

gs3 = gridspec.GridSpec(2, 2)
gs3.update(left=2.20, right=3.2, wspace=0.00, hspace=0.0)
ax1 = plt.subplot(gs3[:,:-1])
ax2 = plt.subplot(gs3[:, -1])
ax1.set_yticks([]);
ax2.set_yticks([]);
ax1.set_xticks([])
ax2.set_xticks([]);

gs4 = gridspec.GridSpec(2, 2)
gs4.update(left=3.30, right=4.3, wspace=0.00, hspace=0.0)
ax1 = plt.subplot(gs4[:,:-1])
ax2 = plt.subplot(gs4[:, -1])
ax1.set_yticks([]);
ax2.set_yticks([]);
ax1.set_xticks([])
ax2.set_xticks([]);

gs5 = gridspec.GridSpec(2, 2)
gs5.update(left=4.40, right=5.4, wspace=0.00, hspace=0.0)
ax1 = plt.subplot(gs5[:,:-1])
ax2 = plt.subplot(gs5[:, -1])
ax1.set_yticks([]);
ax2.set_yticks([]);
ax1.set_xticks([])
ax2.set_xticks([]);

# ax1.set_title('ViT disease detection (No Finding)', x=1, pad=38, fontsize=16, fontweight="bold");
# ax1.legend(loc='upper center', bbox_to_anchor=(1, 1.12),
#           fancybox=True, shadow=True, ncol=2, labels=( 'White', 'Asian'), fontsize='large');

# %%
gs1 = gridspec.GridSpec(5, 8)
gs1.update(bottom=0.15, top=2.5,  left=0.01, right=2.5, wspace=0.02, hspace=0.03)

for nr in range(0,4):
    for nc in range(1,8):
        ax = plt.subplot(gs1[nr,nc])
        ax.set_xticks([])
        ax.set_yticks([])
        if nr == 0:
            ax.set_title('hh')
        
gs2 = gridspec.GridSpec(1, 8)
gs2.update(bottom=0.0, top=0.5, left=0.01, right=2.5, wspace=0.00, hspace=0.1)
for nr in range(0,1):
    for nc in range(1,8):
        ax = plt.subplot(gs2[nr,nc])
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title('hh')

# %%
ptech_list = [ '-3', '-2', '-1','Original', '+1', '+2', '+3']
ptech_listb = ['Original', '+1', '+2', '+3', '+4', '+5', '+6']
plt.rcParams.update({'font.size': 12})
pad = 0
gs2 = gridspec.GridSpec(1, 8)   
gs2.update(bottom=0 + pad, top=0.5 + pad, left=0.01, right=2.5, wspace=0.00, hspace=0.0)
pad += 0.5
for nc in range(1,8):
    ax = plt.subplot(gs2[0,nc])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(ptech_listb[nc-1])
            
for nr in range(0,4):
    gs3 = gridspec.GridSpec(1, 8)   
    gs3.update(bottom=0.08 + pad, top=0.58 + pad, left=0.01, right=2.5, wspace=0.00, hspace=0.1)
    pad += 0.5
    for nc in range(1,8):
        ax = plt.subplot(gs3[0,nc])
        ax.set_xticks([])
        ax.set_yticks([])
        if nr == 3:
            ax.set_title(ptech_list[nc-1])
