# %% [markdown]
# <a href="https://colab.research.google.com/github/mobarakol/tutorial_notebooks/blob/main/MedThinkVQA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datasets import load_dataset

ds = load_dataset("bio-nlp-umass/MedThinkVQA", split="test")
sample = ds[0]
print(sample["CLINICAL_HISTORY"])
print(sample["options"])
print(sample["correct_answer"])
print(sample["image_01_path"])
print(sample["image_01_caption"])
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train.parquet:   0%|          | 0.00/665M [00:00<?, ?B/s]
# test.parquet:   0%|          | 0.00/608M [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/720 [00:00<?, ? examples/s]
# A 20-year-old female patient with disproportionate short stature and mild cognitive impairment presented with progressive joint stiffness and rapid onset of fatigue. Clinical evaluation revealed coarse face, and joint contractures. Echocardiography demonstrated cardiac valve thickening and ophthalmologic examination showed mild macular pigment changes. There was an excess excretion of urinary glycosaminoglycans.
# {'A': 'carbohydrate-deficient glycoprotein syndrome', 'B': 'All types of MPS', 'C': 'Maroteaux-Lamy syndrome', 'D': 'and GM1 gangliosidosis', 'E': 'Other storage diseases like multiple sulfatase deficiency'}
# C
# images/case10017/3r3P4sPV.jpg
# ...

# %%
print(sample["CLINICAL_HISTORY"])
# Out:
# A 20-year-old female patient with disproportionate short stature and mild cognitive impairment presented with progressive joint stiffness and rapid onset of fatigue. Clinical evaluation revealed coarse face, and joint contractures. Echocardiography demonstrated cardiac valve thickening and ophthalmologic examination showed mild macular pigment changes. There was an excess excretion of urinary glycosaminoglycans.

# %%
print(sample["correct_answer"])
# Out:
# C

# %%
print(sample["image_01_path"])
# Out:
# images/case10017/3r3P4sPV.jpg

# %%
print(sample["image_count"])
# Out:
# 6

# %%
print(sample["image_01_caption"])
# Out:
# Scaphocephalic skull with enlargement of the calvaria and thickening of the diploe(*). Enlarged J-shaped sella turcica (arrow).

# %%
print(sample["image_01_modality"])
print(sample["image_01_sub_modality"])
# Out:
# X-ray
# Plain radiograph

# %%
ds[0]["image_01"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=480x480>

# %%
ds[0]["image_02"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=480x480>

# %%
ds[0]["image_03"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=480x480>

# %%
ds[1]["image_02"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=480x480>

# %%
'image_count', 'image_01_id', 'image_01_path', 'image_01_caption', 'image_01_modality', 'image_01_sub_modality', 'image_01',

# %%
sample = ds[700]
sample.keys()
# Out:
# dict_keys(['title', 'CLINICAL_HISTORY', 'IMAGING_FINDINGS', 'discussion', 'options', 'correct_answer', 'correct_answer_text', 'ICD Chapter', 'ICD Block', 'ICD Category', 'is_longitudinal', 'timepoint_count', 'interval_text', 'image_count', 'image_01_id', 'image_01_path', 'image_01_caption', 'image_01_modality', 'image_01_sub_modality', 'image_01', 'image_02_id', 'image_02_path', 'image_02_caption', 'image_02_modality', 'image_02_sub_modality', 'image_02', 'image_03_id', 'image_03_path', 'image_03_caption', 'image_03_modality', 'image_03_sub_modality', 'image_03', 'image_04_id', 'image_04_path', 'image_04_caption', 'image_04_modality', 'image_04_sub_modality', 'image_04', 'image_05_id', 'image_05_path', 'image_05_caption', 'image_05_modality', 'image_05_sub_modality', 'image_05', 'image_06_id', 'image_06_path', 'image_06_caption', 'image_06_modality', 'image_06_sub_modality', 'image_06', 'image_07_id', 'image_07_path', 'image_07_caption', 'image_07_modality', 'image_07_sub_modality', 
# ...

# %%
for i in range (len(ds)):
    print(ds[i]["image_01_modality"], ds[i]["image_count"])
# Out:
# X-ray 6
# CT 5
# Ultrasound 8
# X-ray 13
# Ultrasound 8
# X-ray 10
# X-ray 5
# CT 8
# X-ray 6
# MRI 6
# Ultrasound 4
# Endoscopy 8
# X-ray 3
# X-ray 8
# MRI 6
# X-ray 3
# Ultrasound 3
# X-ray 10
# Ultrasound 4
# CT 22
# CT 6
# X-ray 6
# CT 4
# Nuclear medicine & Molecular imaging 8
# Clinical photography 10
# CT 8
# MRI 6
# X-ray 4
# X-ray 4
# CT 6
# CT 5
# MRI 10
# Non-modality / Workflow / Post-processing 5
# CT 5
# CT 8
# CT 3
# Ultrasound 6
# MRI 22
# X-ray 15
# Ultrasound 7
# X-ray 7
# X-ray 4
# Non-modality / Workflow / Post-processing 7
# MRI 12
# MRI 20
# CT 14
# CT 5
# X-ray 5
# X-ray 5
# CT 4
# X-ray 3
# CT 11
# Ultrasound 8
# X-ray 15
# Ultrasound 6
# CT 4
# MRI 4
# X-ray 9
# X-ray 4
# X-ray 4
# CT 5
# Ultrasound 7
# CT 3
# Ultrasound 3
# X-ray 6
# X-ray 15
# CT 14
# X-ray 4
# CT 5
# X-ray 3
# Ultrasound 12
# CT 8
# X-ray 9
# X-ray 5
# X-ray 8
# CT 5
# CT 9
# Ultrasound 6
# Non-modality / Workflow / Post-processing 8
# X-ray 5
# X-ray 3
# Ultrasound 4
# CT 14
# MRI 8
# ...

# %%
ds[0].keys()
# Out:
# dict_keys(['title', 'CLINICAL_HISTORY', 'IMAGING_FINDINGS', 'discussion', 'options', 'correct_answer', 'correct_answer_text', 'ICD Chapter', 'ICD Block', 'ICD Category', 'is_longitudinal', 'timepoint_count', 'interval_text', 'image_count', 'image_01_id', 'image_01_path', 'image_01_caption', 'image_01_modality', 'image_01_sub_modality', 'image_01', 'image_02_id', 'image_02_path', 'image_02_caption', 'image_02_modality', 'image_02_sub_modality', 'image_02', 'image_03_id', 'image_03_path', 'image_03_caption', 'image_03_modality', 'image_03_sub_modality', 'image_03', 'image_04_id', 'image_04_path', 'image_04_caption', 'image_04_modality', 'image_04_sub_modality', 'image_04', 'image_05_id', 'image_05_path', 'image_05_caption', 'image_05_modality', 'image_05_sub_modality', 'image_05', 'image_06_id', 'image_06_path', 'image_06_caption', 'image_06_modality', 'image_06_sub_modality', 'image_06', 'image_07_id', 'image_07_path', 'image_07_caption', 'image_07_modality', 'image_07_sub_modality', 
# ...
