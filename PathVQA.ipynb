# %% [markdown]
# <a href="https://colab.research.google.com/github/mobarakol/tutorial_notebooks/blob/main/PathVQA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datasets import load_dataset
from PIL import Image

ds = load_dataset("flaviagiammarino/path-vqa")

print(ds)
print(ds["train"][0].keys())

sample = ds["train"][0]

image = sample["image"]       # PIL image
question = sample["question"] # VQA question
answer = sample["answer"]     # target answer

print("Question:", question)
print("Answer:", answer)
print("Image:", image.size, image.mode)

image.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data/train-00000-of-00007-f2d0e9ef9f022d(…):   0%|          | 0.00/42.8M [00:00<?, ?B/s]
# data/train-00001-of-00007-47d8e0220bf6c9(…):   0%|          | 0.00/81.0M [00:00<?, ?B/s]
# data/train-00002-of-00007-7fb5037c4c5da7(…):   0%|          | 0.00/104M [00:00<?, ?B/s]
# ...

# %%
PathVQA_Test = load_dataset("flaviagiammarino/path-vqa", split="test")

# %%
PathVQA_Test[0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=CMYK size=335x400>,
#  'question': 'what are positively charged, thus allowing the compaction of the negatively charged dna?',
#  'answer': 'the histone subunits'}

# %%
PathVQA_Test[0]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=CMYK size=335x400>

# %%
PathVQA_Test[100]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=262x235>

# %%
PathVQA_Test[600]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=792x526>
