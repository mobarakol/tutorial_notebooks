# %% [markdown]
# <a href="https://colab.research.google.com/github/mobarakol/tutorial_notebooks/blob/main/catr_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Captioning with Transformers
# Similar Paper: https://arxiv.org/pdf/2101.10804.pdf <br>
# Code: https://github.com/Milkymap/transformer-image-captioning<br>
# Code: https://github.com/saahiluppal/catr.git

# %%
# !git clone https://github.com/saahiluppal/catr.git
# Out:
# Cloning into 'catr'...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 121 (delta 52), reused 38 (delta 38), pack-reused 52
# Receiving objects: 100% (121/121), 3.05 MiB | 30.30 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
# %cd catr/
# Out:
# /content/catr

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 18.0 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 44.0 MB/s
# ...
#      |████████████████████████████████| 182 kB 76.9 MB/s
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open('.github/cake.png')
plt.imshow(img)

# !python -W ignore predict.py --path .github/cake.png
# Out:
# Using cache found in /root/.cache/torch/hub/saahiluppal_catr_master
# A person cutting a cake with a knife.

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open('.github/girl.png')
plt.imshow(img)

# !python -W ignore predict.py --path .github/girl.png
# Out:
# Using cache found in /root/.cache/torch/hub/saahiluppal_catr_master
# A woman sitting on a curb holding an umbrella.

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open('.github/office.png')
plt.imshow(img)

# !python -W ignore predict.py --path .github/office.png
# Out:
# Using cache found in /root/.cache/torch/hub/saahiluppal_catr_master
# A group of people sitting at desks with laptops.

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open('.github/horse.png')
plt.imshow(img)

# !python -W ignore predict.py --path .github/horse.png
# Out:
# Using cache found in /root/.cache/torch/hub/saahiluppal_catr_master
# A man riding a horse on a lush green hillside.

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open('.github/airplane.png')
plt.imshow(img)

# !python -W ignore predict.py --path .github/airplane.png
# Out:
# Using cache found in /root/.cache/torch/hub/saahiluppal_catr_master
# A large plane is on a runway with a sky background
